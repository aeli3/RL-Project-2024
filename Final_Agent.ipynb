# %%
#### import gymnasium as gym
from gymnasium import spaces
import pygame
import numpy as np
import time
import matplotlib.pyplot as plt
import time
import random
import pandas as pd
from random import randrange

# seed 4 -498
np.random.seed(2)
random.seed(2)

# %%
def add_features(df):
    df['month'] = df['PRICES'].dt.month - 1
    df['day'] = df['PRICES'].dt.day - 1
    df['year'] = df['PRICES'].dt.year
    df['day_of_week'] = df['PRICES'].dt.dayofweek
    df['day_of_week'] = df['day_of_week'].astype(int)
    return df

train = pd.read_excel("train.xlsx", parse_dates=['PRICES'])
val = pd.read_excel("validate.xlsx", parse_dates=['PRICES'])
train = add_features(train)
val = add_features(val)
train.head()
# Out:
#       PRICES  Hour 01  Hour 02  Hour 03  Hour 04  Hour 05  Hour 06  Hour 07  \
# 0 2007-01-01    24.31    24.31    21.71     8.42     0.01     0.01     0.02
# 1 2007-01-02    16.01    11.00     9.01     7.50     9.00     7.45    16.50
# 2 2007-01-03    28.00    24.50    24.15    18.99    15.50    23.11    29.01
# 3 2007-01-04    31.01    28.69    27.00    24.20    12.02    27.00    28.00
# 4 2007-01-05    22.00    19.50    17.55    15.91    11.40    22.65    27.30
#
#    Hour 08  Hour 09  ...  Hour 19  Hour 20  Hour 21  Hour 22  Hour 23  \
# 0     0.01     0.01  ...    37.99    33.11    37.99    33.00    36.48
# 1    28.01    29.96  ...    59.69    50.09    50.00    36.22    31.09
# 2    39.73    43.81  ...    60.99    55.51    51.77    34.51    39.31
# 3    34.85    41.31  ...    58.99    53.50    44.01    35.00    34.46
# 4    34.00    40.01  ...    53.00    45.91    36.74    29.61    30.61
#
#    Hour 24  month  day  year  day_of_week
# 0    30.65      0    0  2007            0
# 1    29.84      0    1  2007            1
# 2    38.05      0    2  2007            2
# 3    31.57      0    3  2007            3
# 4    27.51      0    4  2007            4
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Environment

# %%
import gym
import numpy as np
import pandas as pd

class Electric_Car(gym.Env):
    def __init__(self, path_to_test_data=str):
        # Define a continuous action space, -1 to 1. (You can discretize this later!)
        self.continuous_action_space = gym.spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        # Define the test data
        self.test_data = pd.read_excel(path_to_test_data)
        self.price_values = self.test_data.iloc[:, 1:25].to_numpy()
        self.timestamps = self.test_data['PRICES']
        self.state = np.empty(7)

        # Battery characteristics
        self.battery_capacity = 50  # kWh
        self.max_power = 25 / 0.9  # kW
        self.charge_efficiency = 0.9  # -
        self.discharge_efficiency = 0.9  # -
        self.battery_level = self.battery_capacity / 2  # kWh (start at 50%)
        self.minimum_morning_level = 20  # kWh
        self.car_use_consumption = 20  # kWh

        # Time Tracking
        self.counter = 0
        self.hour = 1
        self.day = 1
        self.car_is_available = True

    def step(self, action):

        action = np.squeeze(action)  # Remove the extra dimension

        if action <-1 or action >1:
            raise ValueError('Action must be between -1 and 1')

        # Calculate if, at 7am and after the chosen action, the battery level will be below the minimum morning level:
        if self.hour == 8:
            if action > 0 and (self.battery_level < self.minimum_morning_level):
                if (
                        self.battery_level + action * self.max_power * self.charge_efficiency) < self.minimum_morning_level:  # If the chosen action will not charge the battery to 20kWh
                    action = (self.minimum_morning_level - self.battery_level) / (
                                self.max_power * self.charge_efficiency)  # Charge until 20kWh
            elif action < 0:
                if (self.battery_level + action * self.max_power) < self.minimum_morning_level:
                    if self.battery_level < self.minimum_morning_level:  # If the level was lower than 20kWh, charge until 20kWh
                        action = (self.minimum_morning_level - self.battery_level) / (
                                    self.max_power * self.charge_efficiency)  # Charge until 20kWh
                    elif self.battery_level >= self.minimum_morning_level:  # If the level was higher than 20kWh, discharge until 20kWh
                        action = (self.minimum_morning_level - self.battery_level) / (
                            self.max_power)  # Discharge until 20kWh
            elif action == 0:
                if self.battery_level < self.minimum_morning_level:
                    action = (self.minimum_morning_level - self.battery_level) / (
                                self.max_power * self.charge_efficiency)

        if not self.car_is_available:
            action = 0

        # Calculate the costs and battery level when charging (action >0)
        if (action > 0) and (self.battery_level <= self.battery_capacity):
            if (self.battery_level + action * self.max_power * self.charge_efficiency) > self.battery_capacity:
                action = (self.battery_capacity - self.battery_level) / (self.max_power * self.charge_efficiency)
            charged_electricity_kW = action * self.max_power
            charged_electricity_costs = charged_electricity_kW * self.price_values[self.day - 1][
                self.hour-1] * 2 * 1e-3
            reward = -charged_electricity_costs
            self.battery_level += charged_electricity_kW * self.charge_efficiency
        # Calculate the profits and battery level when discharging (action <0)
        elif (action < 0) and (self.battery_level >= 0):
            if (self.battery_level + action * self.max_power) < 0:
                action = -self.battery_level / (self.max_power)
            discharged_electricity_kWh = action * self.max_power  # Negative discharge value
            discharged_electricity_profits = abs(discharged_electricity_kWh) * self.discharge_efficiency * \
                                             self.price_values[self.day - 1][self.hour-1] * 1e-3
            reward = discharged_electricity_profits
            self.battery_level += discharged_electricity_kWh
            # Some small numerical errors causing the battery level to be 1e-14 to 1e-17 under 0 :
            if self.battery_level < 0:
                self.battery_level = 0

        else:
            reward = 0

        self.counter += 1  # Increase the counter
        self.hour += 1  # Increase the hour

        # There is a 50% chance that the car is unavailable from 8am to 6pm
        if self.hour == 9:
            self.car_is_available = np.random.choice([True, False])
            if not self.car_is_available:
                self.battery_level -= self.car_use_consumption
        if self.hour == 19:
            self.car_is_available = True

        if self.counter % 24 == 0:  # If the counter is a multiple of 24, increase the day, reset hour to first hour
            self.day += 1
            self.hour = 1

        terminated = self.counter == len(
            self.price_values.flatten()) - 1  # If the counter is equal to the number of hours in the test data, terminate the episode
        truncated = False

        info = action  # The final action taken after all constraints! For debugging purposes

        self.state = self.observation()  # Update the state

        return self.state, reward, terminated, truncated, info

    def observation(self):  # Returns the current state
        battery_level = self.battery_level
        price = self.price_values[self.day - 1][self.hour-1]
        hour = self.hour
        day_of_week = self.timestamps[self.day - 1].dayofweek  # Monday = 0, Sunday = 6
        day_of_year = self.timestamps[self.day - 1].dayofyear  # January 1st = 1, December 31st = 365
        month = self.timestamps[self.day - 1].month  # January = 1, December = 12
        year = self.timestamps[self.day - 1].year
        self.state = np.array(
            [battery_level, price, int(hour), int(day_of_week), int(day_of_year), int(month), int(year),
             int(self.car_is_available)])

        return self.state

# %%
class CustomDiscreteActionSpace(spaces.Discrete):
    def __init__(self, start=-25, end=25, step=12.5):
        num_actions = int((end - start) / step) + 1
        super(CustomDiscreteActionSpace, self).__init__(num_actions)
        self.start = start
        self.step_size = step
        self.end = end
    def map_to_action(self, action_index):
        return self.start + action_index * self.step_size

custom_action_space = CustomDiscreteActionSpace()

class QAgent():
    def __init__(self, env, action_space=custom_action_space, discount_rate = 0.95, learning_rate=0.3, epsilon=0.5):
        self.env = env
        self.discount_rate = discount_rate
        self.learning_rate = learning_rate
        self.epsilon = epsilon
        self.price_bins = np.array([-1,20,27,32,37,43,50,60,72,88,3000]) 
        self.action_space = action_space
        self.state_space = [5, len(self.price_bins)-1, 24, self.action_space.n]
        self.Qtable = np.zeros(self.state_space)
        self.profit = []
        self.time_constraint = 8
        self.all_profits = []
        self.max_power = 25

    def mask(self):
        # 7 am constraint  
        if self.env.hour == self.time_constraint and self.env.battery_level >= self.env.minimum_morning_level:
            lower_bound = min(np.ceil((self.env.minimum_morning_level - self.env.battery_level)*0.9), self.max_power)
            upper_bound =  min(np.floor((self.env.battery_capacity - self.env.battery_level)/0.9), self.max_power)
            mask_range = (lower_bound, upper_bound)
        elif self.env.hour == self.time_constraint and self.env.battery_level < self.env.minimum_morning_level:
            lower_bound = min(np.ceil((self.env.minimum_morning_level - self.env.battery_level)/0.9), self.max_power)
            upper_bound =  min(np.floor((self.env.battery_capacity - self.env.battery_level)/0.9), self.max_power)
            mask_range = (lower_bound, upper_bound)
        else: 
            lower_bound = max(np.ceil(-(self.env.battery_level)*0.9), -self.max_power)
            upper_bound = min(np.floor((self.env.battery_capacity - self.env.battery_level)/0.9), self.max_power)
            mask_range = (lower_bound, upper_bound)
                
        # construct boolean mask_vector
        mask = np.arange(self.action_space.start, self.action_space.end + 1, self.action_space.step_size) 
        mask = np.where((mask >= mask_range[0]) & (mask <= mask_range[1]), True, False)
        return mask

    def reward_shape(self, reward, continuous_action):
        if continuous_action < 0:
            reward -= 0.05 * 25
        if continuous_action > 0:
            reward -= 0.02 * 25
        return reward

    def to_continuous(self, action):
        continuous = np.linspace(-1 , 1, 5)
        return continuous[action]

    def discretize_features(self, features):
        battery, price, hour  = features[0], features[1], features[2]
        return tuple([int(battery//10.001), np.max(np.where(self.price_bins<price)), int(hour - 1)])

    def reset(self):
        # Battery characteristics
        self.env.battery_level = self.env.battery_capacity / 2  # kWh (start at 50%)

        # Time Tracking
        self.env.counter = 0
        self.env.hour = 1
        self.env.day = 1
        self.env.car_is_available = True
        
    def select_action_epsilon_greedy(self, current_state):
        mask = self.mask()

        #pick random action
        if (np.random.uniform(0,1) > 1-self.epsilon) or (np.all(self.Qtable[current_state] == 0)):
            
            action = np.random.choice(np.arange(self.action_space.n)[mask])
        #pick greedy action
        else:
            max_action = np.argmax(self.Qtable[current_state][mask])
            action = np.where(mask)[0][0] + max_action
        return action

    def train(self, simulations = 100, epsilon = 0.1):
        for i in range(simulations):
            done = False
            profits = 0
            self.epsilon = max(0.05, self.epsilon - 0.05)
            self.learning_rate *= 0.9
            while not done:    
                current_state = self.env.observation()
                current_state = self.discretize_features(current_state) 
                action = self.select_action_epsilon_greedy(current_state)
                continuous_action = self.to_continuous(action)
                
                next_state, reward, done, truncated, info = self.env.step(continuous_action)
                profits += reward
                
                next_state = self.discretize_features(next_state)
                next_state_mask = self.mask()
                reward = self.reward_shape(reward, continuous_action)
                
                # update Q_values
                Q_target = (reward + self.discount_rate*np.max(self.Qtable[next_state][next_state_mask]))
                delta = self.learning_rate * (Q_target - self.Qtable[current_state][action])
                self.Qtable[current_state][action] = self.Qtable[current_state][action] + delta

            print(f'{i} simulations done')
            self.all_profits.append(profits)
            self.reset()
            
    def predict(self, state):
        mask = self.mask()
        max_action = np.argmax(self.Qtable[state][mask])
        action = np.where(mask)[0][0] + max_action
        return action


    def plot_profits(self):
        plt.plot(self.all_profits)
        plt.xlabel('Epochs')
        plt.ylabel('Profit')
        plt.title("Cost per epoch")

# %% [markdown]
# ## Train

# %%
env = Electric_Car(path_to_test_data='train.xlsx')
agent = QAgent(env, action_space=custom_action_space)
agent.train(simulations=16)
agent.plot_profits()
# Out:
# 0 simulations done
# 1 simulations done
# 2 simulations done
# 3 simulations done
# 4 simulations done
# 5 simulations done
# 6 simulations done
# 7 simulations done
# 8 simulations done
# 9 simulations done
# 10 simulations done
# 11 simulations done
# 12 simulations done
# 13 simulations done
# 14 simulations done
# 15 simulations done

# %% [markdown]
# ## Eval

# %%
eval_env = Electric_Car(path_to_test_data='validate.xlsx')
agent.env = eval_env
discrete_act = [-25, -12.5, 0, 12.5, 25]
all_profits = []

for episode in range(5):
    done = False
    profits = 0
    while not done:
        current_state = agent.env.observation()
        battery, price, hour  = current_state[0], current_state[1], current_state[2]
        current_state = agent.discretize_features(current_state)
        
        action = agent.predict(current_state)
        continuous_action = agent.to_continuous(action)
        if agent.env.car_is_available and episode == 4:
            print(f"at time {hour} agent transacts {discrete_act[action]}, price is {price} battery is {battery}")
        next_state, reward, done, trucated, info = agent.env.step(continuous_action)
        profits += reward

    all_profits.append(profits)
    agent.reset()

print("Profit on validation set over 5 episodes: ", np.mean(all_profits))
# Out:
# at time 1.0 agent transacts 0, price is 13.2 battery is 25.0
# at time 2.0 agent transacts 0, price is 13.14 battery is 25.0
# at time 3.0 agent transacts 0, price is 11.83 battery is 25.0
# at time 4.0 agent transacts 0, price is 9.49 battery is 25.0
# at time 5.0 agent transacts 0, price is 8.63 battery is 25.0
# at time 6.0 agent transacts 0, price is 7.12 battery is 25.0
# at time 7.0 agent transacts 0, price is 4.06 battery is 25.0
# at time 8.0 agent transacts 0, price is 1.0 battery is 25.0
# at time 9.0 agent transacts 0, price is 8.4 battery is 25.0
# at time 10.0 agent transacts 0, price is 9.11 battery is 25.0
# at time 11.0 agent transacts 0, price is 10.18 battery is 25.0
# at time 12.0 agent transacts 0, price is 13.56 battery is 25.0
# at time 13.0 agent transacts 12.5, price is 18.02 battery is 25.0
# at time 14.0 agent transacts 0, price is 15.02 battery is 37.5
# at time 15.0 agent transacts 0, price is 12.58 battery is 37.5
# at time 16.0 agent transacts 0, price is 10.18 battery is 37.5
# at time 17.0 agent transacts 0, price is 9.81 battery is 37.5
# at time 18.0 agent transacts 0, price is 18.79 battery is 37.5
# at time 19.0 agent transacts 0, price is 22.7 battery is 37.5
# at time 20.0 agent transacts 0, price is 30.06 battery is 37.5
# at time 21.0 agent transacts 0, price is 27.3 battery is 37.5
# at time 22.0 agent transacts 0, price is 23.93 battery is 37.5
# at time 23.0 agent transacts 0, price is 33.49 battery is 37.5
# at time 24.0 agent transacts 0, price is 31.06 battery is 37.5
# at time 1.0 agent transacts 0, price is 23.0 battery is 37.5
# at time 2.0 agent transacts 0, price is 17.45 battery is 37.5
# at time 3.0 agent transacts 0, price is 19.12 battery is 37.5
# at time 4.0 agent transacts 0, price is 12.76 battery is 37.5
# at time 5.0 agent transacts 0, price is 10.19 battery is 37.5
# at time 6.0 agent transacts 0, price is 11.99 battery is 37.5
# at time 7.0 agent transacts 0, price is 15.65 battery is 37.5
# at time 8.0 agent transacts 0, price is 23.5 battery is 37.5
# at time 9.0 agent transacts 0, price is 28.9 battery is 37.5
# at time 10.0 agent transacts 0, price is 37.12 battery is 37.5
# at time 11.0 agent transacts 0, price is 41.82 battery is 37.5
# at time 12.0 agent transacts 0, price is 44.69 battery is 37.5
# at time 13.0 agent transacts 0, price is 47.0 battery is 37.5
# at time 14.0 agent transacts 0, price is 41.15 battery is 37.5
# at time 15.0 agent transacts 0, price is 39.25 battery is 37.5
# at time 16.0 agent transacts 0, price is 34.95 battery is 37.5
# at time 17.0 agent transacts 0, price is 37.26 battery is 37.5
# at time 18.0 agent transacts 0, price is 46.84 battery is 37.5
# at time 19.0 agent transacts 0, price is 56.49 battery is 37.5
# at time 20.0 agent transacts 0, price is 56.05 battery is 37.5
# at time 21.0 agent transacts 0, price is 45.5 battery is 37.5
# at time 22.0 agent transacts 0, price is 39.32 battery is 37.5
# at time 23.0 agent transacts 0, price is 43.0 battery is 37.5
# at time 24.0 agent transacts 0, price is 41.07 battery is 37.5
# at time 1.0 agent transacts 0, price is 39.44 battery is 37.5
# at time 2.0 agent transacts 0, price is 31.98 battery is 37.5
# at time 3.0 agent transacts 0, price is 30.0 battery is 37.5
# at time 4.0 agent transacts 0, price is 27.07 battery is 37.5
# at time 5.0 agent transacts 0, price is 19.18 battery is 37.5
# at time 6.0 agent transacts 0, price is 17.51 battery is 37.5
# at time 7.0 agent transacts 0, price is 17.03 battery is 37.5
# at time 8.0 agent transacts 0, price is 21.0 battery is 37.5
# at time 19.0 agent transacts 0, price is 56.85 battery is 17.5
# at time 20.0 agent transacts 0, price is 57.75 battery is 17.5
# at time 21.0 agent transacts 0, price is 49.66 battery is 17.5
# at time 22.0 agent transacts 0, price is 39.67 battery is 17.5
# at time 23.0 agent transacts 0, price is 43.55 battery is 17.5
# at time 24.0 agent transacts 0, price is 39.34 battery is 17.5
# at time 1.0 agent transacts 0, price is 37.15 battery is 17.5
# at time 2.0 agent transacts 0, price is 33.47 battery is 17.5
# at time 3.0 agent transacts 0, price is 28.0 battery is 17.5
# at time 4.0 agent transacts 0, price is 21.29 battery is 17.5
# at time 5.0 agent transacts 12.5, price is 16.92 battery is 17.5
# at time 6.0 agent transacts 0, price is 28.0 battery is 30.0
# at time 7.0 agent transacts 0, price is 36.43 battery is 30.0
# at time 8.0 agent transacts 0, price is 59.47 battery is 30.0
# at time 19.0 agent transacts 0, price is 78.77 battery is 10.0
# at time 20.0 agent transacts 0, price is 64.46 battery is 10.0
# at time 21.0 agent transacts 0, price is 50.73 battery is 10.0
# at time 22.0 agent transacts 0, price is 43.9 battery is 10.0
# at time 23.0 agent transacts 0, price is 46.58 battery is 10.0
# at time 24.0 agent transacts 0, price is 43.38 battery is 10.0
# at time 1.0 agent transacts 0, price is 37.9 battery is 10.0
# at time 2.0 agent transacts 0, price is 38.11 battery is 10.0
# at time 3.0 agent transacts 0, price is 29.99 battery is 10.0
# at time 4.0 agent transacts 0, price is 28.91 battery is 10.0
# at time 5.0 agent transacts 25, price is 27.0 battery is 10.0
# at time 6.0 agent transacts 0, price is 29.56 battery is 35.0
# at time 7.0 agent transacts 0, price is 40.94 battery is 35.0
# at time 8.0 agent transacts 0, price is 55.0 battery is 35.0
# at time 9.0 agent transacts 0, price is 55.5 battery is 35.0
# at time 10.0 agent transacts 0, price is 57.1 battery is 35.0
# at time 11.0 agent transacts 0, price is 57.0 battery is 35.0
# at time 12.0 agent transacts 0, price is 58.0 battery is 35.0
# at time 13.0 agent transacts 0, price is 57.0 battery is 35.0
# at time 14.0 agent transacts 0, price is 56.17 battery is 35.0
# at time 15.0 agent transacts 0, price is 56.28 battery is 35.0
# at time 16.0 agent transacts 0, price is 53.54 battery is 35.0
# at time 17.0 agent transacts 0, price is 56.19 battery is 35.0
# at time 18.0 agent transacts 0, price is 67.2 battery is 35.0
# at time 19.0 agent transacts 0, price is 62.0 battery is 35.0
# at time 20.0 agent transacts 0, price is 55.0 battery is 35.0
# at time 21.0 agent transacts 0, price is 49.5 battery is 35.0
# at time 22.0 agent transacts 0, price is 45.88 battery is 35.0
# at time 23.0 agent transacts 0, price is 42.68 battery is 35.0
# at time 24.0 agent transacts 0, price is 41.85 battery is 35.0
# at time 1.0 agent transacts 0, price is 48.52 battery is 35.0
# at time 2.0 agent transacts 0, price is 39.62 battery is 35.0
# at time 3.0 agent transacts 0, price is 41.25 battery is 35.0
# at time 4.0 agent transacts 0, price is 37.12 battery is 35.0
# at time 5.0 agent transacts 0, price is 32.5 battery is 35.0
# at time 6.0 agent transacts 0, price is 39.5 battery is 35.0
# at time 7.0 agent transacts 0, price is 51.69 battery is 35.0
# at time 8.0 agent transacts 0, price is 56.9 battery is 35.0
# at time 19.0 agent transacts 0, price is 75.0 battery is 15.0
# at time 20.0 agent transacts 0, price is 56.9 battery is 15.0
# at time 21.0 agent transacts 0, price is 43.56 battery is 15.0
# at time 22.0 agent transacts 0, price is 40.5 battery is 15.0
# at time 23.0 agent transacts 0, price is 56.36 battery is 15.0
# at time 24.0 agent transacts 0, price is 58.98 battery is 15.0
# at time 1.0 agent transacts 0, price is 40.0 battery is 15.0
# at time 2.0 agent transacts 0, price is 38.02 battery is 15.0
# at time 3.0 agent transacts 0, price is 34.99 battery is 15.0
# at time 4.0 agent transacts 0, price is 33.65 battery is 15.0
# at time 5.0 agent transacts 12.5, price is 32.0 battery is 15.0
# at time 6.0 agent transacts 0, price is 32.82 battery is 27.5
# at time 7.0 agent transacts 0, price is 39.1 battery is 27.5
# at time 8.0 agent transacts 0, price is 52.65 battery is 27.5
# at time 9.0 agent transacts 0, price is 59.0 battery is 27.5
# at time 10.0 agent transacts 0, price is 62.66 battery is 27.5
# at time 11.0 agent transacts 0, price is 61.1 battery is 27.5
# at time 12.0 agent transacts 0, price is 62.86 battery is 27.5
# at time 13.0 agent transacts 0, price is 63.0 battery is 27.5
# at time 14.0 agent transacts 0, price is 70.8 battery is 27.5
# at time 15.0 agent transacts 0, price is 66.4 battery is 27.5
# at time 16.0 agent transacts 0, price is 55.75 battery is 27.5
# at time 17.0 agent transacts 0, price is 60.12 battery is 27.5
# at time 18.0 agent transacts 0, price is 77.44 battery is 27.5
# at time 19.0 agent transacts 0, price is 70.0 battery is 27.5
# at time 20.0 agent transacts 0, price is 59.95 battery is 27.5
# at time 21.0 agent transacts 0, price is 54.0 battery is 27.5
# at time 22.0 agent transacts 0, price is 48.0 battery is 27.5
# at time 23.0 agent transacts 0, price is 46.47 battery is 27.5
# at time 24.0 agent transacts 0, price is 43.94 battery is 27.5
# at time 1.0 agent transacts 0, price is 47.96 battery is 27.5
# at time 2.0 agent transacts 0, price is 49.02 battery is 27.5
# at time 3.0 agent transacts 0, price is 37.0 battery is 27.5
# at time 4.0 agent transacts 0, price is 33.61 battery is 27.5
# at time 5.0 agent transacts 0, price is 32.96 battery is 27.5
# at time 6.0 agent transacts 0, price is 33.31 battery is 27.5
# at time 7.0 agent transacts 0, price is 54.9 battery is 27.5
# at time 8.0 agent transacts 0, price is 66.26 battery is 27.5
# at time 9.0 agent transacts 0, price is 75.0 battery is 27.5
# at time 10.0 agent transacts 0, price is 78.09 battery is 27.5
# at time 11.0 agent transacts 0, price is 61.45 battery is 27.5
# at time 12.0 agent transacts 0, price is 59.26 battery is 27.5
# at time 13.0 agent transacts 0, price is 57.0 battery is 27.5
# at time 14.0 agent transacts 0, price is 61.4 battery is 27.5
# at time 15.0 agent transacts 0, price is 49.01 battery is 27.5
# at time 16.0 agent transacts 0, price is 48.0 battery is 27.5
# at time 17.0 agent transacts 0, price is 49.66 battery is 27.5
# at time 18.0 agent transacts 0, price is 63.08 battery is 27.5
# at time 19.0 agent transacts 0, price is 55.63 battery is 27.5
# at time 20.0 agent transacts 0, price is 47.15 battery is 27.5
# at time 21.0 agent transacts 0, price is 41.49 battery is 27.5
# at time 22.0 agent transacts 0, price is 34.99 battery is 27.5
# at time 23.0 agent transacts 0, price is 36.04 battery is 27.5
# at time 24.0 agent transacts 0, price is 54.9 battery is 27.5
# at time 1.0 agent transacts 0, price is 30.04 battery is 27.5
# at time 2.0 agent transacts 0, price is 28.0 battery is 27.5
# at time 3.0 agent transacts 0, price is 46.16 battery is 27.5
# at time 4.0 agent transacts 0, price is 27.53 battery is 27.5
# at time 5.0 agent transacts 0, price is 25.0 battery is 27.5
# at time 6.0 agent transacts 0, price is 22.0 battery is 27.5
# at time 7.0 agent transacts 0, price is 30.24 battery is 27.5
# at time 8.0 agent transacts 0, price is 33.0 battery is 27.5
# at time 9.0 agent transacts 0, price is 37.0 battery is 27.5
# at time 10.0 agent transacts 0, price is 42.99 battery is 27.5
# at time 11.0 agent transacts 0, price is 46.59 battery is 27.5
# at time 12.0 agent transacts 0, price is 46.76 battery is 27.5
# at time 13.0 agent transacts 0, price is 47.66 battery is 27.5
# at time 14.0 agent transacts 0, price is 45.0 battery is 27.5
# at time 15.0 agent transacts 0, price is 43.6 battery is 27.5
# at time 16.0 agent transacts 0, price is 40.06 battery is 27.5
# at time 17.0 agent transacts 0, price is 45.0 battery is 27.5
# at time 18.0 agent transacts 0, price is 55.29 battery is 27.5
# at time 19.0 agent transacts 0, price is 51.61 battery is 27.5
# at time 20.0 agent transacts 0, price is 48.0 battery is 27.5
# at time 21.0 agent transacts 0, price is 48.77 battery is 27.5
# at time 22.0 agent transacts 0, price is 39.93 battery is 27.5
# at time 23.0 agent transacts 0, price is 43.24 battery is 27.5
# at time 24.0 agent transacts 0, price is 43.05 battery is 27.5
# at time 1.0 agent transacts 0, price is 66.0 battery is 27.5
# at time 2.0 agent transacts 0, price is 63.19 battery is 27.5
# at time 3.0 agent transacts 0, price is 56.18 battery is 27.5
# at time 4.0 agent transacts 0, price is 18.0 battery is 27.5
# at time 5.0 agent transacts 0, price is 0.01 battery is 27.5
# at time 6.0 agent transacts 0, price is 0.01 battery is 27.5
# at time 7.0 agent transacts 0, price is 1.0 battery is 27.5
# at time 8.0 agent transacts 0, price is 0.01 battery is 27.5
# at time 19.0 agent transacts 0, price is 54.0 battery is 7.5
# at time 20.0 agent transacts 0, price is 49.18 battery is 7.5
# at time 21.0 agent transacts 0, price is 45.62 battery is 7.5
# at time 22.0 agent transacts 0, price is 43.0 battery is 7.5
# at time 23.0 agent transacts 0, price is 43.0 battery is 7.5
# at time 24.0 agent transacts 0, price is 38.1 battery is 7.5
# at time 1.0 agent transacts 0, price is 59.43 battery is 7.5
# at time 2.0 agent transacts 0, price is 45.93 battery is 7.5
# at time 3.0 agent transacts 0, price is 36.09 battery is 7.5
# at time 4.0 agent transacts 0, price is 31.0 battery is 7.5
# at time 5.0 agent transacts 25, price is 30.91 battery is 7.5
# at time 6.0 agent transacts 0, price is 30.9 battery is 32.5
# at time 7.0 agent transacts 0, price is 37.31 battery is 32.5
# at time 8.0 agent transacts 0, price is 57.04 battery is 32.5
# at time 19.0 agent transacts 0, price is 80.66 battery is 12.5
# at time 20.0 agent transacts 0, price is 63.5 battery is 12.5
# at time 21.0 agent transacts 0, price is 49.99 battery is 12.5
# at time 22.0 agent transacts 0, price is 43.66 battery is 12.5
# at time 23.0 agent transacts 0, price is 66.19 battery is 12.5
# at time 24.0 agent transacts 0, price is 62.92 battery is 12.5
# at time 1.0 agent transacts 0, price is 63.2 battery is 12.5
# at time 2.0 agent transacts 0, price is 67.27 battery is 12.5
# at time 3.0 agent transacts 0, price is 61.85 battery is 12.5
# at time 4.0 agent transacts 0, price is 55.0 battery is 12.5
# at time 5.0 agent transacts 0, price is 53.02 battery is 12.5
# at time 6.0 agent transacts 12.5, price is 60.29 battery is 12.5
# at time 7.0 agent transacts 0, price is 75.0 battery is 25.0
# at time 8.0 agent transacts 0, price is 102.12 battery is 25.0
# at time 19.0 agent transacts 0, price is 101.25 battery is 5.0
# at time 20.0 agent transacts 0, price is 72.77 battery is 5.0
# at time 21.0 agent transacts 0, price is 64.15 battery is 5.0
# at time 22.0 agent transacts 0, price is 42.0 battery is 5.0
# at time 23.0 agent transacts 0, price is 61.1 battery is 5.0
# at time 24.0 agent transacts 0, price is 54.69 battery is 5.0
# at time 1.0 agent transacts 0, price is 44.96 battery is 5.0
# at time 2.0 agent transacts 0, price is 46.4 battery is 5.0
# at time 3.0 agent transacts 0, price is 45.88 battery is 5.0
# at time 4.0 agent transacts 0, price is 35.01 battery is 5.0
# at time 5.0 agent transacts 25, price is 34.28 battery is 5.0
# at time 6.0 agent transacts 0, price is 37.11 battery is 30.0
# at time 7.0 agent transacts 0, price is 53.05 battery is 30.0
# at time 8.0 agent transacts 0, price is 66.18 battery is 30.0
# at time 19.0 agent transacts 0, price is 72.13 battery is 10.0
# at time 20.0 agent transacts 0, price is 71.03 battery is 10.0
# at time 21.0 agent transacts 0, price is 67.5 battery is 10.0
# at time 22.0 agent transacts 0, price is 43.5 battery is 10.0
# at time 23.0 agent transacts 0, price is 51.67 battery is 10.0
# at time 24.0 agent transacts 0, price is 47.0 battery is 10.0
# at time 1.0 agent transacts 0, price is 44.09 battery is 10.0
# at time 2.0 agent transacts 0, price is 45.18 battery is 10.0
# at time 3.0 agent transacts 0, price is 41.19 battery is 10.0
# at time 4.0 agent transacts 0, price is 33.5 battery is 10.0
# at time 5.0 agent transacts 25, price is 32.21 battery is 10.0
# at time 6.0 agent transacts 0, price is 40.9 battery is 35.0
# at time 7.0 agent transacts 0, price is 51.47 battery is 35.0
# at time 8.0 agent transacts 0, price is 65.25 battery is 35.0
# at time 9.0 agent transacts 0, price is 65.58 battery is 35.0
# at time 10.0 agent transacts 0, price is 66.2 battery is 35.0
# at time 11.0 agent transacts 0, price is 66.19 battery is 35.0
# at time 12.0 agent transacts 0, price is 66.17 battery is 35.0
# at time 13.0 agent transacts 0, price is 65.29 battery is 35.0
# at time 14.0 agent transacts 0, price is 63.08 battery is 35.0
# at time 15.0 agent transacts 0, price is 62.03 battery is 35.0
# at time 16.0 agent transacts 0, price is 57.23 battery is 35.0
# at time 17.0 agent transacts 0, price is 61.11 battery is 35.0
# at time 18.0 agent transacts 0, price is 69.0 battery is 35.0
# at time 19.0 agent transacts 0, price is 87.96 battery is 35.0
# at time 20.0 agent transacts 0, price is 69.99 battery is 35.0
# at time 21.0 agent transacts 0, price is 66.19 battery is 35.0
# at time 22.0 agent transacts 0, price is 55.59 battery is 35.0
# at time 23.0 agent transacts 0, price is 55.53 battery is 35.0
# at time 24.0 agent transacts 0, price is 50.62 battery is 35.0
# at time 1.0 agent transacts 0, price is 47.73 battery is 35.0
# at time 2.0 agent transacts 0, price is 47.78 battery is 35.0
# at time 3.0 agent transacts 0, price is 42.75 battery is 35.0
# at time 4.0 agent transacts 0, price is 32.99 battery is 35.0
# at time 5.0 agent transacts 0, price is 32.0 battery is 35.0
# at time 6.0 agent transacts 0, price is 39.84 battery is 35.0
# at time 7.0 agent transacts 0, price is 48.96 battery is 35.0
# at time 8.0 agent transacts 0, price is 65.0 battery is 35.0
# at time 9.0 agent transacts 0, price is 65.17 battery is 35.0
# at time 10.0 agent transacts 0, price is 64.82 battery is 35.0
# at time 11.0 agent transacts 0, price is 66.18 battery is 35.0
# at time 12.0 agent transacts 0, price is 66.0 battery is 35.0
# at time 13.0 agent transacts 0, price is 62.93 battery is 35.0
# at time 14.0 agent transacts 0, price is 62.13 battery is 35.0
# at time 15.0 agent transacts 0, price is 57.95 battery is 35.0
# at time 16.0 agent transacts 0, price is 50.41 battery is 35.0
# at time 17.0 agent transacts 0, price is 53.8 battery is 35.0
# at time 18.0 agent transacts 0, price is 63.02 battery is 35.0
# at time 19.0 agent transacts 0, price is 67.44 battery is 35.0
# at time 20.0 agent transacts 0, price is 66.99 battery is 35.0
# at time 21.0 agent transacts 0, price is 60.95 battery is 35.0
# at time 22.0 agent transacts 0, price is 50.77 battery is 35.0
# at time 23.0 agent transacts 0, price is 53.06 battery is 35.0
# at time 24.0 agent transacts 0, price is 53.86 battery is 35.0
# at time 1.0 agent transacts 0, price is 42.56 battery is 35.0
# at time 2.0 agent transacts 0, price is 40.74 battery is 35.0
# at time 3.0 agent transacts 0, price is 37.56 battery is 35.0
# at time 4.0 agent transacts 0, price is 34.01 battery is 35.0
# at time 5.0 agent transacts 0, price is 31.76 battery is 35.0
# at time 6.0 agent transacts 0, price is 29.8 battery is 35.0
# at time 7.0 agent transacts 0, price is 29.2 battery is 35.0
# at time 8.0 agent transacts 0, price is 27.67 battery is 35.0
# at time 9.0 agent transacts 0, price is 36.67 battery is 35.0
# at time 10.0 agent transacts 0, price is 43.0 battery is 35.0
# at time 11.0 agent transacts 0, price is 45.34 battery is 35.0
# at time 12.0 agent transacts 0, price is 46.0 battery is 35.0
# at time 13.0 agent transacts 0, price is 43.0 battery is 35.0
# at time 14.0 agent transacts 0, price is 39.59 battery is 35.0
# at time 15.0 agent transacts 0, price is 37.93 battery is 35.0
# at time 16.0 agent transacts 0, price is 34.87 battery is 35.0
# at time 17.0 agent transacts 0, price is 34.3 battery is 35.0
# at time 18.0 agent transacts 0, price is 44.8 battery is 35.0
# at time 19.0 agent transacts 0, price is 53.12 battery is 35.0
# at time 20.0 agent transacts 0, price is 39.93 battery is 35.0
# at time 21.0 agent transacts 0, price is 34.2 battery is 35.0
# at time 22.0 agent transacts 0, price is 37.0 battery is 35.0
# at time 23.0 agent transacts 0, price is 47.03 battery is 35.0
# at time 24.0 agent transacts 0, price is 47.08 battery is 35.0
# at time 1.0 agent transacts 0, price is 41.78 battery is 35.0
# at time 2.0 agent transacts 0, price is 40.17 battery is 35.0
# at time 3.0 agent transacts 0, price is 30.91 battery is 35.0
# at time 4.0 agent transacts 0, price is 17.0 battery is 35.0
# at time 5.0 agent transacts 0, price is 14.79 battery is 35.0
# at time 6.0 agent transacts 0, price is 12.31 battery is 35.0
# at time 7.0 agent transacts 0, price is 11.93 battery is 35.0
# at time 8.0 agent transacts 0, price is 14.0 battery is 35.0
# at time 19.0 agent transacts 0, price is 41.11 battery is 15.0
# at time 20.0 agent transacts 0, price is 43.0 battery is 15.0
# at time 21.0 agent transacts 0, price is 43.71 battery is 15.0
# at time 22.0 agent transacts 0, price is 42.65 battery is 15.0
# at time 23.0 agent transacts 0, price is 45.21 battery is 15.0
# at time 24.0 agent transacts 0, price is 42.73 battery is 15.0
# at time 1.0 agent transacts 0, price is 32.01 battery is 15.0
# at time 2.0 agent transacts 0, price is 31.0 battery is 15.0
# at time 3.0 agent transacts 0, price is 26.44 battery is 15.0
# at time 4.0 agent transacts 0, price is 19.15 battery is 15.0
# at time 5.0 agent transacts 12.5, price is 19.0 battery is 15.0
# at time 6.0 agent transacts 0, price is 26.21 battery is 27.5
# at time 7.0 agent transacts 0, price is 40.2 battery is 27.5
# at time 8.0 agent transacts 0, price is 61.53 battery is 27.5
# at time 19.0 agent transacts 0, price is 68.27 battery is 7.5
# at time 20.0 agent transacts 0, price is 54.75 battery is 7.5
# at time 21.0 agent transacts 0, price is 47.8 battery is 7.5
# at time 22.0 agent transacts 0, price is 43.54 battery is 7.5
# at time 23.0 agent transacts 0, price is 47.91 battery is 7.5
# at time 24.0 agent transacts 0, price is 42.31 battery is 7.5
# at time 1.0 agent transacts 0, price is 39.93 battery is 7.5
# at time 2.0 agent transacts 0, price is 38.67 battery is 7.5
# at time 3.0 agent transacts 0, price is 33.99 battery is 7.5
# at time 4.0 agent transacts 0, price is 30.91 battery is 7.5
# at time 5.0 agent transacts 25, price is 29.0 battery is 7.5
# at time 6.0 agent transacts 0, price is 36.53 battery is 32.5
# at time 7.0 agent transacts 0, price is 49.59 battery is 32.5
# at time 8.0 agent transacts 0, price is 57.0 battery is 32.5
# at time 19.0 agent transacts 0, price is 65.46 battery is 12.5
# at time 20.0 agent transacts 0, price is 58.87 battery is 12.5
# at time 21.0 agent transacts 0, price is 50.86 battery is 12.5
# at time 22.0 agent transacts 0, price is 43.4 battery is 12.5
# at time 23.0 agent transacts 0, price is 47.66 battery is 12.5
# at time 24.0 agent transacts 0, price is 43.79 battery is 12.5
# at time 1.0 agent transacts 0, price is 38.57 battery is 12.5
# at time 2.0 agent transacts 0, price is 37.33 battery is 12.5
# at time 3.0 agent transacts 0, price is 31.64 battery is 12.5
# at time 4.0 agent transacts 0, price is 29.31 battery is 12.5
# at time 5.0 agent transacts 12.5, price is 28.91 battery is 12.5
# at time 6.0 agent transacts 0, price is 32.96 battery is 25.0
# at time 7.0 agent transacts 0, price is 43.08 battery is 25.0
# at time 8.0 agent transacts 0, price is 58.0 battery is 25.0
# at time 9.0 agent transacts 0, price is 56.44 battery is 25.0
# at time 10.0 agent transacts 0, price is 56.87 battery is 25.0
# at time 11.0 agent transacts 0, price is 58.62 battery is 25.0
# at time 12.0 agent transacts 0, price is 53.09 battery is 25.0
# at time 13.0 agent transacts 0, price is 51.0 battery is 25.0
# at time 14.0 agent transacts 0, price is 52.46 battery is 25.0
# at time 15.0 agent transacts 0, price is 54.68 battery is 25.0
# at time 16.0 agent transacts 0, price is 49.78 battery is 25.0
# at time 17.0 agent transacts 0, price is 49.99 battery is 25.0
# at time 18.0 agent transacts 0, price is 54.93 battery is 25.0
# at time 19.0 agent transacts 0, price is 63.84 battery is 25.0
# at time 20.0 agent transacts 0, price is 47.1 battery is 25.0
# at time 21.0 agent transacts 0, price is 46.83 battery is 25.0
# at time 22.0 agent transacts 0, price is 43.0 battery is 25.0
# at time 23.0 agent transacts 0, price is 44.99 battery is 25.0
# at time 24.0 agent transacts 0, price is 41.02 battery is 25.0
# at time 1.0 agent transacts 0, price is 37.51 battery is 25.0
# at time 2.0 agent transacts 0, price is 36.12 battery is 25.0
# at time 3.0 agent transacts 0, price is 33.05 battery is 25.0
# at time 4.0 agent transacts 0, price is 28.81 battery is 25.0
# at time 5.0 agent transacts 0, price is 27.54 battery is 25.0
# at time 6.0 agent transacts 0, price is 34.0 battery is 25.0
# at time 7.0 agent transacts 0, price is 41.3 battery is 25.0
# at time 8.0 agent transacts 0, price is 53.18 battery is 25.0
# at time 19.0 agent transacts 0, price is 63.16 battery is 5.0
# at time 20.0 agent transacts 0, price is 47.58 battery is 5.0
# at time 21.0 agent transacts 0, price is 44.93 battery is 5.0
# at time 22.0 agent transacts 0, price is 42.0 battery is 5.0
# at time 23.0 agent transacts 0, price is 45.0 battery is 5.0
# at time 24.0 agent transacts 0, price is 40.47 battery is 5.0
# at time 1.0 agent transacts 0, price is 37.75 battery is 5.0
# at time 2.0 agent transacts 0, price is 37.1 battery is 5.0
# at time 3.0 agent transacts 0, price is 32.48 battery is 5.0
# at time 4.0 agent transacts 0, price is 30.3 battery is 5.0
# at time 5.0 agent transacts 25, price is 29.34 battery is 5.0
# at time 6.0 agent transacts 0, price is 31.34 battery is 30.0
# at time 7.0 agent transacts 0, price is 40.86 battery is 30.0
# at time 8.0 agent transacts 0, price is 54.14 battery is 30.0
# at time 9.0 agent transacts 0, price is 55.0 battery is 30.0
# at time 10.0 agent transacts 0, price is 56.7 battery is 30.0
# at time 11.0 agent transacts 0, price is 54.56 battery is 30.0
# at time 12.0 agent transacts 0, price is 55.39 battery is 30.0
# at time 13.0 agent transacts 0, price is 52.92 battery is 30.0
# at time 14.0 agent transacts 0, price is 50.0 battery is 30.0
# at time 15.0 agent transacts 0, price is 48.45 battery is 30.0
# at time 16.0 agent transacts 0, price is 44.96 battery is 30.0
# at time 17.0 agent transacts 0, price is 45.5 battery is 30.0
# at time 18.0 agent transacts 0, price is 51.22 battery is 30.0
# at time 19.0 agent transacts 0, price is 51.43 battery is 30.0
# at time 20.0 agent transacts 0, price is 44.88 battery is 30.0
# at time 21.0 agent transacts 0, price is 41.5 battery is 30.0
# at time 22.0 agent transacts 0, price is 42.4 battery is 30.0
# at time 23.0 agent transacts 0, price is 43.47 battery is 30.0
# at time 24.0 agent transacts 0, price is 40.51 battery is 30.0
# at time 1.0 agent transacts 0, price is 41.27 battery is 30.0
# at time 2.0 agent transacts 0, price is 39.09 battery is 30.0
# at time 3.0 agent transacts 0, price is 35.0 battery is 30.0
# at time 4.0 agent transacts 0, price is 30.95 battery is 30.0
# at time 5.0 agent transacts 0, price is 28.5 battery is 30.0
# at time 6.0 agent transacts 0, price is 29.58 battery is 30.0
# at time 7.0 agent transacts 0, price is 29.77 battery is 30.0
# at time 8.0 agent transacts 0, price is 35.0 battery is 30.0
# at time 19.0 agent transacts 0, price is 53.19 battery is 10.0
# at time 20.0 agent transacts 0, price is 52.83 battery is 10.0
# at time 21.0 agent transacts 0, price is 46.29 battery is 10.0
# at time 22.0 agent transacts 0, price is 41.19 battery is 10.0
# at time 23.0 agent transacts 0, price is 43.01 battery is 10.0
# at time 24.0 agent transacts 0, price is 42.0 battery is 10.0
# at time 1.0 agent transacts 0, price is 42.07 battery is 10.0
# at time 2.0 agent transacts 0, price is 41.83 battery is 10.0
# at time 3.0 agent transacts 0, price is 40.09 battery is 10.0
# at time 4.0 agent transacts 0, price is 33.28 battery is 10.0
# at time 5.0 agent transacts 25, price is 26.67 battery is 10.0
# at time 6.0 agent transacts 0, price is 22.0 battery is 35.0
# at time 7.0 agent transacts 0, price is 20.05 battery is 35.0
# at time 8.0 agent transacts 0, price is 27.85 battery is 35.0
# at time 9.0 agent transacts 0, price is 31.16 battery is 35.0
# at time 10.0 agent transacts 0, price is 36.57 battery is 35.0
# at time 11.0 agent transacts 0, price is 42.76 battery is 35.0
# at time 12.0 agent transacts 0, price is 46.09 battery is 35.0
# at time 13.0 agent transacts 0, price is 48.6 battery is 35.0
# at time 14.0 agent transacts 0, price is 42.61 battery is 35.0
# at time 15.0 agent transacts 0, price is 37.82 battery is 35.0
# at time 16.0 agent transacts 0, price is 34.4 battery is 35.0
# at time 17.0 agent transacts 0, price is 34.84 battery is 35.0
# at time 18.0 agent transacts 0, price is 42.15 battery is 35.0
# at time 19.0 agent transacts 0, price is 50.08 battery is 35.0
# at time 20.0 agent transacts 0, price is 49.48 battery is 35.0
# at time 21.0 agent transacts 0, price is 45.68 battery is 35.0
# at time 22.0 agent transacts 0, price is 42.42 battery is 35.0
# at time 23.0 agent transacts 0, price is 43.16 battery is 35.0
# at time 24.0 agent transacts 0, price is 42.63 battery is 35.0
# at time 1.0 agent transacts 0, price is 37.71 battery is 35.0
# at time 2.0 agent transacts 0, price is 34.15 battery is 35.0
# at time 3.0 agent transacts 0, price is 31.0 battery is 35.0
# at time 4.0 agent transacts 0, price is 27.0 battery is 35.0
# at time 5.0 agent transacts 0, price is 27.97 battery is 35.0
# at time 6.0 agent transacts 0, price is 33.0 battery is 35.0
# at time 7.0 agent transacts 0, price is 43.45 battery is 35.0
# at time 8.0 agent transacts 0, price is 53.6 battery is 35.0
# at time 9.0 agent transacts 0, price is 57.11 battery is 35.0
# at time 10.0 agent transacts 0, price is 61.0 battery is 35.0
# at time 11.0 agent transacts 0, price is 62.7 battery is 35.0
# at time 12.0 agent transacts 0, price is 62.7 battery is 35.0
# at time 13.0 agent transacts 0, price is 59.04 battery is 35.0
# at time 14.0 agent transacts 0, price is 60.04 battery is 35.0
# at time 15.0 agent transacts 0, price is 55.58 battery is 35.0
# at time 16.0 agent transacts 0, price is 50.66 battery is 35.0
# at time 17.0 agent transacts 0, price is 51.0 battery is 35.0
# at time 18.0 agent transacts 0, price is 60.67 battery is 35.0
# at time 19.0 agent transacts 0, price is 58.85 battery is 35.0
# at time 20.0 agent transacts 0, price is 50.0 battery is 35.0
# at time 21.0 agent transacts 0, price is 49.9 battery is 35.0
# at time 22.0 agent transacts 0, price is 44.37 battery is 35.0
# at time 23.0 agent transacts 0, price is 42.89 battery is 35.0
# at time 24.0 agent transacts 0, price is 39.84 battery is 35.0
# at time 1.0 agent transacts 0, price is 41.91 battery is 35.0
# at time 2.0 agent transacts 0, price is 40.0 battery is 35.0
# at time 3.0 agent transacts 0, price is 36.25 battery is 35.0
# at time 4.0 agent transacts 0, price is 31.08 battery is 35.0
# at time 5.0 agent transacts 0, price is 30.0 battery is 35.0
# at time 6.0 agent transacts 0, price is 37.01 battery is 35.0
# at time 7.0 agent transacts 0, price is 44.11 battery is 35.0
# at time 8.0 agent transacts 0, price is 56.3 battery is 35.0
# at time 9.0 agent transacts 0, price is 60.61 battery is 35.0
# at time 10.0 agent transacts 0, price is 62.38 battery is 35.0
# at time 11.0 agent transacts 0, price is 63.34 battery is 35.0
# at time 12.0 agent transacts 0, price is 63.0 battery is 35.0
# at time 13.0 agent transacts 0, price is 62.2 battery is 35.0
# at time 14.0 agent transacts 0, price is 60.66 battery is 35.0
# at time 15.0 agent transacts 0, price is 58.35 battery is 35.0
# at time 16.0 agent transacts 0, price is 54.94 battery is 35.0
# at time 17.0 agent transacts 0, price is 55.0 battery is 35.0
# at time 18.0 agent transacts 0, price is 66.19 battery is 35.0
# at time 19.0 agent transacts 0, price is 70.18 battery is 35.0
# at time 20.0 agent transacts 0, price is 61.07 battery is 35.0
# at time 21.0 agent transacts 0, price is 50.77 battery is 35.0
# at time 22.0 agent transacts 0, price is 46.72 battery is 35.0
# at time 23.0 agent transacts 0, price is 46.1 battery is 35.0
# at time 24.0 agent transacts 0, price is 45.68 battery is 35.0
# at time 1.0 agent transacts 0, price is 49.89 battery is 35.0
# at time 2.0 agent transacts 0, price is 46.03 battery is 35.0
# at time 3.0 agent transacts 0, price is 43.02 battery is 35.0
# at time 4.0 agent transacts 0, price is 35.94 battery is 35.0
# at time 5.0 agent transacts 0, price is 33.5 battery is 35.0
# at time 6.0 agent transacts 0, price is 34.81 battery is 35.0
# at time 7.0 agent transacts 0, price is 46.7 battery is 35.0
# at time 8.0 agent transacts 0, price is 60.97 battery is 35.0
# at time 9.0 agent transacts 0, price is 66.51 battery is 35.0
# at time 10.0 agent transacts 0, price is 79.08 battery is 35.0
# at time 11.0 agent transacts 0, price is 72.67 battery is 35.0
# at time 12.0 agent transacts 0, price is 65.5 battery is 35.0
# at time 13.0 agent transacts 0, price is 66.18 battery is 35.0
# at time 14.0 agent transacts 0, price is 62.92 battery is 35.0
# at time 15.0 agent transacts 0, price is 59.22 battery is 35.0
# at time 16.0 agent transacts 0, price is 51.1 battery is 35.0
# at time 17.0 agent transacts 0, price is 47.86 battery is 35.0
# at time 18.0 agent transacts 0, price is 52.0 battery is 35.0
# at time 19.0 agent transacts 0, price is 52.0 battery is 35.0
# at time 20.0 agent transacts 0, price is 44.93 battery is 35.0
# at time 21.0 agent transacts 0, price is 38.0 battery is 35.0
# at time 22.0 agent transacts 0, price is 33.98 battery is 35.0
# at time 23.0 agent transacts 0, price is 44.1 battery is 35.0
# at time 24.0 agent transacts 0, price is 45.52 battery is 35.0
# at time 1.0 agent transacts 0, price is 43.86 battery is 35.0
# at time 2.0 agent transacts 0, price is 44.77 battery is 35.0
# at time 3.0 agent transacts 0, price is 43.04 battery is 35.0
# at time 4.0 agent transacts 0, price is 35.21 battery is 35.0
# at time 5.0 agent transacts 0, price is 34.5 battery is 35.0
# at time 6.0 agent transacts 0, price is 43.15 battery is 35.0
# at time 7.0 agent transacts 0, price is 56.18 battery is 35.0
# at time 8.0 agent transacts 0, price is 65.99 battery is 35.0
# at time 9.0 agent transacts 0, price is 63.2 battery is 35.0
# at time 10.0 agent transacts 0, price is 63.07 battery is 35.0
# at time 11.0 agent transacts 0, price is 61.26 battery is 35.0
# at time 12.0 agent transacts 0, price is 61.34 battery is 35.0
# at time 13.0 agent transacts 0, price is 56.19 battery is 35.0
# at time 14.0 agent transacts 0, price is 55.0 battery is 35.0
# at time 15.0 agent transacts 0, price is 54.55 battery is 35.0
# at time 16.0 agent transacts 0, price is 51.92 battery is 35.0
# at time 17.0 agent transacts 0, price is 51.67 battery is 35.0
# at time 18.0 agent transacts 0, price is 53.43 battery is 35.0
# at time 19.0 agent transacts 0, price is 76.86 battery is 35.0
# at time 20.0 agent transacts 0, price is 51.0 battery is 35.0
# at time 21.0 agent transacts 0, price is 47.0 battery is 35.0
# at time 22.0 agent transacts 0, price is 41.5 battery is 35.0
# at time 23.0 agent transacts 0, price is 47.17 battery is 35.0
# at time 24.0 agent transacts 0, price is 47.02 battery is 35.0
# at time 1.0 agent transacts 0, price is 50.14 battery is 35.0
# at time 2.0 agent transacts 0, price is 46.32 battery is 35.0
# at time 3.0 agent transacts 0, price is 35.0 battery is 35.0
# at time 4.0 agent transacts 0, price is 32.0 battery is 35.0
# at time 5.0 agent transacts 0, price is 31.5 battery is 35.0
# at time 6.0 agent transacts 0, price is 35.27 battery is 35.0
# at time 7.0 agent transacts 0, price is 60.11 battery is 35.0
# at time 8.0 agent transacts 0, price is 66.26 battery is 35.0
# at time 19.0 agent transacts 0, price is 58.5 battery is 15.0
# at time 20.0 agent transacts 0, price is 55.0 battery is 15.0
# at time 21.0 agent transacts 0, price is 48.94 battery is 15.0
# at time 22.0 agent transacts 0, price is 42.0 battery is 15.0
# at time 23.0 agent transacts 0, price is 59.5 battery is 15.0
# at time 24.0 agent transacts 0, price is 58.96 battery is 15.0
# at time 1.0 agent transacts 0, price is 46.61 battery is 15.0
# at time 2.0 agent transacts 0, price is 46.33 battery is 15.0
# at time 3.0 agent transacts 0, price is 30.0 battery is 15.0
# at time 4.0 agent transacts 0, price is 28.0 battery is 15.0
# at time 5.0 agent transacts 12.5, price is 27.92 battery is 15.0
# at time 6.0 agent transacts 0, price is 29.0 battery is 27.5
# at time 7.0 agent transacts 0, price is 29.34 battery is 27.5
# at time 8.0 agent transacts 0, price is 33.5 battery is 27.5
# at time 9.0 agent transacts 0, price is 36.0 battery is 27.5
# at time 10.0 agent transacts 0, price is 43.56 battery is 27.5
# at time 11.0 agent transacts 0, price is 47.67 battery is 27.5
# at time 12.0 agent transacts 0, price is 50.1 battery is 27.5
# at time 13.0 agent transacts 0, price is 48.39 battery is 27.5
# at time 14.0 agent transacts 0, price is 44.0 battery is 27.5
# at time 15.0 agent transacts 0, price is 41.04 battery is 27.5
# at time 16.0 agent transacts 0, price is 42.0 battery is 27.5
# at time 17.0 agent transacts 0, price is 44.36 battery is 27.5
# at time 18.0 agent transacts 0, price is 49.93 battery is 27.5
# at time 19.0 agent transacts 0, price is 57.0 battery is 27.5
# at time 20.0 agent transacts 0, price is 50.0 battery is 27.5
# at time 21.0 agent transacts 0, price is 46.69 battery is 27.5
# at time 22.0 agent transacts 0, price is 41.26 battery is 27.5
# at time 23.0 agent transacts 0, price is 43.5 battery is 27.5
# at time 24.0 agent transacts 0, price is 42.97 battery is 27.5
# at time 1.0 agent transacts 0, price is 55.77 battery is 27.5
# at time 2.0 agent transacts 0, price is 55.11 battery is 27.5
# at time 3.0 agent transacts 0, price is 32.0 battery is 27.5
# at time 4.0 agent transacts 0, price is 28.72 battery is 27.5
# at time 5.0 agent transacts 0, price is 26.29 battery is 27.5
# at time 6.0 agent transacts 0, price is 23.04 battery is 27.5
# at time 7.0 agent transacts 0, price is 16.04 battery is 27.5
# at time 8.0 agent transacts 0, price is 18.44 battery is 27.5
# at time 9.0 agent transacts 0, price is 25.59 battery is 27.5
# at time 10.0 agent transacts 0, price is 32.17 battery is 27.5
# at time 11.0 agent transacts 0, price is 37.0 battery is 27.5
# at time 12.0 agent transacts 0, price is 42.5 battery is 27.5
# at time 13.0 agent transacts 0, price is 43.75 battery is 27.5
# at time 14.0 agent transacts 0, price is 38.99 battery is 27.5
# at time 15.0 agent transacts 0, price is 34.2 battery is 27.5
# at time 16.0 agent transacts 0, price is 31.97 battery is 27.5
# at time 17.0 agent transacts 0, price is 34.93 battery is 27.5
# at time 18.0 agent transacts 0, price is 48.36 battery is 27.5
# at time 19.0 agent transacts 0, price is 55.0 battery is 27.5
# at time 20.0 agent transacts 0, price is 50.0 battery is 27.5
# at time 21.0 agent transacts 0, price is 45.0 battery is 27.5
# at time 22.0 agent transacts 0, price is 41.28 battery is 27.5
# at time 23.0 agent transacts 0, price is 43.67 battery is 27.5
# at time 24.0 agent transacts 0, price is 51.75 battery is 27.5
# at time 1.0 agent transacts 0, price is 36.5 battery is 27.5
# at time 2.0 agent transacts 0, price is 34.0 battery is 27.5
# at time 3.0 agent transacts 0, price is 30.65 battery is 27.5
# at time 4.0 agent transacts 0, price is 29.93 battery is 27.5
# at time 5.0 agent transacts 0, price is 27.8 battery is 27.5
# at time 6.0 agent transacts 0, price is 31.0 battery is 27.5
# at time 7.0 agent transacts 0, price is 69.57 battery is 27.5
# at time 8.0 agent transacts 0, price is 74.23 battery is 27.5
# at time 9.0 agent transacts 0, price is 63.54 battery is 27.5
# at time 10.0 agent transacts 0, price is 65.0 battery is 27.5
# at time 11.0 agent transacts 0, price is 65.0 battery is 27.5
# at time 12.0 agent transacts 0, price is 69.0 battery is 27.5
# at time 13.0 agent transacts 0, price is 65.25 battery is 27.5
# at time 14.0 agent transacts 0, price is 64.43 battery is 27.5
# at time 15.0 agent transacts 0, price is 62.33 battery is 27.5
# at time 16.0 agent transacts 0, price is 55.92 battery is 27.5
# at time 17.0 agent transacts 0, price is 56.5 battery is 27.5
# at time 18.0 agent transacts 0, price is 71.53 battery is 27.5
# at time 19.0 agent transacts 0, price is 109.72 battery is 27.5
# at time 20.0 agent transacts 0, price is 91.01 battery is 27.5
# at time 21.0 agent transacts 0, price is 50.5 battery is 27.5
# at time 22.0 agent transacts 0, price is 43.05 battery is 27.5
# at time 23.0 agent transacts 0, price is 56.29 battery is 27.5
# at time 24.0 agent transacts 0, price is 56.96 battery is 27.5
# at time 1.0 agent transacts 0, price is 39.33 battery is 27.5
# at time 2.0 agent transacts 0, price is 40.75 battery is 27.5
# at time 3.0 agent transacts 0, price is 31.5 battery is 27.5
# at time 4.0 agent transacts 0, price is 29.0 battery is 27.5
# at time 5.0 agent transacts 0, price is 28.0 battery is 27.5
# at time 6.0 agent transacts 0, price is 30.5 battery is 27.5
# at time 7.0 agent transacts 0, price is 53.03 battery is 27.5
# at time 8.0 agent transacts 0, price is 65.99 battery is 27.5
# at time 19.0 agent transacts 0, price is 75.18 battery is 7.5
# at time 20.0 agent transacts 0, price is 66.01 battery is 7.5
# at time 21.0 agent transacts 0, price is 56.0 battery is 7.5
# at time 22.0 agent transacts 0, price is 35.53 battery is 7.5
# at time 23.0 agent transacts 0, price is 48.59 battery is 7.5
# at time 24.0 agent transacts 0, price is 45.17 battery is 7.5
# at time 1.0 agent transacts 0, price is 39.85 battery is 7.5
# at time 2.0 agent transacts 0, price is 42.29 battery is 7.5
# at time 3.0 agent transacts 0, price is 30.0 battery is 7.5
# at time 4.0 agent transacts 0, price is 27.06 battery is 7.5
# at time 5.0 agent transacts 25, price is 24.38 battery is 7.5
# at time 6.0 agent transacts 0, price is 30.0 battery is 32.5
# at time 7.0 agent transacts 0, price is 47.02 battery is 32.5
# at time 8.0 agent transacts 0, price is 58.99 battery is 32.5
# at time 9.0 agent transacts 0, price is 57.0 battery is 32.5
# at time 10.0 agent transacts 0, price is 57.96 battery is 32.5
# at time 11.0 agent transacts 0, price is 59.83 battery is 32.5
# at time 12.0 agent transacts 0, price is 61.99 battery is 32.5
# at time 13.0 agent transacts 0, price is 60.21 battery is 32.5
# at time 14.0 agent transacts 0, price is 60.62 battery is 32.5
# at time 15.0 agent transacts 0, price is 54.2 battery is 32.5
# at time 16.0 agent transacts 0, price is 50.01 battery is 32.5
# at time 17.0 agent transacts 0, price is 47.14 battery is 32.5
# at time 18.0 agent transacts 0, price is 54.5 battery is 32.5
# at time 19.0 agent transacts 0, price is 80.25 battery is 32.5
# at time 20.0 agent transacts 0, price is 59.11 battery is 32.5
# at time 21.0 agent transacts 0, price is 49.93 battery is 32.5
# at time 22.0 agent transacts 0, price is 45.88 battery is 32.5
# at time 23.0 agent transacts 0, price is 45.09 battery is 32.5
# at time 24.0 agent transacts 0, price is 42.0 battery is 32.5
# at time 1.0 agent transacts 0, price is 39.76 battery is 32.5
# at time 2.0 agent transacts 0, price is 41.02 battery is 32.5
# at time 3.0 agent transacts 0, price is 33.5 battery is 32.5
# at time 4.0 agent transacts 0, price is 29.93 battery is 32.5
# at time 5.0 agent transacts 0, price is 30.0 battery is 32.5
# at time 6.0 agent transacts 0, price is 36.0 battery is 32.5
# at time 7.0 agent transacts 0, price is 44.74 battery is 32.5
# at time 8.0 agent transacts 0, price is 56.91 battery is 32.5
# at time 9.0 agent transacts 0, price is 57.95 battery is 32.5
# at time 10.0 agent transacts 0, price is 59.25 battery is 32.5
# at time 11.0 agent transacts 0, price is 58.92 battery is 32.5
# at time 12.0 agent transacts 0, price is 59.3 battery is 32.5
# at time 13.0 agent transacts 0, price is 56.88 battery is 32.5
# at time 14.0 agent transacts 0, price is 56.34 battery is 32.5
# at time 15.0 agent transacts 0, price is 54.0 battery is 32.5
# at time 16.0 agent transacts 0, price is 51.0 battery is 32.5
# at time 17.0 agent transacts 0, price is 49.99 battery is 32.5
# at time 18.0 agent transacts 0, price is 58.0 battery is 32.5
# at time 19.0 agent transacts 0, price is 70.68 battery is 32.5
# at time 20.0 agent transacts 0, price is 59.74 battery is 32.5
# at time 21.0 agent transacts 0, price is 51.24 battery is 32.5
# at time 22.0 agent transacts 0, price is 43.61 battery is 32.5
# at time 23.0 agent transacts 0, price is 44.0 battery is 32.5
# at time 24.0 agent transacts 0, price is 39.22 battery is 32.5
# at time 1.0 agent transacts 0, price is 36.93 battery is 32.5
# at time 2.0 agent transacts 0, price is 34.19 battery is 32.5
# at time 3.0 agent transacts 0, price is 32.34 battery is 32.5
# at time 4.0 agent transacts 0, price is 29.03 battery is 32.5
# at time 5.0 agent transacts 0, price is 28.17 battery is 32.5
# at time 6.0 agent transacts 0, price is 32.58 battery is 32.5
# at time 7.0 agent transacts 0, price is 38.97 battery is 32.5
# at time 8.0 agent transacts 0, price is 50.5 battery is 32.5
# at time 9.0 agent transacts 0, price is 50.75 battery is 32.5
# at time 10.0 agent transacts 0, price is 52.0 battery is 32.5
# at time 11.0 agent transacts 0, price is 52.68 battery is 32.5
# at time 12.0 agent transacts 0, price is 53.0 battery is 32.5
# at time 13.0 agent transacts 0, price is 52.4 battery is 32.5
# at time 14.0 agent transacts 0, price is 49.19 battery is 32.5
# at time 15.0 agent transacts 0, price is 45.06 battery is 32.5
# at time 16.0 agent transacts 0, price is 41.0 battery is 32.5
# at time 17.0 agent transacts 0, price is 40.83 battery is 32.5
# at time 18.0 agent transacts 0, price is 47.0 battery is 32.5
# at time 19.0 agent transacts 0, price is 57.1 battery is 32.5
# at time 20.0 agent transacts 0, price is 53.06 battery is 32.5
# at time 21.0 agent transacts 0, price is 46.43 battery is 32.5
# at time 22.0 agent transacts 0, price is 39.91 battery is 32.5
# at time 23.0 agent transacts 0, price is 42.07 battery is 32.5
# at time 24.0 agent transacts 0, price is 41.27 battery is 32.5
# at time 1.0 agent transacts 0, price is 40.0 battery is 32.5
# at time 2.0 agent transacts 0, price is 37.93 battery is 32.5
# at time 3.0 agent transacts 0, price is 34.0 battery is 32.5
# at time 4.0 agent transacts 0, price is 29.9 battery is 32.5
# at time 5.0 agent transacts 0, price is 27.82 battery is 32.5
# at time 6.0 agent transacts 0, price is 28.01 battery is 32.5
# at time 7.0 agent transacts 0, price is 26.1 battery is 32.5
# at time 8.0 agent transacts 0, price is 31.12 battery is 32.5
# at time 9.0 agent transacts 0, price is 36.98 battery is 32.5
# at time 10.0 agent transacts 0, price is 42.27 battery is 32.5
# at time 11.0 agent transacts 0, price is 44.0 battery is 32.5
# at time 12.0 agent transacts 0, price is 46.5 battery is 32.5
# at time 13.0 agent transacts 0, price is 47.01 battery is 32.5
# at time 14.0 agent transacts 0, price is 44.12 battery is 32.5
# at time 15.0 agent transacts 0, price is 39.8 battery is 32.5
# at time 16.0 agent transacts 0, price is 38.99 battery is 32.5
# at time 17.0 agent transacts 0, price is 39.96 battery is 32.5
# at time 18.0 agent transacts 0, price is 43.77 battery is 32.5
# at time 19.0 agent transacts 0, price is 56.28 battery is 32.5
# at time 20.0 agent transacts 0, price is 53.35 battery is 32.5
# at time 21.0 agent transacts 0, price is 43.95 battery is 32.5
# at time 22.0 agent transacts 0, price is 40.09 battery is 32.5
# at time 23.0 agent transacts 0, price is 42.09 battery is 32.5
# at time 24.0 agent transacts 0, price is 40.89 battery is 32.5
# at time 1.0 agent transacts 0, price is 40.94 battery is 32.5
# at time 2.0 agent transacts 0, price is 39.41 battery is 32.5
# at time 3.0 agent transacts 0, price is 35.89 battery is 32.5
# at time 4.0 agent transacts 0, price is 30.65 battery is 32.5
# at time 5.0 agent transacts 0, price is 27.82 battery is 32.5
# at time 6.0 agent transacts 0, price is 26.28 battery is 32.5
# at time 7.0 agent transacts 0, price is 23.98 battery is 32.5
# at time 8.0 agent transacts 0, price is 27.65 battery is 32.5
# at time 19.0 agent transacts 0, price is 50.06 battery is 12.5
# at time 20.0 agent transacts 0, price is 51.48 battery is 12.5
# at time 21.0 agent transacts 0, price is 47.75 battery is 12.5
# at time 22.0 agent transacts 0, price is 44.3 battery is 12.5
# at time 23.0 agent transacts 0, price is 44.4 battery is 12.5
# at time 24.0 agent transacts 0, price is 40.8 battery is 12.5
# at time 1.0 agent transacts 0, price is 37.25 battery is 12.5
# at time 2.0 agent transacts 0, price is 36.46 battery is 12.5
# at time 3.0 agent transacts 0, price is 37.39 battery is 12.5
# at time 4.0 agent transacts 0, price is 30.0 battery is 12.5
# at time 5.0 agent transacts 12.5, price is 29.73 battery is 12.5
# at time 6.0 agent transacts 0, price is 33.0 battery is 25.0
# at time 7.0 agent transacts 0, price is 54.0 battery is 25.0
# at time 8.0 agent transacts 0, price is 63.62 battery is 25.0
# at time 9.0 agent transacts 0, price is 64.9 battery is 25.0
# ...
# at time 6.0 agent transacts 0, price is 38.17 battery is 34.722222222222214
# at time 7.0 agent transacts 0, price is 42.85 battery is 34.722222222222214
# at time 8.0 agent transacts 0, price is 49.08 battery is 34.722222222222214
# at time 9.0 agent transacts 0, price is 53.22 battery is 34.722222222222214
# at time 10.0 agent transacts 0, price is 54.42 battery is 34.722222222222214
# at time 11.0 agent transacts 0, price is 53.27 battery is 34.722222222222214
# at time 12.0 agent transacts 0, price is 55.5 battery is 34.722222222222214
# at time 13.0 agent transacts 0, price is 56.4 battery is 34.722222222222214
# at time 14.0 agent transacts 0, price is 54.91 battery is 34.722222222222214
# at time 15.0 agent transacts 0, price is 54.49 battery is 34.722222222222214
# at time 16.0 agent transacts 0, price is 54.45 battery is 34.722222222222214
# at time 17.0 agent transacts 0, price is 55.46 battery is 34.722222222222214
# at time 18.0 agent transacts 0, price is 62.4 battery is 34.722222222222214
# at time 19.0 agent transacts 0, price is 62.96 battery is 34.722222222222214
# at time 20.0 agent transacts 0, price is 58.96 battery is 34.722222222222214
# at time 21.0 agent transacts 0, price is 54.91 battery is 34.722222222222214
# at time 22.0 agent transacts 0, price is 49.59 battery is 34.722222222222214
# at time 23.0 agent transacts 0, price is 48.0 battery is 34.722222222222214
# at time 24.0 agent transacts 0, price is 46.36 battery is 34.722222222222214
# at time 1.0 agent transacts 0, price is 42.87 battery is 34.722222222222214
# at time 2.0 agent transacts 0, price is 39.94 battery is 34.722222222222214
# at time 3.0 agent transacts 0, price is 36.98 battery is 34.722222222222214
# at time 4.0 agent transacts 0, price is 32.73 battery is 34.722222222222214
# at time 5.0 agent transacts 0, price is 30.16 battery is 34.722222222222214
# at time 6.0 agent transacts 0, price is 37.62 battery is 34.722222222222214
# at time 7.0 agent transacts 0, price is 42.66 battery is 34.722222222222214
# at time 8.0 agent transacts 0, price is 47.58 battery is 34.722222222222214
# at time 9.0 agent transacts 0, price is 55.81 battery is 34.722222222222214
# at time 10.0 agent transacts 0, price is 56.08 battery is 34.722222222222214
# at time 11.0 agent transacts 0, price is 57.44 battery is 34.722222222222214
# at time 12.0 agent transacts 0, price is 56.35 battery is 34.722222222222214
# at time 13.0 agent transacts 0, price is 54.48 battery is 34.722222222222214
# at time 14.0 agent transacts 0, price is 55.14 battery is 34.722222222222214
# at time 15.0 agent transacts 0, price is 53.91 battery is 34.722222222222214
# at time 16.0 agent transacts 0, price is 51.22 battery is 34.722222222222214
# at time 17.0 agent transacts 0, price is 49.9 battery is 34.722222222222214
# at time 18.0 agent transacts 0, price is 58.74 battery is 34.722222222222214
# at time 19.0 agent transacts 0, price is 61.19 battery is 34.722222222222214
# at time 20.0 agent transacts 0, price is 59.06 battery is 34.722222222222214
# at time 21.0 agent transacts 0, price is 53.2 battery is 34.722222222222214
# at time 22.0 agent transacts 0, price is 49.5 battery is 34.722222222222214
# at time 23.0 agent transacts 0, price is 47.5 battery is 34.722222222222214
# at time 24.0 agent transacts 0, price is 43.07 battery is 34.722222222222214
# at time 1.0 agent transacts 0, price is 41.85 battery is 34.722222222222214
# at time 2.0 agent transacts 0, price is 40.46 battery is 34.722222222222214
# at time 3.0 agent transacts 0, price is 37.75 battery is 34.722222222222214
# at time 4.0 agent transacts 0, price is 35.13 battery is 34.722222222222214
# at time 5.0 agent transacts 0, price is 34.03 battery is 34.722222222222214
# at time 6.0 agent transacts 0, price is 37.44 battery is 34.722222222222214
# at time 7.0 agent transacts 0, price is 42.74 battery is 34.722222222222214
# at time 8.0 agent transacts 0, price is 49.63 battery is 34.722222222222214
# at time 19.0 agent transacts 0, price is 54.18 battery is 14.722222222222214
# at time 20.0 agent transacts 0, price is 53.19 battery is 14.722222222222214
# at time 21.0 agent transacts 0, price is 49.83 battery is 14.722222222222214
# at time 22.0 agent transacts 0, price is 44.0 battery is 14.722222222222214
# at time 23.0 agent transacts 0, price is 45.1 battery is 14.722222222222214
# at time 24.0 agent transacts 0, price is 41.6 battery is 14.722222222222214
# at time 1.0 agent transacts 0, price is 24.3 battery is 14.722222222222214
# at time 2.0 agent transacts 0, price is 19.14 battery is 14.722222222222214
# at time 3.0 agent transacts 0, price is 17.16 battery is 14.722222222222214
# at time 4.0 agent transacts 0, price is 12.96 battery is 14.722222222222214
# at time 5.0 agent transacts 12.5, price is 11.34 battery is 14.722222222222214
# at time 6.0 agent transacts 0, price is 12.23 battery is 27.222222222222214
# at time 7.0 agent transacts 0, price is 12.91 battery is 27.222222222222214
# at time 8.0 agent transacts 0, price is 18.37 battery is 27.222222222222214
# at time 9.0 agent transacts 0, price is 26.73 battery is 27.222222222222214
# at time 10.0 agent transacts 0, price is 32.11 battery is 27.222222222222214
# at time 11.0 agent transacts 0, price is 33.9 battery is 27.222222222222214
# at time 12.0 agent transacts 0, price is 35.88 battery is 27.222222222222214
# at time 13.0 agent transacts 0, price is 35.44 battery is 27.222222222222214
# at time 14.0 agent transacts 0, price is 33.08 battery is 27.222222222222214
# at time 15.0 agent transacts 0, price is 31.65 battery is 27.222222222222214
# at time 16.0 agent transacts 0, price is 31.59 battery is 27.222222222222214
# at time 17.0 agent transacts 0, price is 32.92 battery is 27.222222222222214
# at time 18.0 agent transacts 0, price is 42.31 battery is 27.222222222222214
# at time 19.0 agent transacts 0, price is 44.08 battery is 27.222222222222214
# at time 20.0 agent transacts 0, price is 35.31 battery is 27.222222222222214
# at time 21.0 agent transacts 0, price is 32.95 battery is 27.222222222222214
# at time 22.0 agent transacts 0, price is 30.75 battery is 27.222222222222214
# at time 23.0 agent transacts 0, price is 35.88 battery is 27.222222222222214
# at time 24.0 agent transacts 0, price is 31.45 battery is 27.222222222222214
# at time 1.0 agent transacts 0, price is 27.18 battery is 27.222222222222214
# at time 2.0 agent transacts 0, price is 25.08 battery is 27.222222222222214
# at time 3.0 agent transacts 0, price is 20.96 battery is 27.222222222222214
# at time 4.0 agent transacts 0, price is 15.68 battery is 27.222222222222214
# at time 5.0 agent transacts 0, price is 10.85 battery is 27.222222222222214
# at time 6.0 agent transacts 0, price is 10.53 battery is 27.222222222222214
# at time 7.0 agent transacts 0, price is 11.33 battery is 27.222222222222214
# at time 8.0 agent transacts 0, price is 10.89 battery is 27.222222222222214
# at time 19.0 agent transacts 0, price is 34.94 battery is 7.222222222222214
# at time 20.0 agent transacts 0, price is 38.94 battery is 7.222222222222214
# at time 21.0 agent transacts 0, price is 34.85 battery is 7.222222222222214
# at time 22.0 agent transacts 0, price is 31.1 battery is 7.222222222222214
# at time 23.0 agent transacts 0, price is 33.29 battery is 7.222222222222214
# at time 24.0 agent transacts 0, price is 32.86 battery is 7.222222222222214
# at time 1.0 agent transacts 0, price is 30.06 battery is 7.222222222222214
# at time 2.0 agent transacts 0, price is 27.96 battery is 7.222222222222214
# at time 3.0 agent transacts 0, price is 21.51 battery is 7.222222222222214
# at time 4.0 agent transacts 25, price is 13.22 battery is 7.222222222222214
# at time 5.0 agent transacts 0, price is 10.51 battery is 32.222222222222214
# at time 6.0 agent transacts 0, price is 17.72 battery is 32.222222222222214
# at time 7.0 agent transacts 0, price is 28.96 battery is 32.222222222222214
# at time 8.0 agent transacts 0, price is 35.6 battery is 32.222222222222214
# at time 19.0 agent transacts 0, price is 58.5 battery is 12.222222222222214
# at time 20.0 agent transacts 0, price is 56.19 battery is 12.222222222222214
# at time 21.0 agent transacts 0, price is 50.76 battery is 12.222222222222214
# at time 22.0 agent transacts 0, price is 44.74 battery is 12.222222222222214
# at time 23.0 agent transacts 0, price is 46.92 battery is 12.222222222222214
# at time 24.0 agent transacts 0, price is 42.27 battery is 12.222222222222214
# at time 1.0 agent transacts 0, price is 39.1 battery is 12.222222222222214
# at time 2.0 agent transacts 0, price is 34.08 battery is 12.222222222222214
# at time 3.0 agent transacts 0, price is 29.13 battery is 12.222222222222214
# at time 4.0 agent transacts 0, price is 18.37 battery is 12.222222222222214
# at time 5.0 agent transacts 12.5, price is 17.81 battery is 12.222222222222214
# at time 6.0 agent transacts 0, price is 30.41 battery is 24.722222222222214
# at time 7.0 agent transacts 0, price is 33.69 battery is 24.722222222222214
# at time 8.0 agent transacts 0, price is 39.91 battery is 24.722222222222214
# at time 19.0 agent transacts 0, price is 68.61 battery is 4.722222222222214
# at time 20.0 agent transacts 0, price is 64.2 battery is 4.722222222222214
# at time 21.0 agent transacts 0, price is 53.91 battery is 4.722222222222214
# at time 22.0 agent transacts 0, price is 46.25 battery is 4.722222222222214
# at time 23.0 agent transacts 0, price is 49.35 battery is 4.722222222222214
# at time 24.0 agent transacts 0, price is 48.02 battery is 4.722222222222214
# at time 1.0 agent transacts 0, price is 44.25 battery is 4.722222222222214
# at time 2.0 agent transacts 0, price is 39.99 battery is 4.722222222222214
# at time 3.0 agent transacts 0, price is 37.6 battery is 4.722222222222214
# at time 4.0 agent transacts 0, price is 34.21 battery is 4.722222222222214
# at time 5.0 agent transacts 25, price is 30.42 battery is 4.722222222222214
# at time 6.0 agent transacts 0, price is 37.0 battery is 29.722222222222214
# at time 7.0 agent transacts 0, price is 40.56 battery is 29.722222222222214
# at time 8.0 agent transacts 0, price is 46.13 battery is 29.722222222222214
# at time 9.0 agent transacts 0, price is 47.86 battery is 29.722222222222214
# at time 10.0 agent transacts 0, price is 47.63 battery is 29.722222222222214
# at time 11.0 agent transacts 0, price is 49.29 battery is 29.722222222222214
# at time 12.0 agent transacts 0, price is 48.85 battery is 29.722222222222214
# at time 13.0 agent transacts 0, price is 50.27 battery is 29.722222222222214
# at time 14.0 agent transacts 0, price is 46.89 battery is 29.722222222222214
# at time 15.0 agent transacts 0, price is 43.98 battery is 29.722222222222214
# at time 16.0 agent transacts 0, price is 43.2 battery is 29.722222222222214
# at time 17.0 agent transacts 0, price is 48.97 battery is 29.722222222222214
# at time 18.0 agent transacts 0, price is 53.96 battery is 29.722222222222214
# at time 19.0 agent transacts 0, price is 56.2 battery is 29.722222222222214
# at time 20.0 agent transacts 0, price is 52.12 battery is 29.722222222222214
# at time 21.0 agent transacts 0, price is 49.0 battery is 29.722222222222214
# at time 22.0 agent transacts 0, price is 41.81 battery is 29.722222222222214
# at time 23.0 agent transacts 0, price is 39.79 battery is 29.722222222222214
# at time 24.0 agent transacts 0, price is 38.25 battery is 29.722222222222214
# at time 1.0 agent transacts 0, price is 34.49 battery is 29.722222222222214
# at time 2.0 agent transacts 0, price is 35.79 battery is 29.722222222222214
# at time 3.0 agent transacts 0, price is 20.7 battery is 29.722222222222214
# at time 4.0 agent transacts 0, price is 12.18 battery is 29.722222222222214
# at time 5.0 agent transacts 0, price is 12.47 battery is 29.722222222222214
# at time 6.0 agent transacts 0, price is 13.11 battery is 29.722222222222214
# at time 7.0 agent transacts 0, price is 28.98 battery is 29.722222222222214
# at time 8.0 agent transacts 0, price is 40.1 battery is 29.722222222222214
# at time 9.0 agent transacts 0, price is 41.87 battery is 29.722222222222214
# at time 10.0 agent transacts 0, price is 44.94 battery is 29.722222222222214
# at time 11.0 agent transacts 0, price is 46.5 battery is 29.722222222222214
# at time 12.0 agent transacts 0, price is 46.0 battery is 29.722222222222214
# at time 13.0 agent transacts 0, price is 47.43 battery is 29.722222222222214
# at time 14.0 agent transacts 0, price is 46.5 battery is 29.722222222222214
# at time 15.0 agent transacts 0, price is 42.9 battery is 29.722222222222214
# at time 16.0 agent transacts 0, price is 42.42 battery is 29.722222222222214
# at time 17.0 agent transacts 0, price is 45.0 battery is 29.722222222222214
# at time 18.0 agent transacts 0, price is 53.1 battery is 29.722222222222214
# at time 19.0 agent transacts 0, price is 54.93 battery is 29.722222222222214
# at time 20.0 agent transacts 0, price is 49.88 battery is 29.722222222222214
# at time 21.0 agent transacts 0, price is 45.0 battery is 29.722222222222214
# at time 22.0 agent transacts 0, price is 40.27 battery is 29.722222222222214
# at time 23.0 agent transacts 0, price is 43.74 battery is 29.722222222222214
# at time 24.0 agent transacts 0, price is 41.91 battery is 29.722222222222214
# at time 1.0 agent transacts 0, price is 34.91 battery is 29.722222222222214
# at time 2.0 agent transacts 0, price is 33.02 battery is 29.722222222222214
# at time 3.0 agent transacts 0, price is 27.26 battery is 29.722222222222214
# at time 4.0 agent transacts 0, price is 17.7 battery is 29.722222222222214
# at time 5.0 agent transacts 0, price is 18.75 battery is 29.722222222222214
# at time 6.0 agent transacts 0, price is 25.18 battery is 29.722222222222214
# at time 7.0 agent transacts 0, price is 31.0 battery is 29.722222222222214
# at time 8.0 agent transacts 0, price is 38.5 battery is 29.722222222222214
# at time 19.0 agent transacts 0, price is 63.22 battery is 9.722222222222214
# at time 20.0 agent transacts 0, price is 55.76 battery is 9.722222222222214
# at time 21.0 agent transacts 0, price is 50.21 battery is 9.722222222222214
# at time 22.0 agent transacts 0, price is 43.13 battery is 9.722222222222214
# at time 23.0 agent transacts 0, price is 46.62 battery is 9.722222222222214
# at time 24.0 agent transacts 0, price is 41.15 battery is 9.722222222222214
# at time 1.0 agent transacts 0, price is 33.23 battery is 9.722222222222214
# at time 2.0 agent transacts 0, price is 30.78 battery is 9.722222222222214
# at time 3.0 agent transacts 0, price is 28.28 battery is 9.722222222222214
# at time 4.0 agent transacts 0, price is 24.52 battery is 9.722222222222214
# at time 5.0 agent transacts 25, price is 15.9 battery is 9.722222222222214
# at time 6.0 agent transacts 0, price is 20.0 battery is 34.722222222222214
# at time 7.0 agent transacts 0, price is 23.68 battery is 34.722222222222214
# at time 8.0 agent transacts 0, price is 25.04 battery is 34.722222222222214
# at time 9.0 agent transacts 0, price is 25.48 battery is 34.722222222222214
# at time 10.0 agent transacts 0, price is 28.67 battery is 34.722222222222214
# at time 11.0 agent transacts 0, price is 28.5 battery is 34.722222222222214
# at time 12.0 agent transacts 0, price is 30.41 battery is 34.722222222222214
# at time 13.0 agent transacts 0, price is 34.67 battery is 34.722222222222214
# at time 14.0 agent transacts 0, price is 31.76 battery is 34.722222222222214
# at time 15.0 agent transacts 0, price is 29.13 battery is 34.722222222222214
# at time 16.0 agent transacts 0, price is 27.48 battery is 34.722222222222214
# at time 17.0 agent transacts 0, price is 27.72 battery is 34.722222222222214
# at time 18.0 agent transacts 0, price is 33.54 battery is 34.722222222222214
# at time 19.0 agent transacts 0, price is 37.44 battery is 34.722222222222214
# at time 20.0 agent transacts 0, price is 34.56 battery is 34.722222222222214
# at time 21.0 agent transacts 0, price is 28.75 battery is 34.722222222222214
# at time 22.0 agent transacts 0, price is 25.79 battery is 34.722222222222214
# at time 23.0 agent transacts 0, price is 31.1 battery is 34.722222222222214
# Profit on validation set over 5 episodes:  -570.5707111111113

# %% [markdown]
# ## Baseline Random

# %%
class RandomAgent():
    def __init__(self, env, action_space):
        self.env = env
        self.actions = np.linspace(-1 , 1, 5)
        self.action_space = action_space
        self.time_constraint = 8
        self.max_power = 25

    def select_random(self):
        mask = self.mask()
        return np.random.choice(self.actions[mask])

    def mask(self):
        # 7 am constraint  
        if self.env.hour == self.time_constraint and self.env.battery_level >= self.env.minimum_morning_level:
            lower_bound = min(np.ceil((self.env.minimum_morning_level - self.env.battery_level)*0.9), self.max_power)
            upper_bound =  min(np.floor((self.env.battery_capacity - self.env.battery_level)/0.9), self.max_power)
            mask_range = (lower_bound, upper_bound)
        elif self.env.hour == self.time_constraint and self.env.battery_level < self.env.minimum_morning_level:
            lower_bound = min(np.ceil((self.env.minimum_morning_level - self.env.battery_level)/0.9), self.max_power)
            upper_bound =  min(np.floor((self.env.battery_capacity - self.env.battery_level)/0.9), self.max_power)
            mask_range = (lower_bound, upper_bound)
        else: 
            lower_bound = max(np.ceil(-(self.env.battery_level)*0.9), -self.max_power)
            upper_bound = min(np.floor((self.env.battery_capacity - self.env.battery_level)/0.9), self.max_power)
            mask_range = (lower_bound, upper_bound)
                
        # construct boolean mask_vector
        mask = np.arange(self.action_space.start, self.action_space.end + 1, self.action_space.step_size) 
        mask = np.where((mask >= mask_range[0]) & (mask <= mask_range[1]), True, False)
        return mask

    def reset(self):
        # Battery characteristics
        self.env.battery_level = self.env.battery_capacity / 2  # kWh (start at 50%)

        # Time Tracking
        self.env.counter = 0
        self.env.hour = 1
        self.env.day = 1
        self.env.car_is_available = True

# %%
custom_action_space = CustomDiscreteActionSpace()
env = Electric_Car(path_to_test_data='validate.xlsx')
random_agent = RandomAgent(env, custom_action_space)
random_agent.select_random()
all_profits = []

for episode in range(5):
    done = False
    profits = 0
    while not done:
        current_state = random_agent.env.observation()
        battery, price, hour  = current_state[0], current_state[1], current_state[2] 
        action = random_agent.select_random()
        
        if agent.env.car_is_available and episode == 4:
            print(f"at time {hour} agent transacts {action * 25}, price is {price} battery is {battery}")
        next_state, reward, done, trucated, info = random_agent.env.step(action)
        profits += reward

    all_profits.append(profits)
    random_agent.reset()

print("Profit on validation set over 5 epsidoes: ", np.mean(all_profits))
# Out:
# at time 1.0 agent transacts -12.5, price is 13.2 battery is 25.0
# at time 2.0 agent transacts 12.5, price is 13.14 battery is 11.11111111111111
# at time 3.0 agent transacts 25.0, price is 11.83 battery is 23.61111111111111
# at time 4.0 agent transacts -12.5, price is 9.49 battery is 48.611111111111114
# at time 5.0 agent transacts 0.0, price is 8.63 battery is 34.72222222222223
# at time 6.0 agent transacts 12.5, price is 7.12 battery is 34.72222222222223
# at time 7.0 agent transacts -12.5, price is 4.06 battery is 47.22222222222223
# at time 8.0 agent transacts 12.5, price is 1.0 battery is 33.33333333333334
# at time 9.0 agent transacts 25.0, price is 8.4 battery is 25.833333333333343
# at time 10.0 agent transacts 12.5, price is 9.11 battery is 25.833333333333343
# at time 11.0 agent transacts -12.5, price is 10.18 battery is 25.833333333333343
# at time 12.0 agent transacts -12.5, price is 13.56 battery is 25.833333333333343
# at time 13.0 agent transacts 12.5, price is 18.02 battery is 25.833333333333343
# at time 14.0 agent transacts -12.5, price is 15.02 battery is 25.833333333333343
# at time 15.0 agent transacts -12.5, price is 12.58 battery is 25.833333333333343
# at time 16.0 agent transacts 12.5, price is 10.18 battery is 25.833333333333343
# at time 17.0 agent transacts 25.0, price is 9.81 battery is 25.833333333333343
# at time 18.0 agent transacts 25.0, price is 18.79 battery is 25.833333333333343
# at time 19.0 agent transacts 12.5, price is 22.7 battery is 25.833333333333343
# at time 20.0 agent transacts 0.0, price is 30.06 battery is 38.33333333333334
# at time 21.0 agent transacts -12.5, price is 27.3 battery is 38.33333333333334
# at time 22.0 agent transacts 0.0, price is 23.93 battery is 24.444444444444454
# at time 23.0 agent transacts -12.5, price is 33.49 battery is 24.444444444444454
# at time 24.0 agent transacts 0.0, price is 31.06 battery is 10.555555555555564
# at time 1.0 agent transacts 25.0, price is 23.0 battery is 10.555555555555564
# at time 2.0 agent transacts 0.0, price is 17.45 battery is 35.555555555555564
# at time 3.0 agent transacts -12.5, price is 19.12 battery is 35.555555555555564
# at time 4.0 agent transacts -12.5, price is 12.76 battery is 21.666666666666675
# at time 5.0 agent transacts 0.0, price is 10.19 battery is 7.777777777777786
# at time 6.0 agent transacts 12.5, price is 11.99 battery is 7.777777777777786
# at time 7.0 agent transacts 0.0, price is 15.65 battery is 20.277777777777786
# at time 8.0 agent transacts 0.0, price is 23.5 battery is 20.277777777777786
# at time 9.0 agent transacts 25.0, price is 28.9 battery is 0.2777777777777857
# at time 10.0 agent transacts 12.5, price is 37.12 battery is 0.2777777777777857
# at time 11.0 agent transacts 25.0, price is 41.82 battery is 0.2777777777777857
# at time 12.0 agent transacts 12.5, price is 44.69 battery is 0.2777777777777857
# at time 13.0 agent transacts 12.5, price is 47.0 battery is 0.2777777777777857
# at time 14.0 agent transacts 25.0, price is 41.15 battery is 0.2777777777777857
# at time 15.0 agent transacts 12.5, price is 39.25 battery is 0.2777777777777857
# at time 16.0 agent transacts 12.5, price is 34.95 battery is 0.2777777777777857
# at time 17.0 agent transacts 25.0, price is 37.26 battery is 0.2777777777777857
# at time 18.0 agent transacts 25.0, price is 46.84 battery is 0.2777777777777857
# at time 19.0 agent transacts 12.5, price is 56.49 battery is 0.2777777777777857
# at time 20.0 agent transacts 12.5, price is 56.05 battery is 12.777777777777786
# at time 21.0 agent transacts 0.0, price is 45.5 battery is 25.277777777777786
# at time 22.0 agent transacts 12.5, price is 39.32 battery is 25.277777777777786
# at time 23.0 agent transacts 0.0, price is 43.0 battery is 37.777777777777786
# at time 24.0 agent transacts 12.5, price is 41.07 battery is 37.777777777777786
# at time 1.0 agent transacts -25.0, price is 39.44 battery is 50.0
# at time 2.0 agent transacts 25.0, price is 31.98 battery is 22.22222222222222
# at time 3.0 agent transacts -25.0, price is 30.0 battery is 47.22222222222222
# at time 4.0 agent transacts 25.0, price is 27.07 battery is 19.444444444444443
# at time 5.0 agent transacts -25.0, price is 19.18 battery is 44.44444444444444
# at time 6.0 agent transacts 25.0, price is 17.51 battery is 16.666666666666664
# at time 7.0 agent transacts 0.0, price is 17.03 battery is 41.666666666666664
# at time 8.0 agent transacts 0.0, price is 21.0 battery is 41.666666666666664
# at time 9.0 agent transacts -12.5, price is 28.23 battery is 41.666666666666664
# at time 10.0 agent transacts 12.5, price is 35.01 battery is 27.777777777777775
# at time 11.0 agent transacts -25.0, price is 40.0 battery is 40.27777777777777
# at time 12.0 agent transacts 25.0, price is 44.18 battery is 12.499999999999993
# at time 13.0 agent transacts 0.0, price is 47.21 battery is 37.49999999999999
# at time 14.0 agent transacts 0.0, price is 41.55 battery is 37.49999999999999
# at time 15.0 agent transacts -25.0, price is 36.54 battery is 37.49999999999999
# at time 16.0 agent transacts 12.5, price is 33.2 battery is 9.722222222222214
# at time 17.0 agent transacts 0.0, price is 26.53 battery is 22.222222222222214
# at time 18.0 agent transacts -12.5, price is 44.6 battery is 22.222222222222214
# at time 19.0 agent transacts 0.0, price is 56.85 battery is 8.333333333333325
# at time 20.0 agent transacts 12.5, price is 57.75 battery is 8.333333333333325
# at time 21.0 agent transacts 12.5, price is 49.66 battery is 20.833333333333325
# at time 22.0 agent transacts -25.0, price is 39.67 battery is 33.33333333333333
# at time 23.0 agent transacts 0.0, price is 43.55 battery is 5.55555555555555
# at time 24.0 agent transacts 25.0, price is 39.34 battery is 5.55555555555555
# at time 1.0 agent transacts 12.5, price is 37.15 battery is 30.55555555555555
# at time 2.0 agent transacts 0.0, price is 33.47 battery is 43.05555555555555
# at time 3.0 agent transacts -12.5, price is 28.0 battery is 43.05555555555555
# at time 4.0 agent transacts -25.0, price is 21.29 battery is 29.16666666666666
# at time 5.0 agent transacts 0.0, price is 16.92 battery is 1.3888888888888822
# at time 6.0 agent transacts 0.0, price is 28.0 battery is 1.3888888888888822
# at time 7.0 agent transacts 12.5, price is 36.43 battery is 1.3888888888888822
# at time 8.0 agent transacts 12.5, price is 59.47 battery is 13.888888888888882
# at time 9.0 agent transacts 25.0, price is 59.73 battery is 26.388888888888882
# at time 10.0 agent transacts -25.0, price is 62.1 battery is 50.0
# at time 11.0 agent transacts -12.5, price is 62.74 battery is 22.22222222222222
# at time 12.0 agent transacts 25.0, price is 62.65 battery is 8.333333333333332
# at time 13.0 agent transacts -12.5, price is 62.51 battery is 33.33333333333333
# at time 14.0 agent transacts 0.0, price is 59.92 battery is 19.44444444444444
# at time 15.0 agent transacts 25.0, price is 56.0 battery is 19.44444444444444
# at time 16.0 agent transacts 0.0, price is 49.67 battery is 44.44444444444444
# at time 17.0 agent transacts -12.5, price is 54.4 battery is 44.44444444444444
# at time 18.0 agent transacts 0.0, price is 71.11 battery is 30.555555555555554
# at time 19.0 agent transacts 12.5, price is 78.77 battery is 30.555555555555554
# at time 20.0 agent transacts -12.5, price is 64.46 battery is 43.05555555555556
# at time 21.0 agent transacts -25.0, price is 50.73 battery is 29.166666666666668
# at time 22.0 agent transacts 12.5, price is 43.9 battery is 1.3888888888888893
# at time 23.0 agent transacts 0.0, price is 46.58 battery is 13.88888888888889
# at time 24.0 agent transacts 25.0, price is 43.38 battery is 13.88888888888889
# at time 1.0 agent transacts -25.0, price is 37.9 battery is 38.888888888888886
# at time 2.0 agent transacts 12.5, price is 38.11 battery is 11.111111111111107
# at time 3.0 agent transacts 12.5, price is 29.99 battery is 23.611111111111107
# at time 4.0 agent transacts 12.5, price is 28.91 battery is 36.11111111111111
# at time 5.0 agent transacts -12.5, price is 27.0 battery is 48.61111111111111
# at time 6.0 agent transacts 12.5, price is 29.56 battery is 34.722222222222214
# at time 7.0 agent transacts -25.0, price is 40.94 battery is 47.222222222222214
# at time 8.0 agent transacts 25.0, price is 55.0 battery is 19.444444444444436
# at time 9.0 agent transacts -25.0, price is 55.5 battery is 44.444444444444436
# at time 10.0 agent transacts 0.0, price is 57.1 battery is 16.666666666666657
# at time 11.0 agent transacts 12.5, price is 57.0 battery is 16.666666666666657
# at time 12.0 agent transacts -25.0, price is 58.0 battery is 29.166666666666657
# at time 13.0 agent transacts 0.0, price is 57.0 battery is 1.3888888888888786
# at time 14.0 agent transacts 12.5, price is 56.17 battery is 1.3888888888888786
# at time 15.0 agent transacts 25.0, price is 56.28 battery is 13.888888888888879
# at time 16.0 agent transacts 0.0, price is 53.54 battery is 38.88888888888888
# at time 17.0 agent transacts 0.0, price is 56.19 battery is 38.88888888888888
# at time 18.0 agent transacts -12.5, price is 67.2 battery is 38.88888888888888
# at time 19.0 agent transacts 0.0, price is 62.0 battery is 24.99999999999999
# at time 20.0 agent transacts 0.0, price is 55.0 battery is 24.99999999999999
# at time 21.0 agent transacts 25.0, price is 49.5 battery is 24.99999999999999
# at time 22.0 agent transacts -25.0, price is 45.88 battery is 49.999999999999986
# at time 23.0 agent transacts 12.5, price is 42.68 battery is 22.222222222222207
# at time 24.0 agent transacts -12.5, price is 41.85 battery is 34.72222222222221
# at time 1.0 agent transacts -12.5, price is 48.52 battery is 20.833333333333318
# at time 2.0 agent transacts 0.0, price is 39.62 battery is 6.944444444444429
# at time 3.0 agent transacts 0.0, price is 41.25 battery is 6.944444444444429
# at time 4.0 agent transacts 0.0, price is 37.12 battery is 6.944444444444429
# at time 5.0 agent transacts 25.0, price is 32.5 battery is 6.944444444444429
# at time 6.0 agent transacts -12.5, price is 39.5 battery is 31.94444444444443
# at time 7.0 agent transacts 0.0, price is 51.69 battery is 18.05555555555554
# at time 8.0 agent transacts 12.5, price is 56.9 battery is 18.05555555555554
# at time 9.0 agent transacts -12.5, price is 56.95 battery is 30.55555555555554
# at time 10.0 agent transacts -12.5, price is 49.75 battery is 16.66666666666665
# at time 11.0 agent transacts 12.5, price is 52.31 battery is 2.777777777777761
# at time 12.0 agent transacts -12.5, price is 68.16 battery is 15.27777777777776
# at time 13.0 agent transacts 25.0, price is 66.19 battery is 1.3888888888888715
# at time 14.0 agent transacts 12.5, price is 61.24 battery is 26.38888888888887
# at time 15.0 agent transacts -25.0, price is 59.7 battery is 38.88888888888887
# at time 16.0 agent transacts 12.5, price is 54.63 battery is 11.111111111111093
# at time 17.0 agent transacts 12.5, price is 51.0 battery is 23.611111111111093
# at time 18.0 agent transacts -25.0, price is 66.99 battery is 36.11111111111109
# at time 19.0 agent transacts 25.0, price is 75.0 battery is 8.333333333333314
# at time 20.0 agent transacts -25.0, price is 56.9 battery is 33.333333333333314
# at time 21.0 agent transacts 0.0, price is 43.56 battery is 5.555555555555536
# at time 22.0 agent transacts 0.0, price is 40.5 battery is 5.555555555555536
# at time 23.0 agent transacts 12.5, price is 56.36 battery is 5.555555555555536
# at time 24.0 agent transacts 0.0, price is 58.98 battery is 18.055555555555536
# at time 1.0 agent transacts 25.0, price is 40.0 battery is 18.055555555555536
# at time 2.0 agent transacts 0.0, price is 38.02 battery is 43.055555555555536
# at time 3.0 agent transacts -25.0, price is 34.99 battery is 43.055555555555536
# at time 4.0 agent transacts 0.0, price is 33.65 battery is 15.277777777777757
# at time 5.0 agent transacts 12.5, price is 32.0 battery is 15.277777777777757
# at time 6.0 agent transacts 12.5, price is 32.82 battery is 27.777777777777757
# at time 7.0 agent transacts -25.0, price is 39.1 battery is 40.27777777777776
# at time 8.0 agent transacts 12.5, price is 52.65 battery is 12.499999999999979
# at time 9.0 agent transacts 25.0, price is 59.0 battery is 4.999999999999979
# at time 10.0 agent transacts 12.5, price is 62.66 battery is 4.999999999999979
# at time 11.0 agent transacts 0.0, price is 61.1 battery is 4.999999999999979
# at time 12.0 agent transacts 0.0, price is 62.86 battery is 4.999999999999979
# at time 13.0 agent transacts 25.0, price is 63.0 battery is 4.999999999999979
# at time 14.0 agent transacts 0.0, price is 70.8 battery is 4.999999999999979
# at time 15.0 agent transacts 12.5, price is 66.4 battery is 4.999999999999979
# at time 16.0 agent transacts 25.0, price is 55.75 battery is 4.999999999999979
# at time 17.0 agent transacts 0.0, price is 60.12 battery is 4.999999999999979
# at time 18.0 agent transacts 25.0, price is 77.44 battery is 4.999999999999979
# at time 19.0 agent transacts 25.0, price is 70.0 battery is 4.999999999999979
# at time 20.0 agent transacts 0.0, price is 59.95 battery is 29.99999999999998
# at time 21.0 agent transacts -12.5, price is 54.0 battery is 29.99999999999998
# at time 22.0 agent transacts -12.5, price is 48.0 battery is 16.11111111111109
# at time 23.0 agent transacts 0.0, price is 46.47 battery is 2.2222222222222
# at time 24.0 agent transacts 0.0, price is 43.94 battery is 2.2222222222222
# at time 1.0 agent transacts 25.0, price is 47.96 battery is 2.2222222222222
# at time 2.0 agent transacts -12.5, price is 49.02 battery is 27.2222222222222
# at time 3.0 agent transacts 12.5, price is 37.0 battery is 13.33333333333331
# at time 4.0 agent transacts 0.0, price is 33.61 battery is 25.83333333333331
# at time 5.0 agent transacts 0.0, price is 32.96 battery is 25.83333333333331
# at time 6.0 agent transacts 12.5, price is 33.31 battery is 25.83333333333331
# at time 7.0 agent transacts -12.5, price is 54.9 battery is 38.333333333333314
# at time 8.0 agent transacts 12.5, price is 66.26 battery is 24.444444444444425
# at time 9.0 agent transacts -25.0, price is 75.0 battery is 36.94444444444443
# at time 10.0 agent transacts 12.5, price is 78.09 battery is 9.16666666666665
# at time 11.0 agent transacts 25.0, price is 61.45 battery is 21.66666666666665
# at time 12.0 agent transacts -12.5, price is 59.26 battery is 46.66666666666665
# at time 13.0 agent transacts -25.0, price is 57.0 battery is 32.77777777777776
# at time 14.0 agent transacts 12.5, price is 61.4 battery is 4.999999999999979
# at time 15.0 agent transacts -12.5, price is 49.01 battery is 17.49999999999998
# at time 16.0 agent transacts 12.5, price is 48.0 battery is 3.6111111111110894
# at time 17.0 agent transacts -12.5, price is 49.66 battery is 16.11111111111109
# at time 18.0 agent transacts 12.5, price is 63.08 battery is 2.2222222222222
# at time 19.0 agent transacts 25.0, price is 55.63 battery is 14.7222222222222
# at time 20.0 agent transacts 0.0, price is 47.15 battery is 39.7222222222222
# at time 21.0 agent transacts -12.5, price is 41.49 battery is 39.7222222222222
# at time 22.0 agent transacts 0.0, price is 34.99 battery is 25.83333333333331
# at time 23.0 agent transacts -12.5, price is 36.04 battery is 25.83333333333331
# at time 24.0 agent transacts 25.0, price is 54.9 battery is 11.944444444444422
# at time 1.0 agent transacts -12.5, price is 30.04 battery is 36.94444444444442
# at time 2.0 agent transacts 0.0, price is 28.0 battery is 23.055555555555532
# at time 3.0 agent transacts -12.5, price is 46.16 battery is 23.055555555555532
# at time 4.0 agent transacts 12.5, price is 27.53 battery is 9.166666666666643
# at time 5.0 agent transacts 25.0, price is 25.0 battery is 21.666666666666643
# at time 6.0 agent transacts 0.0, price is 22.0 battery is 46.66666666666664
# at time 7.0 agent transacts -25.0, price is 30.24 battery is 46.66666666666664
# at time 8.0 agent transacts 12.5, price is 33.0 battery is 18.888888888888864
# at time 9.0 agent transacts -12.5, price is 37.0 battery is 31.388888888888864
# at time 10.0 agent transacts 25.0, price is 42.99 battery is 17.499999999999975
# at time 11.0 agent transacts -12.5, price is 46.59 battery is 42.49999999999997
# at time 12.0 agent transacts -25.0, price is 46.76 battery is 28.611111111111082
# at time 13.0 agent transacts 25.0, price is 47.66 battery is 0.8333333333333037
# at time 14.0 agent transacts 0.0, price is 45.0 battery is 25.833333333333304
# at time 15.0 agent transacts -12.5, price is 43.6 battery is 25.833333333333304
# at time 16.0 agent transacts 25.0, price is 40.06 battery is 11.944444444444414
# at time 17.0 agent transacts 0.0, price is 45.0 battery is 36.944444444444414
# at time 18.0 agent transacts -12.5, price is 55.29 battery is 36.944444444444414
# at time 19.0 agent transacts -12.5, price is 51.61 battery is 23.055555555555525
# at time 20.0 agent transacts 25.0, price is 48.0 battery is 9.166666666666636
# at time 21.0 agent transacts 0.0, price is 48.77 battery is 34.166666666666636
# at time 22.0 agent transacts 12.5, price is 39.93 battery is 34.166666666666636
# at time 23.0 agent transacts -12.5, price is 43.24 battery is 46.666666666666636
# at time 24.0 agent transacts 12.5, price is 43.05 battery is 32.77777777777774
# at time 1.0 agent transacts -12.5, price is 66.0 battery is 45.27777777777774
# at time 2.0 agent transacts -12.5, price is 63.19 battery is 31.388888888888854
# at time 3.0 agent transacts 25.0, price is 56.18 battery is 17.499999999999964
# at time 4.0 agent transacts -12.5, price is 18.0 battery is 42.499999999999964
# at time 5.0 agent transacts 0.0, price is 0.01 battery is 28.611111111111075
# at time 6.0 agent transacts -25.0, price is 0.01 battery is 28.611111111111075
# at time 7.0 agent transacts 12.5, price is 1.0 battery is 0.8333333333332966
# at time 8.0 agent transacts 12.5, price is 0.01 battery is 13.333333333333297
# at time 9.0 agent transacts 25.0, price is 20.99 battery is 5.833333333333297
# at time 10.0 agent transacts 25.0, price is 30.0 battery is 5.833333333333297
# at time 11.0 agent transacts 25.0, price is 44.65 battery is 5.833333333333297
# at time 12.0 agent transacts 25.0, price is 46.93 battery is 5.833333333333297
# at time 13.0 agent transacts 25.0, price is 46.6 battery is 5.833333333333297
# at time 14.0 agent transacts 0.0, price is 44.86 battery is 5.833333333333297
# at time 15.0 agent transacts 0.0, price is 39.99 battery is 5.833333333333297
# at time 16.0 agent transacts 0.0, price is 35.57 battery is 5.833333333333297
# at time 17.0 agent transacts 12.5, price is 39.5 battery is 5.833333333333297
# at time 18.0 agent transacts 0.0, price is 47.93 battery is 5.833333333333297
# at time 19.0 agent transacts 12.5, price is 54.0 battery is 5.833333333333297
# at time 20.0 agent transacts -12.5, price is 49.18 battery is 18.333333333333297
# at time 21.0 agent transacts 0.0, price is 45.62 battery is 4.444444444444407
# at time 22.0 agent transacts 12.5, price is 43.0 battery is 4.444444444444407
# at time 23.0 agent transacts 25.0, price is 43.0 battery is 16.944444444444407
# at time 24.0 agent transacts -12.5, price is 38.1 battery is 41.94444444444441
# at time 1.0 agent transacts -25.0, price is 59.43 battery is 28.055555555555518
# at time 2.0 agent transacts 25.0, price is 45.93 battery is 0.2777777777777395
# at time 3.0 agent transacts 0.0, price is 36.09 battery is 25.27777777777774
# at time 4.0 agent transacts -12.5, price is 31.0 battery is 25.27777777777774
# at time 5.0 agent transacts 0.0, price is 30.91 battery is 11.38888888888885
# at time 6.0 agent transacts 0.0, price is 30.9 battery is 11.38888888888885
# at time 7.0 agent transacts 12.5, price is 37.31 battery is 11.38888888888885
# at time 8.0 agent transacts 25.0, price is 57.04 battery is 23.88888888888885
# at time 9.0 agent transacts -12.5, price is 70.5 battery is 48.88888888888885
# at time 10.0 agent transacts 0.0, price is 71.5 battery is 34.99999999999996
# at time 11.0 agent transacts 0.0, price is 71.0 battery is 34.99999999999996
# at time 12.0 agent transacts 12.5, price is 70.04 battery is 34.99999999999996
# at time 13.0 agent transacts -12.5, price is 68.75 battery is 47.49999999999996
# at time 14.0 agent transacts 12.5, price is 84.48 battery is 33.61111111111107
# at time 15.0 agent transacts -25.0, price is 81.52 battery is 46.11111111111107
# at time 16.0 agent transacts -12.5, price is 61.45 battery is 18.333333333333293
# at time 17.0 agent transacts 25.0, price is 72.69 battery is 4.444444444444404
# at time 18.0 agent transacts 0.0, price is 89.0 battery is 29.444444444444404
# at time 19.0 agent transacts 0.0, price is 80.66 battery is 29.444444444444404
# at time 20.0 agent transacts 12.5, price is 63.5 battery is 29.444444444444404
# at time 21.0 agent transacts 0.0, price is 49.99 battery is 41.9444444444444
# at time 22.0 agent transacts -25.0, price is 43.66 battery is 41.9444444444444
# at time 23.0 agent transacts 25.0, price is 66.19 battery is 14.166666666666622
# at time 24.0 agent transacts -25.0, price is 62.92 battery is 39.16666666666662
# at time 1.0 agent transacts 25.0, price is 63.2 battery is 11.388888888888843
# at time 2.0 agent transacts 0.0, price is 67.27 battery is 36.38888888888884
# at time 3.0 agent transacts -25.0, price is 61.85 battery is 36.38888888888884
# at time 4.0 agent transacts 25.0, price is 55.0 battery is 8.611111111111065
# at time 5.0 agent transacts 0.0, price is 53.02 battery is 33.611111111111065
# at time 6.0 agent transacts 12.5, price is 60.29 battery is 33.611111111111065
# at time 7.0 agent transacts 0.0, price is 75.0 battery is 46.111111111111065
# at time 8.0 agent transacts 0.0, price is 102.12 battery is 46.111111111111065
# at time 9.0 agent transacts -25.0, price is 143.28 battery is 46.111111111111065
# at time 10.0 agent transacts -12.5, price is 195.56 battery is 18.333333333333286
# at time 11.0 agent transacts 12.5, price is 179.58 battery is 4.444444444444397
# at time 12.0 agent transacts 0.0, price is 158.11 battery is 16.944444444444397
# at time 13.0 agent transacts 25.0, price is 93.99 battery is 16.944444444444397
# at time 14.0 agent transacts 0.0, price is 75.17 battery is 41.9444444444444
# at time 15.0 agent transacts -25.0, price is 66.11 battery is 41.9444444444444
# at time 16.0 agent transacts 12.5, price is 66.2 battery is 14.166666666666622
# at time 17.0 agent transacts 0.0, price is 65.66 battery is 26.66666666666662
# at time 18.0 agent transacts 0.0, price is 83.73 battery is 26.66666666666662
# at time 19.0 agent transacts -12.5, price is 101.25 battery is 26.66666666666662
# at time 20.0 agent transacts 0.0, price is 72.77 battery is 12.777777777777732
# at time 21.0 agent transacts 12.5, price is 64.15 battery is 12.777777777777732
# at time 22.0 agent transacts -12.5, price is 42.0 battery is 25.277777777777732
# at time 23.0 agent transacts 12.5, price is 61.1 battery is 11.388888888888843
# at time 24.0 agent transacts -12.5, price is 54.69 battery is 23.888888888888843
# at time 1.0 agent transacts 0.0, price is 44.96 battery is 9.999999999999954
# at time 2.0 agent transacts 0.0, price is 46.4 battery is 9.999999999999954
# at time 3.0 agent transacts 12.5, price is 45.88 battery is 9.999999999999954
# at time 4.0 agent transacts 0.0, price is 35.01 battery is 22.499999999999954
# at time 5.0 agent transacts -12.5, price is 34.28 battery is 22.499999999999954
# at time 6.0 agent transacts 25.0, price is 37.11 battery is 8.611111111111065
# at time 7.0 agent transacts 0.0, price is 53.05 battery is 33.611111111111065
# at time 8.0 agent transacts 12.5, price is 66.18 battery is 33.611111111111065
# at time 9.0 agent transacts -25.0, price is 63.92 battery is 46.111111111111065
# at time 10.0 agent transacts 25.0, price is 61.46 battery is 18.333333333333286
# at time 11.0 agent transacts 0.0, price is 62.36 battery is 43.333333333333286
# at time 12.0 agent transacts -12.5, price is 63.88 battery is 43.333333333333286
# at time 13.0 agent transacts -12.5, price is 66.46 battery is 29.444444444444397
# at time 14.0 agent transacts 0.0, price is 65.15 battery is 15.555555555555507
# at time 15.0 agent transacts 0.0, price is 63.6 battery is 15.555555555555507
# at time 16.0 agent transacts -12.5, price is 57.65 battery is 15.555555555555507
# at time 17.0 agent transacts 12.5, price is 58.29 battery is 1.6666666666666181
# at time 18.0 agent transacts 25.0, price is 67.01 battery is 14.166666666666618
# at time 19.0 agent transacts -25.0, price is 72.13 battery is 39.166666666666615
# at time 20.0 agent transacts 25.0, price is 71.03 battery is 11.388888888888836
# at time 21.0 agent transacts 0.0, price is 67.5 battery is 36.388888888888836
# at time 22.0 agent transacts -25.0, price is 43.5 battery is 36.388888888888836
# at time 23.0 agent transacts 12.5, price is 51.67 battery is 8.611111111111057
# at time 24.0 agent transacts 12.5, price is 47.0 battery is 21.111111111111057
# at time 1.0 agent transacts 12.5, price is 44.09 battery is 33.61111111111106
# at time 2.0 agent transacts 0.0, price is 45.18 battery is 46.11111111111106
# at time 3.0 agent transacts -12.5, price is 41.19 battery is 46.11111111111106
# at time 4.0 agent transacts 0.0, price is 33.5 battery is 32.22222222222217
# at time 5.0 agent transacts 0.0, price is 32.21 battery is 32.22222222222217
# at time 6.0 agent transacts -12.5, price is 40.9 battery is 32.22222222222217
# at time 7.0 agent transacts 25.0, price is 51.47 battery is 18.333333333333282
# at time 8.0 agent transacts -12.5, price is 65.25 battery is 43.333333333333286
# at time 9.0 agent transacts -12.5, price is 65.58 battery is 29.444444444444397
# at time 10.0 agent transacts -12.5, price is 66.2 battery is 15.555555555555507
# at time 11.0 agent transacts 12.5, price is 66.19 battery is 1.6666666666666181
# at time 12.0 agent transacts 12.5, price is 66.17 battery is 14.166666666666618
# at time 13.0 agent transacts 0.0, price is 65.29 battery is 26.666666666666618
# at time 14.0 agent transacts 0.0, price is 63.08 battery is 26.666666666666618
# at time 15.0 agent transacts 25.0, price is 62.03 battery is 26.666666666666618
# at time 16.0 agent transacts 0.0, price is 57.23 battery is 50.0
# at time 17.0 agent transacts -12.5, price is 61.11 battery is 50.0
# at time 18.0 agent transacts 0.0, price is 69.0 battery is 36.111111111111114
# at time 19.0 agent transacts -12.5, price is 87.96 battery is 36.111111111111114
# at time 20.0 agent transacts 25.0, price is 69.99 battery is 22.222222222222225
# at time 21.0 agent transacts -12.5, price is 66.19 battery is 47.22222222222223
# at time 22.0 agent transacts 0.0, price is 55.59 battery is 33.33333333333334
# at time 23.0 agent transacts 12.5, price is 55.53 battery is 33.33333333333334
# at time 24.0 agent transacts -25.0, price is 50.62 battery is 45.83333333333334
# at time 1.0 agent transacts 12.5, price is 47.73 battery is 18.055555555555564
# at time 2.0 agent transacts -12.5, price is 47.78 battery is 30.555555555555564
# at time 3.0 agent transacts 25.0, price is 42.75 battery is 16.666666666666675
# at time 4.0 agent transacts -12.5, price is 32.99 battery is 41.66666666666667
# at time 5.0 agent transacts -25.0, price is 32.0 battery is 27.777777777777782
# at time 6.0 agent transacts 12.5, price is 39.84 battery is 3.552713678800501e-15
# at time 7.0 agent transacts 0.0, price is 48.96 battery is 12.500000000000004
# at time 8.0 agent transacts 25.0, price is 65.0 battery is 12.500000000000004
# at time 9.0 agent transacts -12.5, price is 65.17 battery is 17.5
# at time 10.0 agent transacts 0.0, price is 64.82 battery is 17.5
# at time 11.0 agent transacts 12.5, price is 66.18 battery is 17.5
# at time 12.0 agent transacts 0.0, price is 66.0 battery is 17.5
# at time 13.0 agent transacts -12.5, price is 62.93 battery is 17.5
# at time 14.0 agent transacts -12.5, price is 62.13 battery is 17.5
# at time 15.0 agent transacts 25.0, price is 57.95 battery is 17.5
# at time 16.0 agent transacts 0.0, price is 50.41 battery is 17.5
# at time 17.0 agent transacts -12.5, price is 53.8 battery is 17.5
# at time 18.0 agent transacts 25.0, price is 63.02 battery is 17.5
# at time 19.0 agent transacts 0.0, price is 67.44 battery is 17.5
# at time 20.0 agent transacts 0.0, price is 66.99 battery is 17.5
# at time 21.0 agent transacts 0.0, price is 60.95 battery is 17.5
# at time 22.0 agent transacts 12.5, price is 50.77 battery is 17.5
# at time 23.0 agent transacts 12.5, price is 53.06 battery is 30.0
# at time 24.0 agent transacts -12.5, price is 53.86 battery is 42.5
# at time 1.0 agent transacts -25.0, price is 42.56 battery is 28.61111111111111
# at time 2.0 agent transacts 25.0, price is 40.74 battery is 0.8333333333333321
# at time 3.0 agent transacts 25.0, price is 37.56 battery is 25.833333333333332
# at time 4.0 agent transacts -25.0, price is 34.01 battery is 50.0
# at time 5.0 agent transacts 12.5, price is 31.76 battery is 22.22222222222222
# at time 6.0 agent transacts -25.0, price is 29.8 battery is 34.72222222222222
# at time 7.0 agent transacts 25.0, price is 29.2 battery is 6.944444444444443
# at time 8.0 agent transacts 0.0, price is 27.67 battery is 31.944444444444443
# at time 9.0 agent transacts 0.0, price is 36.67 battery is 11.944444444444443
# at time 10.0 agent transacts 0.0, price is 43.0 battery is 11.944444444444443
# at time 11.0 agent transacts 0.0, price is 45.34 battery is 11.944444444444443
# at time 12.0 agent transacts 0.0, price is 46.0 battery is 11.944444444444443
# at time 13.0 agent transacts 0.0, price is 43.0 battery is 11.944444444444443
# at time 14.0 agent transacts 0.0, price is 39.59 battery is 11.944444444444443
# at time 15.0 agent transacts 0.0, price is 37.93 battery is 11.944444444444443
# at time 16.0 agent transacts 0.0, price is 34.87 battery is 11.944444444444443
# at time 17.0 agent transacts 0.0, price is 34.3 battery is 11.944444444444443
# at time 18.0 agent transacts 0.0, price is 44.8 battery is 11.944444444444443
# at time 19.0 agent transacts 25.0, price is 53.12 battery is 11.944444444444443
# at time 20.0 agent transacts -12.5, price is 39.93 battery is 36.94444444444444
# at time 21.0 agent transacts -12.5, price is 34.2 battery is 23.055555555555554
# at time 22.0 agent transacts 25.0, price is 37.0 battery is 9.166666666666664
# at time 23.0 agent transacts -25.0, price is 47.03 battery is 34.166666666666664
# at time 24.0 agent transacts 0.0, price is 47.08 battery is 6.388888888888886
# at time 1.0 agent transacts 12.5, price is 41.78 battery is 6.388888888888886
# at time 2.0 agent transacts -12.5, price is 40.17 battery is 18.888888888888886
# at time 3.0 agent transacts 12.5, price is 30.91 battery is 4.9999999999999964
# at time 4.0 agent transacts -12.5, price is 17.0 battery is 17.499999999999996
# at time 5.0 agent transacts 12.5, price is 14.79 battery is 3.611111111111107
# at time 6.0 agent transacts -12.5, price is 12.31 battery is 16.111111111111107
# at time 7.0 agent transacts 0.0, price is 11.93 battery is 2.222222222222218
# at time 8.0 agent transacts 25.0, price is 14.0 battery is 2.222222222222218
# at time 9.0 agent transacts 0.0, price is 21.25 battery is 7.222222222222218
# at time 10.0 agent transacts 12.5, price is 32.99 battery is 7.222222222222218
# at time 11.0 agent transacts 12.5, price is 40.0 battery is 7.222222222222218
# at time 12.0 agent transacts 0.0, price is 40.5 battery is 7.222222222222218
# at time 13.0 agent transacts 0.0, price is 38.0 battery is 7.222222222222218
# at time 14.0 agent transacts 25.0, price is 34.94 battery is 7.222222222222218
# at time 15.0 agent transacts 0.0, price is 30.0 battery is 7.222222222222218
# at time 16.0 agent transacts 12.5, price is 27.0 battery is 7.222222222222218
# at time 17.0 agent transacts 12.5, price is 27.67 battery is 7.222222222222218
# at time 18.0 agent transacts 0.0, price is 38.68 battery is 7.222222222222218
# at time 19.0 agent transacts 25.0, price is 41.11 battery is 7.222222222222218
# at time 20.0 agent transacts 12.5, price is 43.0 battery is 32.222222222222214
# at time 21.0 agent transacts 0.0, price is 43.71 battery is 44.722222222222214
# at time 22.0 agent transacts -12.5, price is 42.65 battery is 44.722222222222214
# at time 23.0 agent transacts -12.5, price is 45.21 battery is 30.833333333333325
# at time 24.0 agent transacts 0.0, price is 42.73 battery is 16.944444444444436
# at time 1.0 agent transacts 25.0, price is 32.01 battery is 16.944444444444436
# at time 2.0 agent transacts -12.5, price is 31.0 battery is 41.944444444444436
# at time 3.0 agent transacts -25.0, price is 26.44 battery is 28.055555555555546
# at time 4.0 agent transacts 25.0, price is 19.15 battery is 0.2777777777777679
# at time 5.0 agent transacts 0.0, price is 19.0 battery is 25.277777777777768
# at time 6.0 agent transacts -12.5, price is 26.21 battery is 25.277777777777768
# at time 7.0 agent transacts 12.5, price is 40.2 battery is 11.388888888888879
# at time 8.0 agent transacts 25.0, price is 61.53 battery is 23.88888888888888
# at time 9.0 agent transacts -25.0, price is 60.21 battery is 48.88888888888888
# at time 10.0 agent transacts -12.5, price is 59.99 battery is 21.1111111111111
# at time 11.0 agent transacts 25.0, price is 59.3 battery is 7.222222222222211
# at time 12.0 agent transacts 0.0, price is 59.12 battery is 32.222222222222214
# at time 13.0 agent transacts 0.0, price is 57.34 battery is 32.222222222222214
# at time 14.0 agent transacts -25.0, price is 54.93 battery is 32.222222222222214
# at time 15.0 agent transacts 0.0, price is 50.91 battery is 4.444444444444436
# at time 16.0 agent transacts 25.0, price is 48.33 battery is 4.444444444444436
# at time 17.0 agent transacts 0.0, price is 52.8 battery is 29.444444444444436
# at time 18.0 agent transacts -25.0, price is 62.07 battery is 29.444444444444436
# at time 19.0 agent transacts 25.0, price is 68.27 battery is 1.6666666666666572
# at time 20.0 agent transacts 0.0, price is 54.75 battery is 26.666666666666657
# at time 21.0 agent transacts 25.0, price is 47.8 battery is 26.666666666666657
# at time 22.0 agent transacts 0.0, price is 43.54 battery is 50.0
# at time 23.0 agent transacts 0.0, price is 47.91 battery is 50.0
# at time 24.0 agent transacts 0.0, price is 42.31 battery is 50.0
# at time 1.0 agent transacts -12.5, price is 39.93 battery is 50.0
# at time 2.0 agent transacts 12.5, price is 38.67 battery is 36.111111111111114
# at time 3.0 agent transacts 0.0, price is 33.99 battery is 48.611111111111114
# at time 4.0 agent transacts -25.0, price is 30.91 battery is 48.611111111111114
# at time 5.0 agent transacts 25.0, price is 29.0 battery is 20.833333333333336
# at time 6.0 agent transacts 0.0, price is 36.53 battery is 45.833333333333336
# at time 7.0 agent transacts -25.0, price is 49.59 battery is 45.833333333333336
# at time 8.0 agent transacts 25.0, price is 57.0 battery is 18.055555555555557
# at time 9.0 agent transacts 0.0, price is 59.08 battery is 43.05555555555556
# at time 10.0 agent transacts -25.0, price is 58.68 battery is 43.05555555555556
# at time 11.0 agent transacts 25.0, price is 58.57 battery is 15.277777777777779
# at time 12.0 agent transacts -12.5, price is 58.41 battery is 40.27777777777778
# at time 13.0 agent transacts -12.5, price is 57.63 battery is 26.38888888888889
# at time 14.0 agent transacts 12.5, price is 53.63 battery is 12.5
# at time 15.0 agent transacts 0.0, price is 52.05 battery is 25.0
# at time 16.0 agent transacts 0.0, price is 49.01 battery is 25.0
# at time 17.0 agent transacts 0.0, price is 50.75 battery is 25.0
# at time 18.0 agent transacts 25.0, price is 60.0 battery is 25.0
# at time 19.0 agent transacts -25.0, price is 65.46 battery is 50.0
# at time 20.0 agent transacts -12.5, price is 58.87 battery is 22.22222222222222
# at time 21.0 agent transacts 12.5, price is 50.86 battery is 8.333333333333332
# at time 22.0 agent transacts 25.0, price is 43.4 battery is 20.833333333333332
# at time 23.0 agent transacts -25.0, price is 47.66 battery is 45.83333333333333
# at time 24.0 agent transacts 0.0, price is 43.79 battery is 18.05555555555555
# at time 1.0 agent transacts -12.5, price is 38.57 battery is 18.05555555555555
# at time 2.0 agent transacts 25.0, price is 37.33 battery is 4.166666666666661
# at time 3.0 agent transacts 12.5, price is 31.64 battery is 29.16666666666666
# at time 4.0 agent transacts -12.5, price is 29.31 battery is 41.66666666666666
# at time 5.0 agent transacts 12.5, price is 28.91 battery is 27.777777777777768
# at time 6.0 agent transacts -25.0, price is 32.96 battery is 40.27777777777777
# at time 7.0 agent transacts 0.0, price is 43.08 battery is 12.499999999999993
# at time 8.0 agent transacts 12.5, price is 58.0 battery is 12.499999999999993
# at time 9.0 agent transacts 0.0, price is 56.44 battery is 4.999999999999993
# at time 10.0 agent transacts 25.0, price is 56.87 battery is 4.999999999999993
# at time 11.0 agent transacts 0.0, price is 58.62 battery is 4.999999999999993
# at time 12.0 agent transacts 25.0, price is 53.09 battery is 4.999999999999993
# at time 13.0 agent transacts 12.5, price is 51.0 battery is 4.999999999999993
# at time 14.0 agent transacts 0.0, price is 52.46 battery is 4.999999999999993
# at time 15.0 agent transacts 0.0, price is 54.68 battery is 4.999999999999993
# at time 16.0 agent transacts 12.5, price is 49.78 battery is 4.999999999999993
# at time 17.0 agent transacts 12.5, price is 49.99 battery is 4.999999999999993
# at time 18.0 agent transacts 0.0, price is 54.93 battery is 4.999999999999993
# at time 19.0 agent transacts 12.5, price is 63.84 battery is 4.999999999999993
# at time 20.0 agent transacts 25.0, price is 47.1 battery is 17.499999999999993
# at time 21.0 agent transacts -12.5, price is 46.83 battery is 42.49999999999999
# at time 22.0 agent transacts 12.5, price is 43.0 battery is 28.611111111111104
# at time 23.0 agent transacts -12.5, price is 44.99 battery is 41.1111111111111
# at time 24.0 agent transacts 12.5, price is 41.02 battery is 27.22222222222221
# at time 1.0 agent transacts -12.5, price is 37.51 battery is 39.722222222222214
# at time 2.0 agent transacts 25.0, price is 36.12 battery is 25.833333333333325
# at time 3.0 agent transacts -25.0, price is 33.05 battery is 50.0
# at time 4.0 agent transacts 12.5, price is 28.81 battery is 22.22222222222222
# at time 5.0 agent transacts -25.0, price is 27.54 battery is 34.72222222222222
# at time 6.0 agent transacts 12.5, price is 34.0 battery is 6.944444444444443
# at time 7.0 agent transacts 0.0, price is 41.3 battery is 19.444444444444443
# at time 8.0 agent transacts 25.0, price is 53.18 battery is 19.444444444444443
# at time 9.0 agent transacts -12.5, price is 55.27 battery is 24.444444444444443
# at time 10.0 agent transacts 12.5, price is 52.5 battery is 24.444444444444443
# at time 11.0 agent transacts -12.5, price is 53.0 battery is 24.444444444444443
# at time 12.0 agent transacts 0.0, price is 53.5 battery is 24.444444444444443
# at time 13.0 agent transacts 25.0, price is 50.5 battery is 24.444444444444443
# at time 14.0 agent transacts -12.5, price is 52.29 battery is 24.444444444444443
# at time 15.0 agent transacts 25.0, price is 50.22 battery is 24.444444444444443
# at time 16.0 agent transacts 0.0, price is 48.09 battery is 24.444444444444443
# at time 17.0 agent transacts 12.5, price is 49.94 battery is 24.444444444444443
# at time 18.0 agent transacts -12.5, price is 56.27 battery is 24.444444444444443
# at time 19.0 agent transacts 12.5, price is 63.16 battery is 24.444444444444443
# at time 20.0 agent transacts -12.5, price is 47.58 battery is 36.94444444444444
# at time 21.0 agent transacts 0.0, price is 44.93 battery is 23.055555555555554
# at time 22.0 agent transacts 25.0, price is 42.0 battery is 23.055555555555554
# at time 23.0 agent transacts -25.0, price is 45.0 battery is 48.05555555555556
# at time 24.0 agent transacts -12.5, price is 40.47 battery is 20.27777777777778
# at time 1.0 agent transacts 12.5, price is 37.75 battery is 6.388888888888889
# at time 2.0 agent transacts 12.5, price is 37.1 battery is 18.88888888888889
# at time 3.0 agent transacts 12.5, price is 32.48 battery is 31.38888888888889
# at time 4.0 agent transacts 0.0, price is 30.3 battery is 43.888888888888886
# at time 5.0 agent transacts 0.0, price is 29.34 battery is 43.888888888888886
# at time 6.0 agent transacts 0.0, price is 31.34 battery is 43.888888888888886
# at time 7.0 agent transacts 0.0, price is 40.86 battery is 43.888888888888886
# at time 8.0 agent transacts -12.5, price is 54.14 battery is 43.888888888888886
# at time 9.0 agent transacts 12.5, price is 55.0 battery is 29.999999999999996
# at time 10.0 agent transacts -12.5, price is 56.7 battery is 42.5
# at time 11.0 agent transacts -25.0, price is 54.56 battery is 28.61111111111111
# at time 12.0 agent transacts 25.0, price is 55.39 battery is 0.8333333333333321
# at time 13.0 agent transacts -12.5, price is 52.92 battery is 25.833333333333332
# at time 14.0 agent transacts 25.0, price is 50.0 battery is 11.944444444444443
# at time 15.0 agent transacts 12.5, price is 48.45 battery is 36.94444444444444
# at time 16.0 agent transacts -12.5, price is 44.96 battery is 49.44444444444444
# at time 17.0 agent transacts 12.5, price is 45.5 battery is 35.55555555555556
# at time 18.0 agent transacts 0.0, price is 51.22 battery is 48.05555555555556
# at time 19.0 agent transacts -25.0, price is 51.43 battery is 48.05555555555556
# at time 20.0 agent transacts 0.0, price is 44.88 battery is 20.27777777777778
# at time 21.0 agent transacts 0.0, price is 41.5 battery is 20.27777777777778
# at time 22.0 agent transacts -12.5, price is 42.4 battery is 20.27777777777778
# at time 23.0 agent transacts 0.0, price is 43.47 battery is 6.388888888888889
# at time 24.0 agent transacts 12.5, price is 40.51 battery is 6.388888888888889
# at time 1.0 agent transacts 12.5, price is 41.27 battery is 18.88888888888889
# at time 2.0 agent transacts 12.5, price is 39.09 battery is 31.38888888888889
# at time 3.0 agent transacts -25.0, price is 35.0 battery is 43.888888888888886
# at time 4.0 agent transacts 25.0, price is 30.95 battery is 16.111111111111107
# at time 5.0 agent transacts 0.0, price is 28.5 battery is 41.11111111111111
# at time 6.0 agent transacts -25.0, price is 29.58 battery is 41.11111111111111
# at time 7.0 agent transacts 12.5, price is 29.77 battery is 13.333333333333329
# at time 8.0 agent transacts 0.0, price is 35.0 battery is 25.83333333333333
# at time 9.0 agent transacts 0.0, price is 39.93 battery is 5.833333333333329
# at time 10.0 agent transacts 0.0, price is 43.0 battery is 5.833333333333329
# at time 11.0 agent transacts 0.0, price is 46.79 battery is 5.833333333333329
# at time 12.0 agent transacts 0.0, price is 48.66 battery is 5.833333333333329
# at time 13.0 agent transacts 12.5, price is 52.89 battery is 5.833333333333329
# at time 14.0 agent transacts 25.0, price is 46.15 battery is 5.833333333333329
# at time 15.0 agent transacts 25.0, price is 43.41 battery is 5.833333333333329
# at time 16.0 agent transacts 25.0, price is 41.45 battery is 5.833333333333329
# at time 17.0 agent transacts 12.5, price is 41.96 battery is 5.833333333333329
# at time 18.0 agent transacts 12.5, price is 45.78 battery is 5.833333333333329
# at time 19.0 agent transacts 0.0, price is 53.19 battery is 5.833333333333329
# at time 20.0 agent transacts 25.0, price is 52.83 battery is 5.833333333333329
# at time 21.0 agent transacts -25.0, price is 46.29 battery is 30.83333333333333
# at time 22.0 agent transacts 12.5, price is 41.19 battery is 3.05555555555555
# at time 23.0 agent transacts 25.0, price is 43.01 battery is 15.55555555555555
# at time 24.0 agent transacts 0.0, price is 42.0 battery is 40.55555555555555
# at time 1.0 agent transacts 0.0, price is 42.07 battery is 40.55555555555555
# at time 2.0 agent transacts 0.0, price is 41.83 battery is 40.55555555555555
# at time 3.0 agent transacts 0.0, price is 40.09 battery is 40.55555555555555
# at time 4.0 agent transacts 0.0, price is 33.28 battery is 40.55555555555555
# at time 5.0 agent transacts 0.0, price is 26.67 battery is 40.55555555555555
# at time 6.0 agent transacts 0.0, price is 22.0 battery is 40.55555555555555
# at time 7.0 agent transacts 0.0, price is 20.05 battery is 40.55555555555555
# at time 8.0 agent transacts -12.5, price is 27.85 battery is 40.55555555555555
# at time 9.0 agent transacts -12.5, price is 31.16 battery is 26.66666666666666
# at time 10.0 agent transacts 0.0, price is 36.57 battery is 12.777777777777771
# at time 11.0 agent transacts 25.0, price is 42.76 battery is 12.777777777777771
# at time 12.0 agent transacts -12.5, price is 46.09 battery is 37.77777777777777
# at time 13.0 agent transacts 12.5, price is 48.6 battery is 23.888888888888882
# at time 14.0 agent transacts -25.0, price is 42.61 battery is 36.388888888888886
# at time 15.0 agent transacts 25.0, price is 37.82 battery is 8.611111111111107
# at time 16.0 agent transacts 12.5, price is 34.4 battery is 33.61111111111111
# at time 17.0 agent transacts 0.0, price is 34.84 battery is 46.11111111111111
# at time 18.0 agent transacts -25.0, price is 42.15 battery is 46.11111111111111
# at time 19.0 agent transacts 25.0, price is 50.08 battery is 18.33333333333333
# at time 20.0 agent transacts -25.0, price is 49.48 battery is 43.33333333333333
# at time 21.0 agent transacts 25.0, price is 45.68 battery is 15.55555555555555
# at time 22.0 agent transacts -12.5, price is 42.42 battery is 40.55555555555555
# at time 23.0 agent transacts 25.0, price is 43.16 battery is 26.66666666666666
# at time 24.0 agent transacts -12.5, price is 42.63 battery is 50.0
# at time 1.0 agent transacts 0.0, price is 37.71 battery is 36.111111111111114
# at time 2.0 agent transacts 12.5, price is 34.15 battery is 36.111111111111114
# at time 3.0 agent transacts -25.0, price is 31.0 battery is 48.611111111111114
# at time 4.0 agent transacts 12.5, price is 27.0 battery is 20.833333333333336
# at time 5.0 agent transacts 0.0, price is 27.97 battery is 33.333333333333336
# at time 6.0 agent transacts -12.5, price is 33.0 battery is 33.333333333333336
# at time 7.0 agent transacts 25.0, price is 43.45 battery is 19.444444444444446
# at time 8.0 agent transacts -12.5, price is 53.6 battery is 44.44444444444444
# at time 9.0 agent transacts 0.0, price is 57.11 battery is 10.555555555555554
# at time 10.0 agent transacts 25.0, price is 61.0 battery is 10.555555555555554
# at time 11.0 agent transacts 12.5, price is 62.7 battery is 10.555555555555554
# at time 12.0 agent transacts 25.0, price is 62.7 battery is 10.555555555555554
# at time 13.0 agent transacts 25.0, price is 59.04 battery is 10.555555555555554
# at time 14.0 agent transacts 25.0, price is 60.04 battery is 10.555555555555554
# at time 15.0 agent transacts 25.0, price is 55.58 battery is 10.555555555555554
# at time 16.0 agent transacts 0.0, price is 50.66 battery is 10.555555555555554
# at time 17.0 agent transacts 12.5, price is 51.0 battery is 10.555555555555554
# at time 18.0 agent transacts 12.5, price is 60.67 battery is 10.555555555555554
# at time 19.0 agent transacts 0.0, price is 58.85 battery is 10.555555555555554
# at time 20.0 agent transacts 25.0, price is 50.0 battery is 10.555555555555554
# at time 21.0 agent transacts -25.0, price is 49.9 battery is 35.55555555555556
# at time 22.0 agent transacts 0.0, price is 44.37 battery is 7.777777777777779
# at time 23.0 agent transacts 0.0, price is 42.89 battery is 7.777777777777779
# at time 24.0 agent transacts 12.5, price is 39.84 battery is 7.777777777777779
# at time 1.0 agent transacts 0.0, price is 41.91 battery is 20.27777777777778
# at time 2.0 agent transacts 0.0, price is 40.0 battery is 20.27777777777778
# at time 3.0 agent transacts 25.0, price is 36.25 battery is 20.27777777777778
# at time 4.0 agent transacts -12.5, price is 31.08 battery is 45.27777777777778
# at time 5.0 agent transacts -25.0, price is 30.0 battery is 31.38888888888889
# at time 6.0 agent transacts 25.0, price is 37.01 battery is 3.6111111111111107
# at time 7.0 agent transacts 12.5, price is 44.11 battery is 28.61111111111111
# at time 8.0 agent transacts 0.0, price is 56.3 battery is 41.111111111111114
# at time 9.0 agent transacts -25.0, price is 60.61 battery is 41.111111111111114
# at time 10.0 agent transacts 25.0, price is 62.38 battery is 13.333333333333336
# at time 11.0 agent transacts -12.5, price is 63.34 battery is 38.333333333333336
# at time 12.0 agent transacts 12.5, price is 63.0 battery is 24.444444444444446
# at time 13.0 agent transacts 12.5, price is 62.2 battery is 36.94444444444444
# at time 14.0 agent transacts -12.5, price is 60.66 battery is 49.44444444444444
# at time 15.0 agent transacts 0.0, price is 58.35 battery is 35.55555555555556
# ...
# at time 14.0 agent transacts -25.0, price is 50.46 battery is 48.61111111111111
# at time 15.0 agent transacts 25.0, price is 45.35 battery is 20.83333333333333
# at time 16.0 agent transacts -12.5, price is 42.67 battery is 45.83333333333333
# at time 17.0 agent transacts 12.5, price is 46.67 battery is 31.94444444444444
# at time 18.0 agent transacts -12.5, price is 53.95 battery is 44.44444444444444
# at time 19.0 agent transacts 12.5, price is 54.18 battery is 30.555555555555554
# at time 20.0 agent transacts -25.0, price is 53.19 battery is 43.05555555555556
# at time 21.0 agent transacts 0.0, price is 49.83 battery is 15.277777777777779
# at time 22.0 agent transacts 12.5, price is 44.0 battery is 15.277777777777779
# at time 23.0 agent transacts -12.5, price is 45.1 battery is 27.77777777777778
# at time 24.0 agent transacts 25.0, price is 41.6 battery is 13.88888888888889
# at time 1.0 agent transacts -12.5, price is 24.3 battery is 38.888888888888886
# at time 2.0 agent transacts 12.5, price is 19.14 battery is 24.999999999999996
# at time 3.0 agent transacts 12.5, price is 17.16 battery is 37.5
# at time 4.0 agent transacts 0.0, price is 12.96 battery is 50.0
# at time 5.0 agent transacts -12.5, price is 11.34 battery is 50.0
# at time 6.0 agent transacts -25.0, price is 12.23 battery is 36.111111111111114
# at time 7.0 agent transacts 25.0, price is 12.91 battery is 8.333333333333336
# at time 8.0 agent transacts 0.0, price is 18.37 battery is 33.333333333333336
# at time 9.0 agent transacts 12.5, price is 26.73 battery is 33.333333333333336
# at time 10.0 agent transacts 0.0, price is 32.11 battery is 45.833333333333336
# at time 11.0 agent transacts 0.0, price is 33.9 battery is 45.833333333333336
# at time 12.0 agent transacts -25.0, price is 35.88 battery is 45.833333333333336
# at time 13.0 agent transacts -12.5, price is 35.44 battery is 18.055555555555557
# at time 14.0 agent transacts 25.0, price is 33.08 battery is 4.166666666666668
# at time 15.0 agent transacts 0.0, price is 31.65 battery is 29.166666666666668
# at time 16.0 agent transacts 12.5, price is 31.59 battery is 29.166666666666668
# at time 17.0 agent transacts -12.5, price is 32.92 battery is 41.66666666666667
# at time 18.0 agent transacts -25.0, price is 42.31 battery is 27.777777777777782
# at time 19.0 agent transacts 12.5, price is 44.08 battery is 3.552713678800501e-15
# at time 20.0 agent transacts 25.0, price is 35.31 battery is 12.500000000000004
# at time 21.0 agent transacts -25.0, price is 32.95 battery is 37.5
# at time 22.0 agent transacts 12.5, price is 30.75 battery is 9.722222222222221
# at time 23.0 agent transacts 0.0, price is 35.88 battery is 22.22222222222222
# at time 24.0 agent transacts 25.0, price is 31.45 battery is 22.22222222222222
# at time 1.0 agent transacts -25.0, price is 27.18 battery is 47.22222222222222
# at time 2.0 agent transacts 12.5, price is 25.08 battery is 19.444444444444443
# at time 3.0 agent transacts -25.0, price is 20.96 battery is 31.944444444444443
# at time 4.0 agent transacts 0.0, price is 15.68 battery is 4.166666666666664
# at time 5.0 agent transacts 0.0, price is 10.85 battery is 4.166666666666664
# at time 6.0 agent transacts 12.5, price is 10.53 battery is 4.166666666666664
# at time 7.0 agent transacts 12.5, price is 11.33 battery is 16.666666666666664
# at time 8.0 agent transacts 0.0, price is 10.89 battery is 29.166666666666664
# at time 9.0 agent transacts 0.0, price is 14.69 battery is 29.166666666666664
# at time 10.0 agent transacts -25.0, price is 18.07 battery is 29.166666666666664
# at time 11.0 agent transacts 25.0, price is 23.93 battery is 1.3888888888888857
# at time 12.0 agent transacts 25.0, price is 26.66 battery is 26.388888888888886
# at time 13.0 agent transacts -12.5, price is 27.25 battery is 50.0
# at time 14.0 agent transacts -25.0, price is 22.33 battery is 36.111111111111114
# at time 15.0 agent transacts 12.5, price is 19.62 battery is 8.333333333333336
# at time 16.0 agent transacts 0.0, price is 18.89 battery is 20.833333333333336
# at time 17.0 agent transacts 25.0, price is 22.49 battery is 20.833333333333336
# at time 18.0 agent transacts -25.0, price is 30.09 battery is 45.833333333333336
# at time 19.0 agent transacts -12.5, price is 34.94 battery is 18.055555555555557
# at time 20.0 agent transacts 25.0, price is 38.94 battery is 4.166666666666668
# at time 21.0 agent transacts 12.5, price is 34.85 battery is 29.166666666666668
# at time 22.0 agent transacts -25.0, price is 31.1 battery is 41.66666666666667
# at time 23.0 agent transacts 25.0, price is 33.29 battery is 13.888888888888893
# at time 24.0 agent transacts -25.0, price is 32.86 battery is 38.88888888888889
# at time 1.0 agent transacts 0.0, price is 30.06 battery is 11.111111111111114
# at time 2.0 agent transacts 25.0, price is 27.96 battery is 11.111111111111114
# at time 3.0 agent transacts -12.5, price is 21.51 battery is 36.111111111111114
# at time 4.0 agent transacts 25.0, price is 13.22 battery is 22.222222222222225
# at time 5.0 agent transacts -12.5, price is 10.51 battery is 47.22222222222223
# at time 6.0 agent transacts -12.5, price is 17.72 battery is 33.33333333333334
# at time 7.0 agent transacts 0.0, price is 28.96 battery is 19.444444444444454
# at time 8.0 agent transacts 25.0, price is 35.6 battery is 19.444444444444454
# at time 9.0 agent transacts 25.0, price is 35.48 battery is 24.444444444444457
# at time 10.0 agent transacts 0.0, price is 40.0 battery is 24.444444444444457
# at time 11.0 agent transacts 25.0, price is 42.14 battery is 24.444444444444457
# at time 12.0 agent transacts 12.5, price is 46.0 battery is 24.444444444444457
# at time 13.0 agent transacts 12.5, price is 44.44 battery is 24.444444444444457
# at time 14.0 agent transacts -12.5, price is 40.0 battery is 24.444444444444457
# at time 15.0 agent transacts -12.5, price is 37.27 battery is 24.444444444444457
# at time 16.0 agent transacts 12.5, price is 35.25 battery is 24.444444444444457
# at time 17.0 agent transacts 12.5, price is 38.0 battery is 24.444444444444457
# at time 18.0 agent transacts 25.0, price is 53.57 battery is 24.444444444444457
# at time 19.0 agent transacts 0.0, price is 58.5 battery is 24.444444444444457
# at time 20.0 agent transacts 25.0, price is 56.19 battery is 24.444444444444457
# at time 21.0 agent transacts -12.5, price is 50.76 battery is 49.44444444444446
# at time 22.0 agent transacts -12.5, price is 44.74 battery is 35.55555555555557
# at time 23.0 agent transacts 0.0, price is 46.92 battery is 21.666666666666682
# at time 24.0 agent transacts -12.5, price is 42.27 battery is 21.666666666666682
# at time 1.0 agent transacts 12.5, price is 39.1 battery is 7.777777777777793
# at time 2.0 agent transacts -12.5, price is 34.08 battery is 20.277777777777793
# at time 3.0 agent transacts 25.0, price is 29.13 battery is 6.3888888888889035
# at time 4.0 agent transacts 0.0, price is 18.37 battery is 31.388888888888903
# at time 5.0 agent transacts 0.0, price is 17.81 battery is 31.388888888888903
# at time 6.0 agent transacts -25.0, price is 30.41 battery is 31.388888888888903
# at time 7.0 agent transacts 12.5, price is 33.69 battery is 3.611111111111125
# at time 8.0 agent transacts 12.5, price is 39.91 battery is 16.111111111111125
# at time 9.0 agent transacts 12.5, price is 44.9 battery is 28.611111111111125
# at time 10.0 agent transacts 0.0, price is 51.8 battery is 41.11111111111113
# at time 11.0 agent transacts 0.0, price is 51.65 battery is 41.11111111111113
# at time 12.0 agent transacts -12.5, price is 52.08 battery is 41.11111111111113
# at time 13.0 agent transacts 25.0, price is 53.18 battery is 27.22222222222224
# at time 14.0 agent transacts -25.0, price is 52.04 battery is 50.0
# at time 15.0 agent transacts 12.5, price is 50.18 battery is 22.22222222222222
# at time 16.0 agent transacts -12.5, price is 49.96 battery is 34.72222222222222
# at time 17.0 agent transacts 12.5, price is 52.39 battery is 20.833333333333332
# at time 18.0 agent transacts -25.0, price is 63.57 battery is 33.33333333333333
# at time 19.0 agent transacts 25.0, price is 68.61 battery is 5.55555555555555
# at time 20.0 agent transacts -25.0, price is 64.2 battery is 30.55555555555555
# at time 21.0 agent transacts 25.0, price is 53.91 battery is 2.7777777777777715
# at time 22.0 agent transacts -12.5, price is 46.25 battery is 27.77777777777777
# at time 23.0 agent transacts 25.0, price is 49.35 battery is 13.888888888888882
# at time 24.0 agent transacts -25.0, price is 48.02 battery is 38.888888888888886
# at time 1.0 agent transacts 0.0, price is 44.25 battery is 11.111111111111107
# at time 2.0 agent transacts 25.0, price is 39.99 battery is 11.111111111111107
# at time 3.0 agent transacts 12.5, price is 37.6 battery is 36.11111111111111
# at time 4.0 agent transacts -12.5, price is 34.21 battery is 48.61111111111111
# at time 5.0 agent transacts 0.0, price is 30.42 battery is 34.722222222222214
# at time 6.0 agent transacts -12.5, price is 37.0 battery is 34.722222222222214
# at time 7.0 agent transacts 12.5, price is 40.56 battery is 20.833333333333325
# at time 8.0 agent transacts 0.0, price is 46.13 battery is 33.33333333333333
# at time 9.0 agent transacts -12.5, price is 47.86 battery is 33.33333333333333
# at time 10.0 agent transacts -12.5, price is 47.63 battery is 19.44444444444444
# at time 11.0 agent transacts 0.0, price is 49.29 battery is 5.55555555555555
# at time 12.0 agent transacts 25.0, price is 48.85 battery is 5.55555555555555
# at time 13.0 agent transacts 0.0, price is 50.27 battery is 30.55555555555555
# at time 14.0 agent transacts 12.5, price is 46.89 battery is 30.55555555555555
# at time 15.0 agent transacts 0.0, price is 43.98 battery is 43.05555555555555
# at time 16.0 agent transacts -12.5, price is 43.2 battery is 43.05555555555555
# at time 17.0 agent transacts -12.5, price is 48.97 battery is 29.16666666666666
# at time 18.0 agent transacts 0.0, price is 53.96 battery is 15.277777777777771
# at time 19.0 agent transacts 25.0, price is 56.2 battery is 15.277777777777771
# at time 20.0 agent transacts -12.5, price is 52.12 battery is 40.27777777777777
# at time 21.0 agent transacts -12.5, price is 49.0 battery is 26.388888888888882
# at time 22.0 agent transacts 12.5, price is 41.81 battery is 12.499999999999993
# at time 23.0 agent transacts 12.5, price is 39.79 battery is 24.999999999999993
# at time 24.0 agent transacts 0.0, price is 38.25 battery is 37.49999999999999
# at time 1.0 agent transacts 0.0, price is 34.49 battery is 37.49999999999999
# at time 2.0 agent transacts 0.0, price is 35.79 battery is 37.49999999999999
# at time 3.0 agent transacts -12.5, price is 20.7 battery is 37.49999999999999
# at time 4.0 agent transacts 0.0, price is 12.18 battery is 23.611111111111104
# at time 5.0 agent transacts 0.0, price is 12.47 battery is 23.611111111111104
# at time 6.0 agent transacts 12.5, price is 13.11 battery is 23.611111111111104
# at time 7.0 agent transacts 12.5, price is 28.98 battery is 36.1111111111111
# at time 8.0 agent transacts -25.0, price is 40.1 battery is 48.6111111111111
# at time 9.0 agent transacts 25.0, price is 41.87 battery is 0.8333333333333215
# at time 10.0 agent transacts 12.5, price is 44.94 battery is 0.8333333333333215
# at time 11.0 agent transacts 12.5, price is 46.5 battery is 0.8333333333333215
# at time 12.0 agent transacts 12.5, price is 46.0 battery is 0.8333333333333215
# at time 13.0 agent transacts 12.5, price is 47.43 battery is 0.8333333333333215
# at time 14.0 agent transacts 25.0, price is 46.5 battery is 0.8333333333333215
# at time 15.0 agent transacts 12.5, price is 42.9 battery is 0.8333333333333215
# at time 16.0 agent transacts 0.0, price is 42.42 battery is 0.8333333333333215
# at time 17.0 agent transacts 25.0, price is 45.0 battery is 0.8333333333333215
# at time 18.0 agent transacts 0.0, price is 53.1 battery is 0.8333333333333215
# at time 19.0 agent transacts 12.5, price is 54.93 battery is 0.8333333333333215
# at time 20.0 agent transacts 25.0, price is 49.88 battery is 13.333333333333321
# at time 21.0 agent transacts 0.0, price is 45.0 battery is 38.33333333333332
# at time 22.0 agent transacts -12.5, price is 40.27 battery is 38.33333333333332
# at time 23.0 agent transacts 12.5, price is 43.74 battery is 24.444444444444432
# at time 24.0 agent transacts -12.5, price is 41.91 battery is 36.94444444444443
# at time 1.0 agent transacts -12.5, price is 34.91 battery is 23.05555555555554
# at time 2.0 agent transacts 0.0, price is 33.02 battery is 9.16666666666665
# at time 3.0 agent transacts 0.0, price is 27.26 battery is 9.16666666666665
# at time 4.0 agent transacts 12.5, price is 17.7 battery is 9.16666666666665
# at time 5.0 agent transacts 0.0, price is 18.75 battery is 21.66666666666665
# at time 6.0 agent transacts 0.0, price is 25.18 battery is 21.66666666666665
# at time 7.0 agent transacts 0.0, price is 31.0 battery is 21.66666666666665
# at time 8.0 agent transacts 25.0, price is 38.5 battery is 21.66666666666665
# at time 9.0 agent transacts 25.0, price is 40.63 battery is 26.66666666666665
# at time 10.0 agent transacts 12.5, price is 42.9 battery is 26.66666666666665
# at time 11.0 agent transacts 12.5, price is 43.8 battery is 26.66666666666665
# at time 12.0 agent transacts 0.0, price is 46.5 battery is 26.66666666666665
# at time 13.0 agent transacts -12.5, price is 48.76 battery is 26.66666666666665
# at time 14.0 agent transacts -12.5, price is 44.5 battery is 26.66666666666665
# at time 15.0 agent transacts 0.0, price is 42.77 battery is 26.66666666666665
# at time 16.0 agent transacts 25.0, price is 42.78 battery is 26.66666666666665
# at time 17.0 agent transacts 25.0, price is 45.9 battery is 26.66666666666665
# at time 18.0 agent transacts 12.5, price is 56.64 battery is 26.66666666666665
# at time 19.0 agent transacts 12.5, price is 63.22 battery is 26.66666666666665
# at time 20.0 agent transacts -25.0, price is 55.76 battery is 39.16666666666665
# at time 21.0 agent transacts 0.0, price is 50.21 battery is 11.388888888888872
# at time 22.0 agent transacts 12.5, price is 43.13 battery is 11.388888888888872
# at time 23.0 agent transacts -12.5, price is 46.62 battery is 23.88888888888887
# at time 24.0 agent transacts 0.0, price is 41.15 battery is 9.999999999999982
# at time 1.0 agent transacts 0.0, price is 33.23 battery is 9.999999999999982
# at time 2.0 agent transacts 12.5, price is 30.78 battery is 9.999999999999982
# at time 3.0 agent transacts 25.0, price is 28.28 battery is 22.499999999999982
# at time 4.0 agent transacts -25.0, price is 24.52 battery is 47.499999999999986
# at time 5.0 agent transacts 25.0, price is 15.9 battery is 19.722222222222207
# at time 6.0 agent transacts -25.0, price is 20.0 battery is 44.72222222222221
# at time 7.0 agent transacts 25.0, price is 23.68 battery is 16.94444444444443
# at time 8.0 agent transacts 0.0, price is 25.04 battery is 41.94444444444443
# at time 9.0 agent transacts 12.5, price is 25.48 battery is 21.94444444444443
# at time 10.0 agent transacts 12.5, price is 28.67 battery is 21.94444444444443
# at time 11.0 agent transacts -12.5, price is 28.5 battery is 21.94444444444443
# at time 12.0 agent transacts 12.5, price is 30.41 battery is 21.94444444444443
# at time 13.0 agent transacts 25.0, price is 34.67 battery is 21.94444444444443
# at time 14.0 agent transacts 0.0, price is 31.76 battery is 21.94444444444443
# at time 15.0 agent transacts 25.0, price is 29.13 battery is 21.94444444444443
# at time 16.0 agent transacts -12.5, price is 27.48 battery is 21.94444444444443
# at time 17.0 agent transacts 25.0, price is 27.72 battery is 21.94444444444443
# at time 18.0 agent transacts 25.0, price is 33.54 battery is 21.94444444444443
# at time 19.0 agent transacts -12.5, price is 37.44 battery is 21.94444444444443
# at time 20.0 agent transacts 0.0, price is 34.56 battery is 8.05555555555554
# at time 21.0 agent transacts 25.0, price is 28.75 battery is 8.05555555555554
# at time 22.0 agent transacts 12.5, price is 25.79 battery is 33.05555555555554
# at time 23.0 agent transacts -12.5, price is 31.1 battery is 45.55555555555554
# Profit on validation set over 5 epsidoes:  -6210.429902469155

# %% [markdown]
# ## Baseline Moving Average

# %%
class MAgent(RandomAgent):
    def __init__(self, env, action_space, window=6):
        super().__init__(env, action_space)
        self.price_history = [0 for x in range(window)]

    def select_on_price(self):
        mask = self.mask()
        state = self.env.observation()

        # bookkeep prices
        price = state[1]
        self.price_history.pop(0)
        self.price_history.append(price)
        avg_price_6h = np.mean(self.price_history)

        # Sell when twice as high
        if price > 2 * avg_price_6h:
            action = np.min(self.actions[mask])
        
        # Buy when low
        elif price < 0.5 * avg_price_6h:
            action = np.max(self.actions[mask])
        
        # hold if possible
        else:
            if mask[2] == True:
                action = 0
            else:
                action =  np.random.choice(self.actions[mask])
        
        return action

# %%
custom_action_space = CustomDiscreteActionSpace()
env = Electric_Car(path_to_test_data='validate.xlsx')
average_agent = MAgent(env, custom_action_space)
all_profits = []

for episode in range(5):
    done = False
    profits = 0
    while not done:
        current_state = average_agent.env.observation()
        battery, price, hour  = current_state[0], current_state[1], current_state[2] 
        action = average_agent.select_on_price()

        if average_agent.env.car_is_available and episode == 4:
            print(f"at time {hour} agent transacts {action * 25}, price is {price} battery is {battery}")       
        
        next_state, reward, done, trucated, info = average_agent.env.step(action)
        profits += reward

    all_profits.append(profits)
    average_agent.reset()
    
print("Profit on validation set for 5 epochs: ", np.mean(all_profits))
# Out:
# at time 1.0 agent transacts 25.0, price is 13.2 battery is 25.0
# at time 2.0 agent transacts 0, price is 13.14 battery is 50.0
# at time 3.0 agent transacts 0, price is 11.83 battery is 50.0
# at time 4.0 agent transacts 0, price is 9.49 battery is 50.0
# at time 5.0 agent transacts 0, price is 8.63 battery is 50.0
# at time 6.0 agent transacts 0, price is 7.12 battery is 50.0
# at time 7.0 agent transacts 0.0, price is 4.06 battery is 50.0
# at time 8.0 agent transacts 0.0, price is 1.0 battery is 50.0
# at time 19.0 agent transacts 0, price is 22.7 battery is 30.0
# at time 20.0 agent transacts 0, price is 30.06 battery is 30.0
# at time 21.0 agent transacts 0, price is 27.3 battery is 30.0
# at time 22.0 agent transacts 0, price is 23.93 battery is 30.0
# at time 23.0 agent transacts 0, price is 33.49 battery is 30.0
# at time 24.0 agent transacts 0, price is 31.06 battery is 30.0
# at time 1.0 agent transacts 0, price is 23.0 battery is 30.0
# at time 2.0 agent transacts 0, price is 17.45 battery is 30.0
# at time 3.0 agent transacts 0, price is 19.12 battery is 30.0
# at time 4.0 agent transacts 0, price is 12.76 battery is 30.0
# at time 5.0 agent transacts 0, price is 10.19 battery is 30.0
# at time 6.0 agent transacts 0, price is 11.99 battery is 30.0
# at time 7.0 agent transacts 0, price is 15.65 battery is 30.0
# at time 8.0 agent transacts 0, price is 23.5 battery is 30.0
# at time 9.0 agent transacts 0, price is 28.9 battery is 30.0
# at time 10.0 agent transacts 0, price is 37.12 battery is 30.0
# at time 11.0 agent transacts 0, price is 41.82 battery is 30.0
# at time 12.0 agent transacts 0, price is 44.69 battery is 30.0
# at time 13.0 agent transacts 0, price is 47.0 battery is 30.0
# at time 14.0 agent transacts 0, price is 41.15 battery is 30.0
# at time 15.0 agent transacts 0, price is 39.25 battery is 30.0
# at time 16.0 agent transacts 0, price is 34.95 battery is 30.0
# at time 17.0 agent transacts 0, price is 37.26 battery is 30.0
# at time 18.0 agent transacts 0, price is 46.84 battery is 30.0
# at time 19.0 agent transacts 0, price is 56.49 battery is 30.0
# at time 20.0 agent transacts 0, price is 56.05 battery is 30.0
# at time 21.0 agent transacts 0, price is 45.5 battery is 30.0
# at time 22.0 agent transacts 0, price is 39.32 battery is 30.0
# at time 23.0 agent transacts 0, price is 43.0 battery is 30.0
# at time 24.0 agent transacts 0, price is 41.07 battery is 30.0
# at time 1.0 agent transacts 0, price is 39.44 battery is 30.0
# at time 2.0 agent transacts 0, price is 31.98 battery is 30.0
# at time 3.0 agent transacts 0, price is 30.0 battery is 30.0
# at time 4.0 agent transacts 0, price is 27.07 battery is 30.0
# at time 5.0 agent transacts 0, price is 19.18 battery is 30.0
# at time 6.0 agent transacts 0, price is 17.51 battery is 30.0
# at time 7.0 agent transacts 0, price is 17.03 battery is 30.0
# at time 8.0 agent transacts 0, price is 21.0 battery is 30.0
# at time 9.0 agent transacts 0, price is 28.23 battery is 30.0
# at time 10.0 agent transacts 0, price is 35.01 battery is 30.0
# at time 11.0 agent transacts 0, price is 40.0 battery is 30.0
# at time 12.0 agent transacts 0, price is 44.18 battery is 30.0
# at time 13.0 agent transacts 0, price is 47.21 battery is 30.0
# at time 14.0 agent transacts 0, price is 41.55 battery is 30.0
# at time 15.0 agent transacts 0, price is 36.54 battery is 30.0
# at time 16.0 agent transacts 0, price is 33.2 battery is 30.0
# at time 17.0 agent transacts 0, price is 26.53 battery is 30.0
# at time 18.0 agent transacts 0, price is 44.6 battery is 30.0
# at time 19.0 agent transacts 0, price is 56.85 battery is 30.0
# at time 20.0 agent transacts 0, price is 57.75 battery is 30.0
# at time 21.0 agent transacts 0, price is 49.66 battery is 30.0
# at time 22.0 agent transacts 0, price is 39.67 battery is 30.0
# at time 23.0 agent transacts 0, price is 43.55 battery is 30.0
# at time 24.0 agent transacts 0, price is 39.34 battery is 30.0
# at time 1.0 agent transacts 0, price is 37.15 battery is 30.0
# at time 2.0 agent transacts 0, price is 33.47 battery is 30.0
# at time 3.0 agent transacts 0, price is 28.0 battery is 30.0
# at time 4.0 agent transacts 0, price is 21.29 battery is 30.0
# at time 5.0 agent transacts 0, price is 16.92 battery is 30.0
# at time 6.0 agent transacts 0, price is 28.0 battery is 30.0
# at time 7.0 agent transacts 0, price is 36.43 battery is 30.0
# at time 8.0 agent transacts 0, price is 59.47 battery is 30.0
# at time 9.0 agent transacts 0, price is 59.73 battery is 30.0
# at time 10.0 agent transacts 0, price is 62.1 battery is 30.0
# at time 11.0 agent transacts 0, price is 62.74 battery is 30.0
# at time 12.0 agent transacts 0, price is 62.65 battery is 30.0
# at time 13.0 agent transacts 0, price is 62.51 battery is 30.0
# at time 14.0 agent transacts 0, price is 59.92 battery is 30.0
# at time 15.0 agent transacts 0, price is 56.0 battery is 30.0
# at time 16.0 agent transacts 0, price is 49.67 battery is 30.0
# at time 17.0 agent transacts 0, price is 54.4 battery is 30.0
# at time 18.0 agent transacts 0, price is 71.11 battery is 30.0
# at time 19.0 agent transacts 0, price is 78.77 battery is 30.0
# at time 20.0 agent transacts 0, price is 64.46 battery is 30.0
# at time 21.0 agent transacts 0, price is 50.73 battery is 30.0
# at time 22.0 agent transacts 0, price is 43.9 battery is 30.0
# at time 23.0 agent transacts 0, price is 46.58 battery is 30.0
# at time 24.0 agent transacts 0, price is 43.38 battery is 30.0
# at time 1.0 agent transacts 0, price is 37.9 battery is 30.0
# at time 2.0 agent transacts 0, price is 38.11 battery is 30.0
# at time 3.0 agent transacts 0, price is 29.99 battery is 30.0
# at time 4.0 agent transacts 0, price is 28.91 battery is 30.0
# at time 5.0 agent transacts 0, price is 27.0 battery is 30.0
# at time 6.0 agent transacts 0, price is 29.56 battery is 30.0
# at time 7.0 agent transacts 0, price is 40.94 battery is 30.0
# at time 8.0 agent transacts 0, price is 55.0 battery is 30.0
# at time 9.0 agent transacts 0, price is 55.5 battery is 30.0
# at time 10.0 agent transacts 0, price is 57.1 battery is 30.0
# at time 11.0 agent transacts 0, price is 57.0 battery is 30.0
# at time 12.0 agent transacts 0, price is 58.0 battery is 30.0
# at time 13.0 agent transacts 0, price is 57.0 battery is 30.0
# at time 14.0 agent transacts 0, price is 56.17 battery is 30.0
# at time 15.0 agent transacts 0, price is 56.28 battery is 30.0
# at time 16.0 agent transacts 0, price is 53.54 battery is 30.0
# at time 17.0 agent transacts 0, price is 56.19 battery is 30.0
# at time 18.0 agent transacts 0, price is 67.2 battery is 30.0
# at time 19.0 agent transacts 0, price is 62.0 battery is 30.0
# at time 20.0 agent transacts 0, price is 55.0 battery is 30.0
# at time 21.0 agent transacts 0, price is 49.5 battery is 30.0
# at time 22.0 agent transacts 0, price is 45.88 battery is 30.0
# at time 23.0 agent transacts 0, price is 42.68 battery is 30.0
# at time 24.0 agent transacts 0, price is 41.85 battery is 30.0
# at time 1.0 agent transacts 0, price is 48.52 battery is 30.0
# at time 2.0 agent transacts 0, price is 39.62 battery is 30.0
# at time 3.0 agent transacts 0, price is 41.25 battery is 30.0
# at time 4.0 agent transacts 0, price is 37.12 battery is 30.0
# at time 5.0 agent transacts 0, price is 32.5 battery is 30.0
# at time 6.0 agent transacts 0, price is 39.5 battery is 30.0
# at time 7.0 agent transacts 0, price is 51.69 battery is 30.0
# at time 8.0 agent transacts 0, price is 56.9 battery is 30.0
# at time 9.0 agent transacts 0, price is 56.95 battery is 30.0
# at time 10.0 agent transacts 0, price is 49.75 battery is 30.0
# at time 11.0 agent transacts 0, price is 52.31 battery is 30.0
# at time 12.0 agent transacts 0, price is 68.16 battery is 30.0
# at time 13.0 agent transacts 0, price is 66.19 battery is 30.0
# at time 14.0 agent transacts 0, price is 61.24 battery is 30.0
# at time 15.0 agent transacts 0, price is 59.7 battery is 30.0
# at time 16.0 agent transacts 0, price is 54.63 battery is 30.0
# at time 17.0 agent transacts 0, price is 51.0 battery is 30.0
# at time 18.0 agent transacts 0, price is 66.99 battery is 30.0
# at time 19.0 agent transacts 0, price is 75.0 battery is 30.0
# at time 20.0 agent transacts 0, price is 56.9 battery is 30.0
# at time 21.0 agent transacts 0, price is 43.56 battery is 30.0
# at time 22.0 agent transacts 0, price is 40.5 battery is 30.0
# at time 23.0 agent transacts 0, price is 56.36 battery is 30.0
# at time 24.0 agent transacts 0, price is 58.98 battery is 30.0
# at time 1.0 agent transacts 0, price is 40.0 battery is 30.0
# at time 2.0 agent transacts 0, price is 38.02 battery is 30.0
# at time 3.0 agent transacts 0, price is 34.99 battery is 30.0
# at time 4.0 agent transacts 0, price is 33.65 battery is 30.0
# at time 5.0 agent transacts 0, price is 32.0 battery is 30.0
# at time 6.0 agent transacts 0, price is 32.82 battery is 30.0
# at time 7.0 agent transacts 0, price is 39.1 battery is 30.0
# at time 8.0 agent transacts 0, price is 52.65 battery is 30.0
# at time 19.0 agent transacts 0, price is 70.0 battery is 10.0
# at time 20.0 agent transacts 0, price is 59.95 battery is 10.0
# at time 21.0 agent transacts 0, price is 54.0 battery is 10.0
# at time 22.0 agent transacts 0, price is 48.0 battery is 10.0
# at time 23.0 agent transacts 0, price is 46.47 battery is 10.0
# at time 24.0 agent transacts 0, price is 43.94 battery is 10.0
# at time 1.0 agent transacts 0, price is 47.96 battery is 10.0
# at time 2.0 agent transacts 0, price is 49.02 battery is 10.0
# at time 3.0 agent transacts 0, price is 37.0 battery is 10.0
# at time 4.0 agent transacts 0, price is 33.61 battery is 10.0
# at time 5.0 agent transacts 0, price is 32.96 battery is 10.0
# at time 6.0 agent transacts 0, price is 33.31 battery is 10.0
# at time 7.0 agent transacts 0, price is 54.9 battery is 10.0
# at time 8.0 agent transacts 25.0, price is 66.26 battery is 10.0
# at time 9.0 agent transacts 0, price is 75.0 battery is 35.0
# at time 10.0 agent transacts 0, price is 78.09 battery is 35.0
# at time 11.0 agent transacts 0, price is 61.45 battery is 35.0
# at time 12.0 agent transacts 0, price is 59.26 battery is 35.0
# at time 13.0 agent transacts 0, price is 57.0 battery is 35.0
# at time 14.0 agent transacts 0, price is 61.4 battery is 35.0
# at time 15.0 agent transacts 0, price is 49.01 battery is 35.0
# at time 16.0 agent transacts 0, price is 48.0 battery is 35.0
# at time 17.0 agent transacts 0, price is 49.66 battery is 35.0
# at time 18.0 agent transacts 0, price is 63.08 battery is 35.0
# at time 19.0 agent transacts 0, price is 55.63 battery is 35.0
# at time 20.0 agent transacts 0, price is 47.15 battery is 35.0
# at time 21.0 agent transacts 0, price is 41.49 battery is 35.0
# at time 22.0 agent transacts 0, price is 34.99 battery is 35.0
# at time 23.0 agent transacts 0, price is 36.04 battery is 35.0
# at time 24.0 agent transacts 0, price is 54.9 battery is 35.0
# at time 1.0 agent transacts 0, price is 30.04 battery is 35.0
# at time 2.0 agent transacts 0, price is 28.0 battery is 35.0
# at time 3.0 agent transacts 0, price is 46.16 battery is 35.0
# at time 4.0 agent transacts 0, price is 27.53 battery is 35.0
# at time 5.0 agent transacts 0, price is 25.0 battery is 35.0
# at time 6.0 agent transacts 0, price is 22.0 battery is 35.0
# at time 7.0 agent transacts 0, price is 30.24 battery is 35.0
# at time 8.0 agent transacts 0, price is 33.0 battery is 35.0
# at time 9.0 agent transacts 0, price is 37.0 battery is 35.0
# at time 10.0 agent transacts 0, price is 42.99 battery is 35.0
# at time 11.0 agent transacts 0, price is 46.59 battery is 35.0
# at time 12.0 agent transacts 0, price is 46.76 battery is 35.0
# at time 13.0 agent transacts 0, price is 47.66 battery is 35.0
# at time 14.0 agent transacts 0, price is 45.0 battery is 35.0
# at time 15.0 agent transacts 0, price is 43.6 battery is 35.0
# at time 16.0 agent transacts 0, price is 40.06 battery is 35.0
# at time 17.0 agent transacts 0, price is 45.0 battery is 35.0
# at time 18.0 agent transacts 0, price is 55.29 battery is 35.0
# at time 19.0 agent transacts 0, price is 51.61 battery is 35.0
# at time 20.0 agent transacts 0, price is 48.0 battery is 35.0
# at time 21.0 agent transacts 0, price is 48.77 battery is 35.0
# at time 22.0 agent transacts 0, price is 39.93 battery is 35.0
# at time 23.0 agent transacts 0, price is 43.24 battery is 35.0
# at time 24.0 agent transacts 0, price is 43.05 battery is 35.0
# at time 1.0 agent transacts 0, price is 66.0 battery is 35.0
# at time 2.0 agent transacts 0, price is 63.19 battery is 35.0
# at time 3.0 agent transacts 0, price is 56.18 battery is 35.0
# at time 4.0 agent transacts 12.5, price is 18.0 battery is 35.0
# at time 5.0 agent transacts 0.0, price is 0.01 battery is 47.5
# at time 6.0 agent transacts 0.0, price is 0.01 battery is 47.5
# at time 7.0 agent transacts 0.0, price is 1.0 battery is 47.5
# at time 8.0 agent transacts 0.0, price is 0.01 battery is 47.5
# at time 19.0 agent transacts 0, price is 54.0 battery is 27.5
# at time 20.0 agent transacts 0, price is 49.18 battery is 27.5
# at time 21.0 agent transacts 0, price is 45.62 battery is 27.5
# at time 22.0 agent transacts 0, price is 43.0 battery is 27.5
# at time 23.0 agent transacts 0, price is 43.0 battery is 27.5
# at time 24.0 agent transacts 0, price is 38.1 battery is 27.5
# at time 1.0 agent transacts 0, price is 59.43 battery is 27.5
# at time 2.0 agent transacts 0, price is 45.93 battery is 27.5
# at time 3.0 agent transacts 0, price is 36.09 battery is 27.5
# at time 4.0 agent transacts 0, price is 31.0 battery is 27.5
# at time 5.0 agent transacts 0, price is 30.91 battery is 27.5
# at time 6.0 agent transacts 0, price is 30.9 battery is 27.5
# at time 7.0 agent transacts 0, price is 37.31 battery is 27.5
# at time 8.0 agent transacts 0, price is 57.04 battery is 27.5
# at time 9.0 agent transacts 0, price is 70.5 battery is 27.5
# at time 10.0 agent transacts 0, price is 71.5 battery is 27.5
# at time 11.0 agent transacts 0, price is 71.0 battery is 27.5
# at time 12.0 agent transacts 0, price is 70.04 battery is 27.5
# at time 13.0 agent transacts 0, price is 68.75 battery is 27.5
# at time 14.0 agent transacts 0, price is 84.48 battery is 27.5
# at time 15.0 agent transacts 0, price is 81.52 battery is 27.5
# at time 16.0 agent transacts 0, price is 61.45 battery is 27.5
# at time 17.0 agent transacts 0, price is 72.69 battery is 27.5
# at time 18.0 agent transacts 0, price is 89.0 battery is 27.5
# at time 19.0 agent transacts 0, price is 80.66 battery is 27.5
# at time 20.0 agent transacts 0, price is 63.5 battery is 27.5
# at time 21.0 agent transacts 0, price is 49.99 battery is 27.5
# at time 22.0 agent transacts 0, price is 43.66 battery is 27.5
# at time 23.0 agent transacts 0, price is 66.19 battery is 27.5
# at time 24.0 agent transacts 0, price is 62.92 battery is 27.5
# at time 1.0 agent transacts 0, price is 63.2 battery is 27.5
# at time 2.0 agent transacts 0, price is 67.27 battery is 27.5
# at time 3.0 agent transacts 0, price is 61.85 battery is 27.5
# at time 4.0 agent transacts 0, price is 55.0 battery is 27.5
# at time 5.0 agent transacts 0, price is 53.02 battery is 27.5
# at time 6.0 agent transacts 0, price is 60.29 battery is 27.5
# at time 7.0 agent transacts 0, price is 75.0 battery is 27.5
# at time 8.0 agent transacts 0, price is 102.12 battery is 27.5
# at time 19.0 agent transacts 0, price is 101.25 battery is 7.5
# at time 20.0 agent transacts 0, price is 72.77 battery is 7.5
# at time 21.0 agent transacts 0, price is 64.15 battery is 7.5
# at time 22.0 agent transacts 0, price is 42.0 battery is 7.5
# at time 23.0 agent transacts 0, price is 61.1 battery is 7.5
# at time 24.0 agent transacts 0, price is 54.69 battery is 7.5
# at time 1.0 agent transacts 0, price is 44.96 battery is 7.5
# at time 2.0 agent transacts 0, price is 46.4 battery is 7.5
# at time 3.0 agent transacts 0, price is 45.88 battery is 7.5
# at time 4.0 agent transacts 0, price is 35.01 battery is 7.5
# at time 5.0 agent transacts 0, price is 34.28 battery is 7.5
# at time 6.0 agent transacts 0, price is 37.11 battery is 7.5
# at time 7.0 agent transacts 0, price is 53.05 battery is 7.5
# at time 8.0 agent transacts 25.0, price is 66.18 battery is 7.5
# at time 9.0 agent transacts 0, price is 63.92 battery is 32.5
# at time 10.0 agent transacts 0, price is 61.46 battery is 32.5
# at time 11.0 agent transacts 0, price is 62.36 battery is 32.5
# at time 12.0 agent transacts 0, price is 63.88 battery is 32.5
# at time 13.0 agent transacts 0, price is 66.46 battery is 32.5
# at time 14.0 agent transacts 0, price is 65.15 battery is 32.5
# at time 15.0 agent transacts 0, price is 63.6 battery is 32.5
# at time 16.0 agent transacts 0, price is 57.65 battery is 32.5
# at time 17.0 agent transacts 0, price is 58.29 battery is 32.5
# at time 18.0 agent transacts 0, price is 67.01 battery is 32.5
# at time 19.0 agent transacts 0, price is 72.13 battery is 32.5
# at time 20.0 agent transacts 0, price is 71.03 battery is 32.5
# at time 21.0 agent transacts 0, price is 67.5 battery is 32.5
# at time 22.0 agent transacts 0, price is 43.5 battery is 32.5
# at time 23.0 agent transacts 0, price is 51.67 battery is 32.5
# at time 24.0 agent transacts 0, price is 47.0 battery is 32.5
# at time 1.0 agent transacts 0, price is 44.09 battery is 32.5
# at time 2.0 agent transacts 0, price is 45.18 battery is 32.5
# at time 3.0 agent transacts 0, price is 41.19 battery is 32.5
# at time 4.0 agent transacts 0, price is 33.5 battery is 32.5
# at time 5.0 agent transacts 0, price is 32.21 battery is 32.5
# at time 6.0 agent transacts 0, price is 40.9 battery is 32.5
# at time 7.0 agent transacts 0, price is 51.47 battery is 32.5
# at time 8.0 agent transacts 0, price is 65.25 battery is 32.5
# at time 19.0 agent transacts 0, price is 87.96 battery is 12.5
# at time 20.0 agent transacts 0, price is 69.99 battery is 12.5
# at time 21.0 agent transacts 0, price is 66.19 battery is 12.5
# at time 22.0 agent transacts 0, price is 55.59 battery is 12.5
# at time 23.0 agent transacts 0, price is 55.53 battery is 12.5
# at time 24.0 agent transacts 0, price is 50.62 battery is 12.5
# at time 1.0 agent transacts 0, price is 47.73 battery is 12.5
# at time 2.0 agent transacts 0, price is 47.78 battery is 12.5
# at time 3.0 agent transacts 0, price is 42.75 battery is 12.5
# at time 4.0 agent transacts 0, price is 32.99 battery is 12.5
# at time 5.0 agent transacts 0, price is 32.0 battery is 12.5
# at time 6.0 agent transacts 0, price is 39.84 battery is 12.5
# at time 7.0 agent transacts 0, price is 48.96 battery is 12.5
# at time 8.0 agent transacts 12.5, price is 65.0 battery is 12.5
# at time 19.0 agent transacts 0, price is 67.44 battery is 5.0
# at time 20.0 agent transacts 0, price is 66.99 battery is 5.0
# at time 21.0 agent transacts 0, price is 60.95 battery is 5.0
# at time 22.0 agent transacts 0, price is 50.77 battery is 5.0
# at time 23.0 agent transacts 0, price is 53.06 battery is 5.0
# at time 24.0 agent transacts 0, price is 53.86 battery is 5.0
# at time 1.0 agent transacts 0, price is 42.56 battery is 5.0
# at time 2.0 agent transacts 0, price is 40.74 battery is 5.0
# at time 3.0 agent transacts 0, price is 37.56 battery is 5.0
# at time 4.0 agent transacts 0, price is 34.01 battery is 5.0
# at time 5.0 agent transacts 0, price is 31.76 battery is 5.0
# at time 6.0 agent transacts 0, price is 29.8 battery is 5.0
# at time 7.0 agent transacts 0, price is 29.2 battery is 5.0
# at time 8.0 agent transacts 25.0, price is 27.67 battery is 5.0
# at time 9.0 agent transacts 0, price is 36.67 battery is 30.0
# at time 10.0 agent transacts 0, price is 43.0 battery is 30.0
# at time 11.0 agent transacts 0, price is 45.34 battery is 30.0
# at time 12.0 agent transacts 0, price is 46.0 battery is 30.0
# at time 13.0 agent transacts 0, price is 43.0 battery is 30.0
# at time 14.0 agent transacts 0, price is 39.59 battery is 30.0
# at time 15.0 agent transacts 0, price is 37.93 battery is 30.0
# at time 16.0 agent transacts 0, price is 34.87 battery is 30.0
# at time 17.0 agent transacts 0, price is 34.3 battery is 30.0
# at time 18.0 agent transacts 0, price is 44.8 battery is 30.0
# at time 19.0 agent transacts 0, price is 53.12 battery is 30.0
# at time 20.0 agent transacts 0, price is 39.93 battery is 30.0
# at time 21.0 agent transacts 0, price is 34.2 battery is 30.0
# at time 22.0 agent transacts 0, price is 37.0 battery is 30.0
# at time 23.0 agent transacts 0, price is 47.03 battery is 30.0
# at time 24.0 agent transacts 0, price is 47.08 battery is 30.0
# at time 1.0 agent transacts 0, price is 41.78 battery is 30.0
# at time 2.0 agent transacts 0, price is 40.17 battery is 30.0
# at time 3.0 agent transacts 0, price is 30.91 battery is 30.0
# at time 4.0 agent transacts 12.5, price is 17.0 battery is 30.0
# at time 5.0 agent transacts 0.0, price is 14.79 battery is 42.5
# at time 6.0 agent transacts 0.0, price is 12.31 battery is 42.5
# at time 7.0 agent transacts 0, price is 11.93 battery is 42.5
# at time 8.0 agent transacts 0, price is 14.0 battery is 42.5
# at time 19.0 agent transacts 0, price is 41.11 battery is 22.5
# at time 20.0 agent transacts 0, price is 43.0 battery is 22.5
# at time 21.0 agent transacts 0, price is 43.71 battery is 22.5
# at time 22.0 agent transacts 0, price is 42.65 battery is 22.5
# at time 23.0 agent transacts 0, price is 45.21 battery is 22.5
# at time 24.0 agent transacts 0, price is 42.73 battery is 22.5
# at time 1.0 agent transacts 0, price is 32.01 battery is 22.5
# at time 2.0 agent transacts 0, price is 31.0 battery is 22.5
# at time 3.0 agent transacts 0, price is 26.44 battery is 22.5
# at time 4.0 agent transacts 0, price is 19.15 battery is 22.5
# at time 5.0 agent transacts 0, price is 19.0 battery is 22.5
# at time 6.0 agent transacts 0, price is 26.21 battery is 22.5
# at time 7.0 agent transacts 0, price is 40.2 battery is 22.5
# at time 8.0 agent transacts 0, price is 61.53 battery is 22.5
# at time 9.0 agent transacts 0, price is 60.21 battery is 22.5
# at time 10.0 agent transacts 0, price is 59.99 battery is 22.5
# at time 11.0 agent transacts 0, price is 59.3 battery is 22.5
# at time 12.0 agent transacts 0, price is 59.12 battery is 22.5
# at time 13.0 agent transacts 0, price is 57.34 battery is 22.5
# at time 14.0 agent transacts 0, price is 54.93 battery is 22.5
# at time 15.0 agent transacts 0, price is 50.91 battery is 22.5
# at time 16.0 agent transacts 0, price is 48.33 battery is 22.5
# at time 17.0 agent transacts 0, price is 52.8 battery is 22.5
# at time 18.0 agent transacts 0, price is 62.07 battery is 22.5
# at time 19.0 agent transacts 0, price is 68.27 battery is 22.5
# at time 20.0 agent transacts 0, price is 54.75 battery is 22.5
# at time 21.0 agent transacts 0, price is 47.8 battery is 22.5
# at time 22.0 agent transacts 0, price is 43.54 battery is 22.5
# at time 23.0 agent transacts 0, price is 47.91 battery is 22.5
# at time 24.0 agent transacts 0, price is 42.31 battery is 22.5
# at time 1.0 agent transacts 0, price is 39.93 battery is 22.5
# at time 2.0 agent transacts 0, price is 38.67 battery is 22.5
# at time 3.0 agent transacts 0, price is 33.99 battery is 22.5
# at time 4.0 agent transacts 0, price is 30.91 battery is 22.5
# at time 5.0 agent transacts 0, price is 29.0 battery is 22.5
# at time 6.0 agent transacts 0, price is 36.53 battery is 22.5
# at time 7.0 agent transacts 0, price is 49.59 battery is 22.5
# at time 8.0 agent transacts 0, price is 57.0 battery is 22.5
# at time 19.0 agent transacts 0, price is 65.46 battery is 2.5
# at time 20.0 agent transacts 0, price is 58.87 battery is 2.5
# at time 21.0 agent transacts 0, price is 50.86 battery is 2.5
# at time 22.0 agent transacts 0, price is 43.4 battery is 2.5
# at time 23.0 agent transacts 0, price is 47.66 battery is 2.5
# at time 24.0 agent transacts 0, price is 43.79 battery is 2.5
# at time 1.0 agent transacts 0, price is 38.57 battery is 2.5
# at time 2.0 agent transacts 0, price is 37.33 battery is 2.5
# at time 3.0 agent transacts 0, price is 31.64 battery is 2.5
# at time 4.0 agent transacts 0, price is 29.31 battery is 2.5
# at time 5.0 agent transacts 0, price is 28.91 battery is 2.5
# at time 6.0 agent transacts 0, price is 32.96 battery is 2.5
# at time 7.0 agent transacts 0, price is 43.08 battery is 2.5
# at time 8.0 agent transacts 25.0, price is 58.0 battery is 2.5
# at time 9.0 agent transacts 0, price is 56.44 battery is 27.5
# at time 10.0 agent transacts 0, price is 56.87 battery is 27.5
# at time 11.0 agent transacts 0, price is 58.62 battery is 27.5
# at time 12.0 agent transacts 0, price is 53.09 battery is 27.5
# at time 13.0 agent transacts 0, price is 51.0 battery is 27.5
# at time 14.0 agent transacts 0, price is 52.46 battery is 27.5
# at time 15.0 agent transacts 0, price is 54.68 battery is 27.5
# at time 16.0 agent transacts 0, price is 49.78 battery is 27.5
# at time 17.0 agent transacts 0, price is 49.99 battery is 27.5
# at time 18.0 agent transacts 0, price is 54.93 battery is 27.5
# at time 19.0 agent transacts 0, price is 63.84 battery is 27.5
# at time 20.0 agent transacts 0, price is 47.1 battery is 27.5
# at time 21.0 agent transacts 0, price is 46.83 battery is 27.5
# at time 22.0 agent transacts 0, price is 43.0 battery is 27.5
# at time 23.0 agent transacts 0, price is 44.99 battery is 27.5
# at time 24.0 agent transacts 0, price is 41.02 battery is 27.5
# at time 1.0 agent transacts 0, price is 37.51 battery is 27.5
# at time 2.0 agent transacts 0, price is 36.12 battery is 27.5
# at time 3.0 agent transacts 0, price is 33.05 battery is 27.5
# at time 4.0 agent transacts 0, price is 28.81 battery is 27.5
# at time 5.0 agent transacts 0, price is 27.54 battery is 27.5
# at time 6.0 agent transacts 0, price is 34.0 battery is 27.5
# at time 7.0 agent transacts 0, price is 41.3 battery is 27.5
# at time 8.0 agent transacts 0, price is 53.18 battery is 27.5
# at time 19.0 agent transacts 0, price is 63.16 battery is 7.5
# at time 20.0 agent transacts 0, price is 47.58 battery is 7.5
# at time 21.0 agent transacts 0, price is 44.93 battery is 7.5
# at time 22.0 agent transacts 0, price is 42.0 battery is 7.5
# at time 23.0 agent transacts 0, price is 45.0 battery is 7.5
# at time 24.0 agent transacts 0, price is 40.47 battery is 7.5
# at time 1.0 agent transacts 0, price is 37.75 battery is 7.5
# at time 2.0 agent transacts 0, price is 37.1 battery is 7.5
# at time 3.0 agent transacts 0, price is 32.48 battery is 7.5
# at time 4.0 agent transacts 0, price is 30.3 battery is 7.5
# at time 5.0 agent transacts 0, price is 29.34 battery is 7.5
# at time 6.0 agent transacts 0, price is 31.34 battery is 7.5
# at time 7.0 agent transacts 0, price is 40.86 battery is 7.5
# at time 8.0 agent transacts 25.0, price is 54.14 battery is 7.5
# at time 19.0 agent transacts 0, price is 51.43 battery is 12.5
# at time 20.0 agent transacts 0, price is 44.88 battery is 12.5
# at time 21.0 agent transacts 0, price is 41.5 battery is 12.5
# at time 22.0 agent transacts 0, price is 42.4 battery is 12.5
# at time 23.0 agent transacts 0, price is 43.47 battery is 12.5
# at time 24.0 agent transacts 0, price is 40.51 battery is 12.5
# at time 1.0 agent transacts 0, price is 41.27 battery is 12.5
# at time 2.0 agent transacts 0, price is 39.09 battery is 12.5
# at time 3.0 agent transacts 0, price is 35.0 battery is 12.5
# at time 4.0 agent transacts 0, price is 30.95 battery is 12.5
# at time 5.0 agent transacts 0, price is 28.5 battery is 12.5
# at time 6.0 agent transacts 0, price is 29.58 battery is 12.5
# at time 7.0 agent transacts 0, price is 29.77 battery is 12.5
# at time 8.0 agent transacts 25.0, price is 35.0 battery is 12.5
# at time 19.0 agent transacts 0, price is 53.19 battery is 17.5
# at time 20.0 agent transacts 0, price is 52.83 battery is 17.5
# at time 21.0 agent transacts 0, price is 46.29 battery is 17.5
# at time 22.0 agent transacts 0, price is 41.19 battery is 17.5
# at time 23.0 agent transacts 0, price is 43.01 battery is 17.5
# at time 24.0 agent transacts 0, price is 42.0 battery is 17.5
# at time 1.0 agent transacts 0, price is 42.07 battery is 17.5
# at time 2.0 agent transacts 0, price is 41.83 battery is 17.5
# at time 3.0 agent transacts 0, price is 40.09 battery is 17.5
# at time 4.0 agent transacts 0, price is 33.28 battery is 17.5
# at time 5.0 agent transacts 0, price is 26.67 battery is 17.5
# at time 6.0 agent transacts 0, price is 22.0 battery is 17.5
# at time 7.0 agent transacts 0, price is 20.05 battery is 17.5
# at time 8.0 agent transacts 25.0, price is 27.85 battery is 17.5
# at time 19.0 agent transacts 0, price is 50.08 battery is 22.5
# at time 20.0 agent transacts 0, price is 49.48 battery is 22.5
# at time 21.0 agent transacts 0, price is 45.68 battery is 22.5
# at time 22.0 agent transacts 0, price is 42.42 battery is 22.5
# at time 23.0 agent transacts 0, price is 43.16 battery is 22.5
# at time 24.0 agent transacts 0, price is 42.63 battery is 22.5
# at time 1.0 agent transacts 0, price is 37.71 battery is 22.5
# at time 2.0 agent transacts 0, price is 34.15 battery is 22.5
# at time 3.0 agent transacts 0, price is 31.0 battery is 22.5
# at time 4.0 agent transacts 0, price is 27.0 battery is 22.5
# at time 5.0 agent transacts 0, price is 27.97 battery is 22.5
# at time 6.0 agent transacts 0, price is 33.0 battery is 22.5
# at time 7.0 agent transacts 0, price is 43.45 battery is 22.5
# at time 8.0 agent transacts 0, price is 53.6 battery is 22.5
# at time 9.0 agent transacts 0, price is 57.11 battery is 22.5
# at time 10.0 agent transacts 0, price is 61.0 battery is 22.5
# at time 11.0 agent transacts 0, price is 62.7 battery is 22.5
# at time 12.0 agent transacts 0, price is 62.7 battery is 22.5
# at time 13.0 agent transacts 0, price is 59.04 battery is 22.5
# at time 14.0 agent transacts 0, price is 60.04 battery is 22.5
# at time 15.0 agent transacts 0, price is 55.58 battery is 22.5
# at time 16.0 agent transacts 0, price is 50.66 battery is 22.5
# at time 17.0 agent transacts 0, price is 51.0 battery is 22.5
# at time 18.0 agent transacts 0, price is 60.67 battery is 22.5
# at time 19.0 agent transacts 0, price is 58.85 battery is 22.5
# at time 20.0 agent transacts 0, price is 50.0 battery is 22.5
# at time 21.0 agent transacts 0, price is 49.9 battery is 22.5
# at time 22.0 agent transacts 0, price is 44.37 battery is 22.5
# at time 23.0 agent transacts 0, price is 42.89 battery is 22.5
# at time 24.0 agent transacts 0, price is 39.84 battery is 22.5
# at time 1.0 agent transacts 0, price is 41.91 battery is 22.5
# at time 2.0 agent transacts 0, price is 40.0 battery is 22.5
# at time 3.0 agent transacts 0, price is 36.25 battery is 22.5
# at time 4.0 agent transacts 0, price is 31.08 battery is 22.5
# at time 5.0 agent transacts 0, price is 30.0 battery is 22.5
# at time 6.0 agent transacts 0, price is 37.01 battery is 22.5
# at time 7.0 agent transacts 0, price is 44.11 battery is 22.5
# at time 8.0 agent transacts 0, price is 56.3 battery is 22.5
# at time 19.0 agent transacts 0, price is 70.18 battery is 2.5
# at time 20.0 agent transacts 0, price is 61.07 battery is 2.5
# at time 21.0 agent transacts 0, price is 50.77 battery is 2.5
# at time 22.0 agent transacts 0, price is 46.72 battery is 2.5
# at time 23.0 agent transacts 0, price is 46.1 battery is 2.5
# at time 24.0 agent transacts 0, price is 45.68 battery is 2.5
# at time 1.0 agent transacts 0, price is 49.89 battery is 2.5
# at time 2.0 agent transacts 0, price is 46.03 battery is 2.5
# at time 3.0 agent transacts 0, price is 43.02 battery is 2.5
# at time 4.0 agent transacts 0, price is 35.94 battery is 2.5
# at time 5.0 agent transacts 0, price is 33.5 battery is 2.5
# at time 6.0 agent transacts 0, price is 34.81 battery is 2.5
# at time 7.0 agent transacts 0, price is 46.7 battery is 2.5
# at time 8.0 agent transacts 25.0, price is 60.97 battery is 2.5
# at time 19.0 agent transacts 0, price is 52.0 battery is 7.5
# at time 20.0 agent transacts 0, price is 44.93 battery is 7.5
# at time 21.0 agent transacts 0, price is 38.0 battery is 7.5
# at time 22.0 agent transacts 0, price is 33.98 battery is 7.5
# at time 23.0 agent transacts 0, price is 44.1 battery is 7.5
# at time 24.0 agent transacts 0, price is 45.52 battery is 7.5
# at time 1.0 agent transacts 0, price is 43.86 battery is 7.5
# at time 2.0 agent transacts 0, price is 44.77 battery is 7.5
# at time 3.0 agent transacts 0, price is 43.04 battery is 7.5
# at time 4.0 agent transacts 0, price is 35.21 battery is 7.5
# at time 5.0 agent transacts 0, price is 34.5 battery is 7.5
# at time 6.0 agent transacts 0, price is 43.15 battery is 7.5
# at time 7.0 agent transacts 0, price is 56.18 battery is 7.5
# at time 8.0 agent transacts 25.0, price is 65.99 battery is 7.5
# at time 9.0 agent transacts 0, price is 63.2 battery is 32.5
# at time 10.0 agent transacts 0, price is 63.07 battery is 32.5
# at time 11.0 agent transacts 0, price is 61.26 battery is 32.5
# at time 12.0 agent transacts 0, price is 61.34 battery is 32.5
# at time 13.0 agent transacts 0, price is 56.19 battery is 32.5
# at time 14.0 agent transacts 0, price is 55.0 battery is 32.5
# at time 15.0 agent transacts 0, price is 54.55 battery is 32.5
# at time 16.0 agent transacts 0, price is 51.92 battery is 32.5
# at time 17.0 agent transacts 0, price is 51.67 battery is 32.5
# at time 18.0 agent transacts 0, price is 53.43 battery is 32.5
# at time 19.0 agent transacts 0, price is 76.86 battery is 32.5
# at time 20.0 agent transacts 0, price is 51.0 battery is 32.5
# at time 21.0 agent transacts 0, price is 47.0 battery is 32.5
# at time 22.0 agent transacts 0, price is 41.5 battery is 32.5
# at time 23.0 agent transacts 0, price is 47.17 battery is 32.5
# at time 24.0 agent transacts 0, price is 47.02 battery is 32.5
# at time 1.0 agent transacts 0, price is 50.14 battery is 32.5
# at time 2.0 agent transacts 0, price is 46.32 battery is 32.5
# at time 3.0 agent transacts 0, price is 35.0 battery is 32.5
# at time 4.0 agent transacts 0, price is 32.0 battery is 32.5
# at time 5.0 agent transacts 0, price is 31.5 battery is 32.5
# at time 6.0 agent transacts 0, price is 35.27 battery is 32.5
# at time 7.0 agent transacts 0, price is 60.11 battery is 32.5
# at time 8.0 agent transacts 0, price is 66.26 battery is 32.5
# at time 19.0 agent transacts 0, price is 58.5 battery is 12.5
# at time 20.0 agent transacts 0, price is 55.0 battery is 12.5
# at time 21.0 agent transacts 0, price is 48.94 battery is 12.5
# at time 22.0 agent transacts 0, price is 42.0 battery is 12.5
# at time 23.0 agent transacts 0, price is 59.5 battery is 12.5
# at time 24.0 agent transacts 0, price is 58.96 battery is 12.5
# at time 1.0 agent transacts 0, price is 46.61 battery is 12.5
# at time 2.0 agent transacts 0, price is 46.33 battery is 12.5
# at time 3.0 agent transacts 0, price is 30.0 battery is 12.5
# at time 4.0 agent transacts 0, price is 28.0 battery is 12.5
# at time 5.0 agent transacts 0, price is 27.92 battery is 12.5
# at time 6.0 agent transacts 0, price is 29.0 battery is 12.5
# at time 7.0 agent transacts 0, price is 29.34 battery is 12.5
# at time 8.0 agent transacts 12.5, price is 33.5 battery is 12.5
# at time 19.0 agent transacts 0, price is 57.0 battery is 5.0
# at time 20.0 agent transacts 0, price is 50.0 battery is 5.0
# at time 21.0 agent transacts 0, price is 46.69 battery is 5.0
# at time 22.0 agent transacts 0, price is 41.26 battery is 5.0
# at time 23.0 agent transacts 0, price is 43.5 battery is 5.0
# at time 24.0 agent transacts 0, price is 42.97 battery is 5.0
# at time 1.0 agent transacts 0, price is 55.77 battery is 5.0
# at time 2.0 agent transacts 0, price is 55.11 battery is 5.0
# at time 3.0 agent transacts 0, price is 32.0 battery is 5.0
# at time 4.0 agent transacts 0, price is 28.72 battery is 5.0
# at time 5.0 agent transacts 0, price is 26.29 battery is 5.0
# at time 6.0 agent transacts 0, price is 23.04 battery is 5.0
# at time 7.0 agent transacts 0, price is 16.04 battery is 5.0
# at time 8.0 agent transacts 25.0, price is 18.44 battery is 5.0
# at time 9.0 agent transacts 0, price is 25.59 battery is 30.0
# at time 10.0 agent transacts 0, price is 32.17 battery is 30.0
# at time 11.0 agent transacts 0, price is 37.0 battery is 30.0
# at time 12.0 agent transacts 0, price is 42.5 battery is 30.0
# at time 13.0 agent transacts 0, price is 43.75 battery is 30.0
# at time 14.0 agent transacts 0, price is 38.99 battery is 30.0
# at time 15.0 agent transacts 0, price is 34.2 battery is 30.0
# at time 16.0 agent transacts 0, price is 31.97 battery is 30.0
# at time 17.0 agent transacts 0, price is 34.93 battery is 30.0
# at time 18.0 agent transacts 0, price is 48.36 battery is 30.0
# at time 19.0 agent transacts 0, price is 55.0 battery is 30.0
# at time 20.0 agent transacts 0, price is 50.0 battery is 30.0
# at time 21.0 agent transacts 0, price is 45.0 battery is 30.0
# at time 22.0 agent transacts 0, price is 41.28 battery is 30.0
# at time 23.0 agent transacts 0, price is 43.67 battery is 30.0
# at time 24.0 agent transacts 0, price is 51.75 battery is 30.0
# at time 1.0 agent transacts 0, price is 36.5 battery is 30.0
# at time 2.0 agent transacts 0, price is 34.0 battery is 30.0
# at time 3.0 agent transacts 0, price is 30.65 battery is 30.0
# at time 4.0 agent transacts 0, price is 29.93 battery is 30.0
# at time 5.0 agent transacts 0, price is 27.8 battery is 30.0
# at time 6.0 agent transacts 0, price is 31.0 battery is 30.0
# at time 7.0 agent transacts 0, price is 69.57 battery is 30.0
# at time 8.0 agent transacts 0, price is 74.23 battery is 30.0
# at time 19.0 agent transacts 0, price is 109.72 battery is 10.0
# at time 20.0 agent transacts 0, price is 91.01 battery is 10.0
# at time 21.0 agent transacts 0, price is 50.5 battery is 10.0
# at time 22.0 agent transacts 0, price is 43.05 battery is 10.0
# at time 23.0 agent transacts 0, price is 56.29 battery is 10.0
# at time 24.0 agent transacts 0, price is 56.96 battery is 10.0
# at time 1.0 agent transacts 0, price is 39.33 battery is 10.0
# at time 2.0 agent transacts 0, price is 40.75 battery is 10.0
# at time 3.0 agent transacts 0, price is 31.5 battery is 10.0
# at time 4.0 agent transacts 0, price is 29.0 battery is 10.0
# at time 5.0 agent transacts 0, price is 28.0 battery is 10.0
# at time 6.0 agent transacts 0, price is 30.5 battery is 10.0
# at time 7.0 agent transacts 0, price is 53.03 battery is 10.0
# at time 8.0 agent transacts 12.5, price is 65.99 battery is 10.0
# at time 19.0 agent transacts 0, price is 75.18 battery is 2.5
# at time 20.0 agent transacts 0, price is 66.01 battery is 2.5
# at time 21.0 agent transacts 0, price is 56.0 battery is 2.5
# at time 22.0 agent transacts 0, price is 35.53 battery is 2.5
# at time 23.0 agent transacts 0, price is 48.59 battery is 2.5
# at time 24.0 agent transacts 0, price is 45.17 battery is 2.5
# at time 1.0 agent transacts 0, price is 39.85 battery is 2.5
# at time 2.0 agent transacts 0, price is 42.29 battery is 2.5
# at time 3.0 agent transacts 0, price is 30.0 battery is 2.5
# at time 4.0 agent transacts 0, price is 27.06 battery is 2.5
# at time 5.0 agent transacts 0, price is 24.38 battery is 2.5
# at time 6.0 agent transacts 0, price is 30.0 battery is 2.5
# at time 7.0 agent transacts 0, price is 47.02 battery is 2.5
# at time 8.0 agent transacts 25.0, price is 58.99 battery is 2.5
# at time 19.0 agent transacts 0, price is 80.25 battery is 7.5
# at time 20.0 agent transacts 0, price is 59.11 battery is 7.5
# at time 21.0 agent transacts 0, price is 49.93 battery is 7.5
# at time 22.0 agent transacts 0, price is 45.88 battery is 7.5
# at time 23.0 agent transacts 0, price is 45.09 battery is 7.5
# at time 24.0 agent transacts 0, price is 42.0 battery is 7.5
# at time 1.0 agent transacts 0, price is 39.76 battery is 7.5
# at time 2.0 agent transacts 0, price is 41.02 battery is 7.5
# at time 3.0 agent transacts 0, price is 33.5 battery is 7.5
# at time 4.0 agent transacts 0, price is 29.93 battery is 7.5
# at time 5.0 agent transacts 0, price is 30.0 battery is 7.5
# at time 6.0 agent transacts 0, price is 36.0 battery is 7.5
# at time 7.0 agent transacts 0, price is 44.74 battery is 7.5
# at time 8.0 agent transacts 25.0, price is 56.91 battery is 7.5
# at time 9.0 agent transacts 0, price is 57.95 battery is 32.5
# at time 10.0 agent transacts 0, price is 59.25 battery is 32.5
# at time 11.0 agent transacts 0, price is 58.92 battery is 32.5
# at time 12.0 agent transacts 0, price is 59.3 battery is 32.5
# at time 13.0 agent transacts 0, price is 56.88 battery is 32.5
# at time 14.0 agent transacts 0, price is 56.34 battery is 32.5
# at time 15.0 agent transacts 0, price is 54.0 battery is 32.5
# at time 16.0 agent transacts 0, price is 51.0 battery is 32.5
# at time 17.0 agent transacts 0, price is 49.99 battery is 32.5
# at time 18.0 agent transacts 0, price is 58.0 battery is 32.5
# at time 19.0 agent transacts 0, price is 70.68 battery is 32.5
# at time 20.0 agent transacts 0, price is 59.74 battery is 32.5
# at time 21.0 agent transacts 0, price is 51.24 battery is 32.5
# at time 22.0 agent transacts 0, price is 43.61 battery is 32.5
# at time 23.0 agent transacts 0, price is 44.0 battery is 32.5
# at time 24.0 agent transacts 0, price is 39.22 battery is 32.5
# at time 1.0 agent transacts 0, price is 36.93 battery is 32.5
# at time 2.0 agent transacts 0, price is 34.19 battery is 32.5
# at time 3.0 agent transacts 0, price is 32.34 battery is 32.5
# at time 4.0 agent transacts 0, price is 29.03 battery is 32.5
# at time 5.0 agent transacts 0, price is 28.17 battery is 32.5
# at time 6.0 agent transacts 0, price is 32.58 battery is 32.5
# at time 7.0 agent transacts 0, price is 38.97 battery is 32.5
# at time 8.0 agent transacts 0, price is 50.5 battery is 32.5
# at time 9.0 agent transacts 0, price is 50.75 battery is 32.5
# at time 10.0 agent transacts 0, price is 52.0 battery is 32.5
# at time 11.0 agent transacts 0, price is 52.68 battery is 32.5
# at time 12.0 agent transacts 0, price is 53.0 battery is 32.5
# at time 13.0 agent transacts 0, price is 52.4 battery is 32.5
# at time 14.0 agent transacts 0, price is 49.19 battery is 32.5
# at time 15.0 agent transacts 0, price is 45.06 battery is 32.5
# at time 16.0 agent transacts 0, price is 41.0 battery is 32.5
# at time 17.0 agent transacts 0, price is 40.83 battery is 32.5
# at time 18.0 agent transacts 0, price is 47.0 battery is 32.5
# at time 19.0 agent transacts 0, price is 57.1 battery is 32.5
# at time 20.0 agent transacts 0, price is 53.06 battery is 32.5
# at time 21.0 agent transacts 0, price is 46.43 battery is 32.5
# at time 22.0 agent transacts 0, price is 39.91 battery is 32.5
# at time 23.0 agent transacts 0, price is 42.07 battery is 32.5
# at time 24.0 agent transacts 0, price is 41.27 battery is 32.5
# at time 1.0 agent transacts 0, price is 40.0 battery is 32.5
# at time 2.0 agent transacts 0, price is 37.93 battery is 32.5
# at time 3.0 agent transacts 0, price is 34.0 battery is 32.5
# at time 4.0 agent transacts 0, price is 29.9 battery is 32.5
# at time 5.0 agent transacts 0, price is 27.82 battery is 32.5
# at time 6.0 agent transacts 0, price is 28.01 battery is 32.5
# at time 7.0 agent transacts 0, price is 26.1 battery is 32.5
# at time 8.0 agent transacts 0, price is 31.12 battery is 32.5
# at time 9.0 agent transacts 0, price is 36.98 battery is 32.5
# at time 10.0 agent transacts 0, price is 42.27 battery is 32.5
# at time 11.0 agent transacts 0, price is 44.0 battery is 32.5
# at time 12.0 agent transacts 0, price is 46.5 battery is 32.5
# at time 13.0 agent transacts 0, price is 47.01 battery is 32.5
# at time 14.0 agent transacts 0, price is 44.12 battery is 32.5
# at time 15.0 agent transacts 0, price is 39.8 battery is 32.5
# at time 16.0 agent transacts 0, price is 38.99 battery is 32.5
# at time 17.0 agent transacts 0, price is 39.96 battery is 32.5
# at time 18.0 agent transacts 0, price is 43.77 battery is 32.5
# at time 19.0 agent transacts 0, price is 56.28 battery is 32.5
# at time 20.0 agent transacts 0, price is 53.35 battery is 32.5
# at time 21.0 agent transacts 0, price is 43.95 battery is 32.5
# at time 22.0 agent transacts 0, price is 40.09 battery is 32.5
# at time 23.0 agent transacts 0, price is 42.09 battery is 32.5
# at time 24.0 agent transacts 0, price is 40.89 battery is 32.5
# at time 1.0 agent transacts 0, price is 40.94 battery is 32.5
# at time 2.0 agent transacts 0, price is 39.41 battery is 32.5
# at time 3.0 agent transacts 0, price is 35.89 battery is 32.5
# at time 4.0 agent transacts 0, price is 30.65 battery is 32.5
# at time 5.0 agent transacts 0, price is 27.82 battery is 32.5
# at time 6.0 agent transacts 0, price is 26.28 battery is 32.5
# at time 7.0 agent transacts 0, price is 23.98 battery is 32.5
# at time 8.0 agent transacts 0, price is 27.65 battery is 32.5
# at time 9.0 agent transacts 0, price is 29.58 battery is 32.5
# at time 10.0 agent transacts 0, price is 35.78 battery is 32.5
# at time 11.0 agent transacts 0, price is 41.23 battery is 32.5
# at time 12.0 agent transacts 0, price is 43.6 battery is 32.5
# at time 13.0 agent transacts 0, price is 44.22 battery is 32.5
# at time 14.0 agent transacts 0, price is 40.49 battery is 32.5
# at time 15.0 agent transacts 0, price is 34.99 battery is 32.5
# at time 16.0 agent transacts 0, price is 32.45 battery is 32.5
# at time 17.0 agent transacts 0, price is 31.04 battery is 32.5
# at time 18.0 agent transacts 0, price is 38.04 battery is 32.5
# at time 19.0 agent transacts 0, price is 50.06 battery is 32.5
# at time 20.0 agent transacts 0, price is 51.48 battery is 32.5
# at time 21.0 agent transacts 0, price is 47.75 battery is 32.5
# at time 22.0 agent transacts 0, price is 44.3 battery is 32.5
# at time 23.0 agent transacts 0, price is 44.4 battery is 32.5
# at time 24.0 agent transacts 0, price is 40.8 battery is 32.5
# at time 1.0 agent transacts 0, price is 37.25 battery is 32.5
# at time 2.0 agent transacts 0, price is 36.46 battery is 32.5
# at time 3.0 agent transacts 0, price is 37.39 battery is 32.5
# at time 4.0 agent transacts 0, price is 30.0 battery is 32.5
# at time 5.0 agent transacts 0, price is 29.73 battery is 32.5
# at time 6.0 agent transacts 0, price is 33.0 battery is 32.5
# at time 7.0 agent transacts 0, price is 54.0 battery is 32.5
# at time 8.0 agent transacts 0, price is 63.62 battery is 32.5
# at time 19.0 agent transacts 0, price is 101.2 battery is 12.5
# at time 20.0 agent transacts 0, price is 70.03 battery is 12.5
# at time 21.0 agent transacts 0, price is 61.99 battery is 12.5
# at time 22.0 agent transacts 0, price is 45.87 battery is 12.5
# at time 23.0 agent transacts 0, price is 51.0 battery is 12.5
# at time 24.0 agent transacts 0, price is 45.9 battery is 12.5
# at time 1.0 agent transacts 0, price is 39.96 battery is 12.5
# at time 2.0 agent transacts 0, price is 39.0 battery is 12.5
# at time 3.0 agent transacts 0, price is 35.0 battery is 12.5
# at time 4.0 agent transacts 0, price is 30.0 battery is 12.5
# at time 5.0 agent transacts 0, price is 29.5 battery is 12.5
# at time 6.0 agent transacts 0, price is 36.09 battery is 12.5
# at time 7.0 agent transacts 0, price is 46.41 battery is 12.5
# at time 8.0 agent transacts 12.5, price is 58.0 battery is 12.5
# at time 9.0 agent transacts 0, price is 62.59 battery is 25.0
# at time 10.0 agent transacts 0, price is 63.18 battery is 25.0
# at time 11.0 agent transacts 0, price is 64.1 battery is 25.0
# at time 12.0 agent transacts 0, price is 64.0 battery is 25.0
# at time 13.0 agent transacts 0, price is 60.53 battery is 25.0
# at time 14.0 agent transacts 0, price is 57.23 battery is 25.0
# at time 15.0 agent transacts 0, price is 56.27 battery is 25.0
# at time 16.0 agent transacts 0, price is 53.02 battery is 25.0
# at time 17.0 agent transacts 0, price is 54.13 battery is 25.0
# at time 18.0 agent transacts 0, price is 60.8 battery is 25.0
# at time 19.0 agent transacts 0, price is 78.41 battery is 25.0
# at time 20.0 agent transacts 0, price is 70.09 battery is 25.0
# at time 21.0 agent transacts 0, price is 54.61 battery is 25.0
# at time 22.0 agent transacts 0, price is 46.43 battery is 25.0
# at time 23.0 agent transacts 0, price is 46.5 battery is 25.0
# at time 24.0 agent transacts 0, price is 44.61 battery is 25.0
# at time 1.0 agent transacts 0, price is 40.71 battery is 25.0
# at time 2.0 agent transacts 0, price is 44.99 battery is 25.0
# at time 3.0 agent transacts 0, price is 38.87 battery is 25.0
# at time 4.0 agent transacts 0, price is 31.96 battery is 25.0
# at time 5.0 agent transacts 0, price is 30.72 battery is 25.0
# at time 6.0 agent transacts 0, price is 37.0 battery is 25.0
# at time 7.0 agent transacts 0, price is 44.75 battery is 25.0
# at time 8.0 agent transacts 0, price is 59.99 battery is 25.0
# at time 9.0 agent transacts 0, price is 63.36 battery is 25.0
# at time 10.0 agent transacts 0, price is 66.19 battery is 25.0
# at time 11.0 agent transacts 0, price is 66.09 battery is 25.0
# at time 12.0 agent transacts 0, price is 66.26 battery is 25.0
# ...
# at time 22.0 agent transacts 0, price is 54.79 battery is 24.72222222222222
# at time 23.0 agent transacts 0, price is 56.28 battery is 24.72222222222222
# at time 24.0 agent transacts 0, price is 54.26 battery is 24.72222222222222
# at time 1.0 agent transacts 0, price is 50.02 battery is 24.72222222222222
# at time 2.0 agent transacts 0, price is 45.69 battery is 24.72222222222222
# at time 3.0 agent transacts 0, price is 40.33 battery is 24.72222222222222
# at time 4.0 agent transacts 0, price is 36.62 battery is 24.72222222222222
# at time 5.0 agent transacts 0, price is 35.07 battery is 24.72222222222222
# at time 6.0 agent transacts 0, price is 38.1 battery is 24.72222222222222
# at time 7.0 agent transacts 0, price is 45.36 battery is 24.72222222222222
# at time 8.0 agent transacts 0, price is 58.19 battery is 24.72222222222222
# at time 19.0 agent transacts 0, price is 71.65 battery is 4.722222222222221
# at time 20.0 agent transacts 0, price is 64.0 battery is 4.722222222222221
# at time 21.0 agent transacts 0, price is 57.34 battery is 4.722222222222221
# at time 22.0 agent transacts 0, price is 48.1 battery is 4.722222222222221
# at time 23.0 agent transacts 0, price is 49.64 battery is 4.722222222222221
# at time 24.0 agent transacts 0, price is 47.1 battery is 4.722222222222221
# at time 1.0 agent transacts 0, price is 38.53 battery is 4.722222222222221
# at time 2.0 agent transacts 0, price is 39.61 battery is 4.722222222222221
# at time 3.0 agent transacts 0, price is 37.0 battery is 4.722222222222221
# at time 4.0 agent transacts 0, price is 32.91 battery is 4.722222222222221
# at time 5.0 agent transacts 0, price is 33.39 battery is 4.722222222222221
# at time 6.0 agent transacts 0, price is 37.56 battery is 4.722222222222221
# at time 7.0 agent transacts 0, price is 41.09 battery is 4.722222222222221
# at time 8.0 agent transacts 25.0, price is 49.13 battery is 4.722222222222221
# at time 19.0 agent transacts 0, price is 64.99 battery is 9.722222222222221
# at time 20.0 agent transacts 0, price is 61.16 battery is 9.722222222222221
# at time 21.0 agent transacts 0, price is 53.02 battery is 9.722222222222221
# at time 22.0 agent transacts 0, price is 47.75 battery is 9.722222222222221
# at time 23.0 agent transacts 0, price is 50.2 battery is 9.722222222222221
# at time 24.0 agent transacts 0, price is 47.67 battery is 9.722222222222221
# at time 1.0 agent transacts 0, price is 42.05 battery is 9.722222222222221
# at time 2.0 agent transacts 0, price is 39.8 battery is 9.722222222222221
# at time 3.0 agent transacts 0, price is 38.23 battery is 9.722222222222221
# at time 4.0 agent transacts 0, price is 35.03 battery is 9.722222222222221
# at time 5.0 agent transacts 0, price is 36.11 battery is 9.722222222222221
# at time 6.0 agent transacts 0, price is 38.17 battery is 9.722222222222221
# at time 7.0 agent transacts 0, price is 42.85 battery is 9.722222222222221
# at time 8.0 agent transacts 25.0, price is 49.08 battery is 9.722222222222221
# at time 9.0 agent transacts 0, price is 53.22 battery is 34.72222222222222
# at time 10.0 agent transacts 0, price is 54.42 battery is 34.72222222222222
# at time 11.0 agent transacts 0, price is 53.27 battery is 34.72222222222222
# at time 12.0 agent transacts 0, price is 55.5 battery is 34.72222222222222
# at time 13.0 agent transacts 0, price is 56.4 battery is 34.72222222222222
# at time 14.0 agent transacts 0, price is 54.91 battery is 34.72222222222222
# at time 15.0 agent transacts 0, price is 54.49 battery is 34.72222222222222
# at time 16.0 agent transacts 0, price is 54.45 battery is 34.72222222222222
# at time 17.0 agent transacts 0, price is 55.46 battery is 34.72222222222222
# at time 18.0 agent transacts 0, price is 62.4 battery is 34.72222222222222
# at time 19.0 agent transacts 0, price is 62.96 battery is 34.72222222222222
# at time 20.0 agent transacts 0, price is 58.96 battery is 34.72222222222222
# at time 21.0 agent transacts 0, price is 54.91 battery is 34.72222222222222
# at time 22.0 agent transacts 0, price is 49.59 battery is 34.72222222222222
# at time 23.0 agent transacts 0, price is 48.0 battery is 34.72222222222222
# at time 24.0 agent transacts 0, price is 46.36 battery is 34.72222222222222
# at time 1.0 agent transacts 0, price is 42.87 battery is 34.72222222222222
# at time 2.0 agent transacts 0, price is 39.94 battery is 34.72222222222222
# at time 3.0 agent transacts 0, price is 36.98 battery is 34.72222222222222
# at time 4.0 agent transacts 0, price is 32.73 battery is 34.72222222222222
# at time 5.0 agent transacts 0, price is 30.16 battery is 34.72222222222222
# at time 6.0 agent transacts 0, price is 37.62 battery is 34.72222222222222
# at time 7.0 agent transacts 0, price is 42.66 battery is 34.72222222222222
# at time 8.0 agent transacts 0, price is 47.58 battery is 34.72222222222222
# at time 19.0 agent transacts 0, price is 61.19 battery is 14.722222222222221
# at time 20.0 agent transacts 0, price is 59.06 battery is 14.722222222222221
# at time 21.0 agent transacts 0, price is 53.2 battery is 14.722222222222221
# at time 22.0 agent transacts 0, price is 49.5 battery is 14.722222222222221
# at time 23.0 agent transacts 0, price is 47.5 battery is 14.722222222222221
# at time 24.0 agent transacts 0, price is 43.07 battery is 14.722222222222221
# at time 1.0 agent transacts 0, price is 41.85 battery is 14.722222222222221
# at time 2.0 agent transacts 0, price is 40.46 battery is 14.722222222222221
# at time 3.0 agent transacts 0, price is 37.75 battery is 14.722222222222221
# at time 4.0 agent transacts 0, price is 35.13 battery is 14.722222222222221
# at time 5.0 agent transacts 0, price is 34.03 battery is 14.722222222222221
# at time 6.0 agent transacts 0, price is 37.44 battery is 14.722222222222221
# at time 7.0 agent transacts 0, price is 42.74 battery is 14.722222222222221
# at time 8.0 agent transacts 12.5, price is 49.63 battery is 14.722222222222221
# at time 9.0 agent transacts 0, price is 53.34 battery is 27.22222222222222
# at time 10.0 agent transacts 0, price is 54.31 battery is 27.22222222222222
# at time 11.0 agent transacts 0, price is 53.31 battery is 27.22222222222222
# at time 12.0 agent transacts 0, price is 54.45 battery is 27.22222222222222
# at time 13.0 agent transacts 0, price is 54.26 battery is 27.22222222222222
# at time 14.0 agent transacts 0, price is 50.46 battery is 27.22222222222222
# at time 15.0 agent transacts 0, price is 45.35 battery is 27.22222222222222
# at time 16.0 agent transacts 0, price is 42.67 battery is 27.22222222222222
# at time 17.0 agent transacts 0, price is 46.67 battery is 27.22222222222222
# at time 18.0 agent transacts 0, price is 53.95 battery is 27.22222222222222
# at time 19.0 agent transacts 0, price is 54.18 battery is 27.22222222222222
# at time 20.0 agent transacts 0, price is 53.19 battery is 27.22222222222222
# at time 21.0 agent transacts 0, price is 49.83 battery is 27.22222222222222
# at time 22.0 agent transacts 0, price is 44.0 battery is 27.22222222222222
# at time 23.0 agent transacts 0, price is 45.1 battery is 27.22222222222222
# at time 24.0 agent transacts 0, price is 41.6 battery is 27.22222222222222
# at time 1.0 agent transacts 0, price is 24.3 battery is 27.22222222222222
# at time 2.0 agent transacts 0, price is 19.14 battery is 27.22222222222222
# at time 3.0 agent transacts 0, price is 17.16 battery is 27.22222222222222
# at time 4.0 agent transacts 25.0, price is 12.96 battery is 27.22222222222222
# at time 5.0 agent transacts 0, price is 11.34 battery is 50.0
# at time 6.0 agent transacts 0, price is 12.23 battery is 50.0
# at time 7.0 agent transacts 0, price is 12.91 battery is 50.0
# at time 8.0 agent transacts 0, price is 18.37 battery is 50.0
# at time 9.0 agent transacts 0, price is 26.73 battery is 50.0
# at time 10.0 agent transacts 0, price is 32.11 battery is 50.0
# at time 11.0 agent transacts 0, price is 33.9 battery is 50.0
# at time 12.0 agent transacts 0, price is 35.88 battery is 50.0
# at time 13.0 agent transacts 0, price is 35.44 battery is 50.0
# at time 14.0 agent transacts 0, price is 33.08 battery is 50.0
# at time 15.0 agent transacts 0, price is 31.65 battery is 50.0
# at time 16.0 agent transacts 0, price is 31.59 battery is 50.0
# at time 17.0 agent transacts 0, price is 32.92 battery is 50.0
# at time 18.0 agent transacts 0, price is 42.31 battery is 50.0
# at time 19.0 agent transacts 0, price is 44.08 battery is 50.0
# at time 20.0 agent transacts 0, price is 35.31 battery is 50.0
# at time 21.0 agent transacts 0, price is 32.95 battery is 50.0
# at time 22.0 agent transacts 0, price is 30.75 battery is 50.0
# at time 23.0 agent transacts 0, price is 35.88 battery is 50.0
# at time 24.0 agent transacts 0, price is 31.45 battery is 50.0
# at time 1.0 agent transacts 0, price is 27.18 battery is 50.0
# at time 2.0 agent transacts 0, price is 25.08 battery is 50.0
# at time 3.0 agent transacts 0, price is 20.96 battery is 50.0
# at time 4.0 agent transacts 0, price is 15.68 battery is 50.0
# at time 5.0 agent transacts 0.0, price is 10.85 battery is 50.0
# at time 6.0 agent transacts 0, price is 10.53 battery is 50.0
# at time 7.0 agent transacts 0, price is 11.33 battery is 50.0
# at time 8.0 agent transacts 0, price is 10.89 battery is 50.0
# at time 19.0 agent transacts 0, price is 34.94 battery is 30.0
# at time 20.0 agent transacts 0, price is 38.94 battery is 30.0
# at time 21.0 agent transacts 0, price is 34.85 battery is 30.0
# at time 22.0 agent transacts 0, price is 31.1 battery is 30.0
# at time 23.0 agent transacts 0, price is 33.29 battery is 30.0
# at time 24.0 agent transacts 0, price is 32.86 battery is 30.0
# at time 1.0 agent transacts 0, price is 30.06 battery is 30.0
# at time 2.0 agent transacts 0, price is 27.96 battery is 30.0
# at time 3.0 agent transacts 0, price is 21.51 battery is 30.0
# at time 4.0 agent transacts 12.5, price is 13.22 battery is 30.0
# at time 5.0 agent transacts 0.0, price is 10.51 battery is 42.5
# at time 6.0 agent transacts 0, price is 17.72 battery is 42.5
# at time 7.0 agent transacts 0, price is 28.96 battery is 42.5
# at time 8.0 agent transacts 0, price is 35.6 battery is 42.5
# at time 9.0 agent transacts 0, price is 35.48 battery is 42.5
# at time 10.0 agent transacts 0, price is 40.0 battery is 42.5
# at time 11.0 agent transacts 0, price is 42.14 battery is 42.5
# at time 12.0 agent transacts 0, price is 46.0 battery is 42.5
# at time 13.0 agent transacts 0, price is 44.44 battery is 42.5
# at time 14.0 agent transacts 0, price is 40.0 battery is 42.5
# at time 15.0 agent transacts 0, price is 37.27 battery is 42.5
# at time 16.0 agent transacts 0, price is 35.25 battery is 42.5
# at time 17.0 agent transacts 0, price is 38.0 battery is 42.5
# at time 18.0 agent transacts 0, price is 53.57 battery is 42.5
# at time 19.0 agent transacts 0, price is 58.5 battery is 42.5
# at time 20.0 agent transacts 0, price is 56.19 battery is 42.5
# at time 21.0 agent transacts 0, price is 50.76 battery is 42.5
# at time 22.0 agent transacts 0, price is 44.74 battery is 42.5
# at time 23.0 agent transacts 0, price is 46.92 battery is 42.5
# at time 24.0 agent transacts 0, price is 42.27 battery is 42.5
# at time 1.0 agent transacts 0, price is 39.1 battery is 42.5
# at time 2.0 agent transacts 0, price is 34.08 battery is 42.5
# at time 3.0 agent transacts 0, price is 29.13 battery is 42.5
# at time 4.0 agent transacts 0, price is 18.37 battery is 42.5
# at time 5.0 agent transacts 0, price is 17.81 battery is 42.5
# at time 6.0 agent transacts 0, price is 30.41 battery is 42.5
# at time 7.0 agent transacts 0, price is 33.69 battery is 42.5
# at time 8.0 agent transacts 0, price is 39.91 battery is 42.5
# at time 19.0 agent transacts 0, price is 68.61 battery is 22.5
# at time 20.0 agent transacts 0, price is 64.2 battery is 22.5
# at time 21.0 agent transacts 0, price is 53.91 battery is 22.5
# at time 22.0 agent transacts 0, price is 46.25 battery is 22.5
# at time 23.0 agent transacts 0, price is 49.35 battery is 22.5
# at time 24.0 agent transacts 0, price is 48.02 battery is 22.5
# at time 1.0 agent transacts 0, price is 44.25 battery is 22.5
# at time 2.0 agent transacts 0, price is 39.99 battery is 22.5
# at time 3.0 agent transacts 0, price is 37.6 battery is 22.5
# at time 4.0 agent transacts 0, price is 34.21 battery is 22.5
# at time 5.0 agent transacts 0, price is 30.42 battery is 22.5
# at time 6.0 agent transacts 0, price is 37.0 battery is 22.5
# at time 7.0 agent transacts 0, price is 40.56 battery is 22.5
# at time 8.0 agent transacts 0, price is 46.13 battery is 22.5
# at time 19.0 agent transacts 0, price is 56.2 battery is 2.5
# at time 20.0 agent transacts 0, price is 52.12 battery is 2.5
# at time 21.0 agent transacts 0, price is 49.0 battery is 2.5
# at time 22.0 agent transacts 0, price is 41.81 battery is 2.5
# at time 23.0 agent transacts 0, price is 39.79 battery is 2.5
# at time 24.0 agent transacts 0, price is 38.25 battery is 2.5
# at time 1.0 agent transacts 0, price is 34.49 battery is 2.5
# at time 2.0 agent transacts 0, price is 35.79 battery is 2.5
# at time 3.0 agent transacts 0, price is 20.7 battery is 2.5
# at time 4.0 agent transacts 25.0, price is 12.18 battery is 2.5
# at time 5.0 agent transacts 25.0, price is 12.47 battery is 27.5
# at time 6.0 agent transacts 0, price is 13.11 battery is 50.0
# at time 7.0 agent transacts 0, price is 28.98 battery is 50.0
# at time 8.0 agent transacts 0, price is 40.1 battery is 50.0
# at time 19.0 agent transacts 0, price is 54.93 battery is 30.0
# at time 20.0 agent transacts 0, price is 49.88 battery is 30.0
# at time 21.0 agent transacts 0, price is 45.0 battery is 30.0
# at time 22.0 agent transacts 0, price is 40.27 battery is 30.0
# at time 23.0 agent transacts 0, price is 43.74 battery is 30.0
# at time 24.0 agent transacts 0, price is 41.91 battery is 30.0
# at time 1.0 agent transacts 0, price is 34.91 battery is 30.0
# at time 2.0 agent transacts 0, price is 33.02 battery is 30.0
# at time 3.0 agent transacts 0, price is 27.26 battery is 30.0
# at time 4.0 agent transacts 0, price is 17.7 battery is 30.0
# at time 5.0 agent transacts 0, price is 18.75 battery is 30.0
# at time 6.0 agent transacts 0, price is 25.18 battery is 30.0
# at time 7.0 agent transacts 0, price is 31.0 battery is 30.0
# at time 8.0 agent transacts 0, price is 38.5 battery is 30.0
# at time 19.0 agent transacts 0, price is 63.22 battery is 10.0
# at time 20.0 agent transacts 0, price is 55.76 battery is 10.0
# at time 21.0 agent transacts 0, price is 50.21 battery is 10.0
# at time 22.0 agent transacts 0, price is 43.13 battery is 10.0
# at time 23.0 agent transacts 0, price is 46.62 battery is 10.0
# at time 24.0 agent transacts 0, price is 41.15 battery is 10.0
# at time 1.0 agent transacts 0, price is 33.23 battery is 10.0
# at time 2.0 agent transacts 0, price is 30.78 battery is 10.0
# at time 3.0 agent transacts 0, price is 28.28 battery is 10.0
# at time 4.0 agent transacts 0, price is 24.52 battery is 10.0
# at time 5.0 agent transacts 0, price is 15.9 battery is 10.0
# at time 6.0 agent transacts 0, price is 20.0 battery is 10.0
# at time 7.0 agent transacts 0, price is 23.68 battery is 10.0
# at time 8.0 agent transacts 12.5, price is 25.04 battery is 10.0
# at time 9.0 agent transacts 0, price is 25.48 battery is 22.5
# at time 10.0 agent transacts 0, price is 28.67 battery is 22.5
# at time 11.0 agent transacts 0, price is 28.5 battery is 22.5
# at time 12.0 agent transacts 0, price is 30.41 battery is 22.5
# at time 13.0 agent transacts 0, price is 34.67 battery is 22.5
# at time 14.0 agent transacts 0, price is 31.76 battery is 22.5
# at time 15.0 agent transacts 0, price is 29.13 battery is 22.5
# at time 16.0 agent transacts 0, price is 27.48 battery is 22.5
# at time 17.0 agent transacts 0, price is 27.72 battery is 22.5
# at time 18.0 agent transacts 0, price is 33.54 battery is 22.5
# at time 19.0 agent transacts 0, price is 37.44 battery is 22.5
# at time 20.0 agent transacts 0, price is 34.56 battery is 22.5
# at time 21.0 agent transacts 0, price is 28.75 battery is 22.5
# at time 22.0 agent transacts 0, price is 25.79 battery is 22.5
# at time 23.0 agent transacts 0, price is 31.1 battery is 22.5
# Profit on validation set for 5 epochs:  -674.418691358025
